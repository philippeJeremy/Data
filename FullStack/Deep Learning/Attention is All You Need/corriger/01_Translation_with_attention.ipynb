# %%
# Import necessaries librairies
import pandas as pd
import numpy as np 
import sklearn
import tensorflow_datasets as tfds
import tensorflow as tf 
import os
from sklearn.model_selection import train_test_split

#Load data with 5000 lines 
doc = pd.read_csv("https://go.aws/38ECHUB", delimiter="\t", header=None, nrows=25000)
doc.rename(columns={0:'en', 1:'fr'}, inplace=True)

#Add the word <start> to the target to change en and fr
doc["en"] = doc['en'].apply(lambda x: "<start> "+ x)

#Create 2 tokenizers fr and eng, add filters that doesn't contain <> 
tokenizer_fr = tf.keras.preprocessing.text.Tokenizer() 
tokenizer_en = tf.keras.preprocessing.text.Tokenizer(filters='!"#$%&()*+,-./:;=?@[\\]^_`{|}~\t\n')

#Fit tokenizer on fr and en
tokenizer_fr.fit_on_texts(doc['fr'])
tokenizer_en.fit_on_texts(doc["en"])

#Apply fitted tokenizers to the dataset by creating 2 columns, one for fr and 1 for en
doc["fr_indices"] = tokenizer_fr.texts_to_sequences(doc['fr'])
doc["en_indices"] = tokenizer_en.texts_to_sequences(doc['en'])

#Store in 2 variables all indices variables once they are padded with pad_sequence
padded_fr_indices = tf.keras.preprocessing.sequence.pad_sequences(doc["fr_indices"], padding="post")
padded_en_indices = tf.keras.preprocessing.sequence.pad_sequences(doc["en_indices"], padding="post")

print(padded_fr_indices.shape, padded_en_indices.shape)

#Do train_test_split to devide into train and validation sets 
X_train, X_val, y_train, y_val = train_test_split(padded_fr_indices, padded_en_indices, test_size=.2)

#Select Batch size and do tensor slices 
BATCH_SIZE=128
train = tf.data.Dataset.from_tensor_slices((X_train, y_train)).shuffle(len(X_train)).batch(BATCH_SIZE)
val = tf.data.Dataset.from_tensor_slices((X_val, y_val)).batch(BATCH_SIZE)

print(X_train.shape, X_val.shape, y_train.shape, y_val.shape)

# %%
n_embed = 1024
n_gru = 256
vocab_inp_size = len(tokenizer_fr.word_index)
vocab_tar_size = len(tokenizer_en.word_index)

# %% [markdown]
# ![bahdanau](https://full-stack-bigdata-datasets.s3.eu-west-3.amazonaws.com/Deep+Learning/attention/Attention-encoder-decoder.drawio.png)

# %%
class Encoder_maker(tf.keras.Model):
  def __init__(self, in_vocab_size, embed_dim, n_units):
    super().__init__()
    # Declaring layers I need 
    self.embed = tf.keras.layers.Embedding(input_dim=in_vocab_size, output_dim=embed_dim)
    self.gru = tf.keras.layers.GRU(units=n_units, return_sequences=True, return_state=True)
    
  def __call__(self, input_batch):
    #Returning both values of GRU
    return self.gru(self.embed(input_batch))
    
class Bahdanau_attention_maker(tf.keras.layers.Layer):
  def __init__(self, attention_units):
    super().__init__()
    # Declaring layers I need 
    self.W1 = tf.keras.layers.Dense(units=attention_units)
    self.W2 = tf.keras.layers.Dense(units=attention_units)
    self.V = tf.keras.layers.Dense(units=1)

  def __call__(self, enc_out, state):
    #Using first 2 neurons
    self.W1_out = self.W1(enc_out) 
    self.W2_out = self.W2(tf.expand_dims(state, axis = 1)) 
    self.sum = self.W1_out + self.W2_out  
    
    #Using third neuron
    self.score = self.V(tf.nn.tanh(self.sum)) 

    #Creating Attention vector
    self.attention_weights = tf.nn.softmax(self.score, axis=1) 
    self.weighted_enc_out = enc_out * self.attention_weights 
    self.context_vector = tf.reduce_sum(self.weighted_enc_out, axis=1) 

    return self.context_vector, self.attention_weights
     
class Decoder_maker(tf.keras.Model):
  def __init__(self, tar_vocab_size, embed_dim, n_units):
    super().__init__()
    # Declaring layers I need 
    self.embed = tf.keras.layers.Embedding(input_dim=tar_vocab_size, output_dim=embed_dim)
    self.gru = tf.keras.layers.GRU(units=n_units, return_sequences=True, return_state=True)
    self.pred = tf.keras.layers.Dense(units=tar_vocab_size,activation="softmax")
    self.attention = Bahdanau_attention_maker(attention_units=n_units)

  def __call__(self, dec_in, enc_out, state):
    # Applying attention layer 
    self.context_vector, self.attention_weights = self.attention(enc_out,state)
    self.embed_out = self.embed(dec_in) 
    self.concat = tf.keras.layers.concatenate([self.embed_out, tf.expand_dims(self.context_vector, axis=1)])

    # Using GRU
    self.gru_out, self.gru_state = self.gru(self.concat) 
    self.pred_out = self.pred(tf.reshape(self.gru_out, shape=(-1, self.gru_out.shape[2]))) 

    return self.pred_out, self.gru_state, self.attention_weights

# %%
encoder = Encoder_maker(vocab_inp_size+1, n_embed, n_gru)
decoder = Decoder_maker(tar_vocab_size=vocab_tar_size+1, embed_dim=n_embed, n_units=n_gru)

# %%
optimizer = tf.keras.optimizers.Adam()
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(reduction='none')

def loss_function(real, pred):
  loss_ = loss_object(real, pred)
  mask = tf.cast(tf.math.logical_not(tf.math.equal(real, 0)), dtype=loss_.dtype)
  loss_ *= mask
  return tf.reduce_mean(loss_)

# %%
checkpoint_dir = './training_checkpoints2'
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(optimizer=optimizer, encoder=encoder, decoder=decoder)

# %%
def train_step(inp, targ):
  loss = 0
  with tf.GradientTape() as tape: 
    enc_output, enc_state = encoder(inp)
    dec_state = enc_state 
    dec_input = tf.expand_dims(targ[:,0], axis=1)
    for t in range(1, targ.shape[1]):
      pred, dec_state, _ = decoder(dec_input, enc_output, dec_state)
      loss += loss_function(targ[:, t], pred)
      dec_input = tf.expand_dims(targ[:, t], 1)

  variables = encoder.trainable_variables + decoder.trainable_variables 
  gradients = tape.gradient(loss, variables)
  optimizer.apply_gradients(zip(gradients, variables)) 

  return (loss / int(targ.shape[1]))

# %%
import time
EPOCHS = 100

for epoch in range(EPOCHS):
  start = time.time()
  total_loss = 0

  for (batch, (inp, targ)) in enumerate(train):
    batch_loss = train_step(inp, targ)
    total_loss += batch_loss

    if batch % 10 == 0:
      print('Epoch {} Batch {} Loss {:.4f}'.format(epoch + 1, batch, batch_loss.numpy()))
  
  checkpoint.save(file_prefix = checkpoint_prefix)
  print('Epoch {} Loss {:.4f}'.format(epoch + 1, total_loss))
  print('Time taken for 1 epoch {} sec'.format(time.time() - start))

  enc_input = X_val
  dec_input = tf.zeros(shape=(len(X_val),1))
  enc_out, enc_state = encoder(enc_input)
  dec_state = enc_state

  pred = []

  for i in range(y_val.shape[1]-1):
    dec_out, dec_state, attention_w = decoder(dec_input, enc_out, dec_state)
    decoded_out = tf.expand_dims(tf.argmax(dec_out, axis=-1), axis=1)
    pred.append(tf.expand_dims(dec_out,axis=1)) 
    dec_input = decoded_out 

  pred = tf.concat(pred, axis=1).numpy()
  print("\n val loss :", loss_function(y_val[:,1:],pred),"\n")
# Out:
# Epoch 1 Batch 0 Loss 3.1797
# Epoch 1 Loss 21.9276
# Time taken for 1 epoch 2.1873700618743896 sec
#
#  val loss : tf.Tensor(4.0299044, shape=(), dtype=float32)
#
# Epoch 2 Batch 0 Loss 2.8797
# Epoch 2 Loss 19.5678
# Time taken for 1 epoch 0.6481108665466309 sec
#
#  val loss : tf.Tensor(3.8183992, shape=(), dtype=float32)
#
# Epoch 3 Batch 0 Loss 2.6701
# Epoch 3 Loss 18.4579
# Time taken for 1 epoch 0.6290912628173828 sec
#
#  val loss : tf.Tensor(3.8240035, shape=(), dtype=float32)
#
# Epoch 4 Batch 0 Loss 2.4998
# Epoch 4 Loss 17.8649
# Time taken for 1 epoch 0.6332724094390869 sec
#
#  val loss : tf.Tensor(3.8400233, shape=(), dtype=float32)
#
# Epoch 5 Batch 0 Loss 2.4902
# Epoch 5 Loss 17.0234
# Time taken for 1 epoch 0.641333818435669 sec
#
#  val loss : tf.Tensor(3.9425151, shape=(), dtype=float32)
#
# Epoch 6 Batch 0 Loss 2.3161
# Epoch 6 Loss 16.5858
# Time taken for 1 epoch 0.6108508110046387 sec
#
#  val loss : tf.Tensor(3.966123, shape=(), dtype=float32)
#
# Epoch 7 Batch 0 Loss 2.3471
# Epoch 7 Loss 15.7355
# Time taken for 1 epoch 0.628936767578125 sec
#
#  val loss : tf.Tensor(4.0470457, shape=(), dtype=float32)
#
# Epoch 8 Batch 0 Loss 2.1918
# Epoch 8 Loss 14.7688
# Time taken for 1 epoch 0.6085975170135498 sec
#
#  val loss : tf.Tensor(3.965974, shape=(), dtype=float32)
#
# Epoch 9 Batch 0 Loss 1.9671
# Epoch 9 Loss 13.8636
# Time taken for 1 epoch 0.6227285861968994 sec
#
#  val loss : tf.Tensor(3.903619, shape=(), dtype=float32)
#
# Epoch 10 Batch 0 Loss 1.9139
# Epoch 10 Loss 12.9614
# Time taken for 1 epoch 0.5959644317626953 sec
#
#  val loss : tf.Tensor(3.9661443, shape=(), dtype=float32)
#
# Epoch 11 Batch 0 Loss 1.8235
# Epoch 11 Loss 12.2618
# Time taken for 1 epoch 0.5971672534942627 sec
#
#  val loss : tf.Tensor(3.8636384, shape=(), dtype=float32)
#
# Epoch 12 Batch 0 Loss 1.7139
# Epoch 12 Loss 11.4530
# Time taken for 1 epoch 0.6218419075012207 sec
#
#  val loss : tf.Tensor(3.9276433, shape=(), dtype=float32)
#
# Epoch 13 Batch 0 Loss 1.6326
# Epoch 13 Loss 10.8990
# Time taken for 1 epoch 0.6239523887634277 sec
#
#  val loss : tf.Tensor(3.8896554, shape=(), dtype=float32)
#
# Epoch 14 Batch 0 Loss 1.4720
# Epoch 14 Loss 10.3814
# Time taken for 1 epoch 0.6228733062744141 sec
#
#  val loss : tf.Tensor(3.8048418, shape=(), dtype=float32)
#
# Epoch 15 Batch 0 Loss 1.4160
# Epoch 15 Loss 9.8544
# Time taken for 1 epoch 0.5985019207000732 sec
#
#  val loss : tf.Tensor(3.7782662, shape=(), dtype=float32)
#
# Epoch 16 Batch 0 Loss 1.3191
# Epoch 16 Loss 9.2211
# Time taken for 1 epoch 0.6043910980224609 sec
#
#  val loss : tf.Tensor(3.7420487, shape=(), dtype=float32)
#
# Epoch 17 Batch 0 Loss 1.2908
# Epoch 17 Loss 8.5959
# Time taken for 1 epoch 0.6451091766357422 sec
#
#  val loss : tf.Tensor(3.7465734, shape=(), dtype=float32)
#
# Epoch 18 Batch 0 Loss 1.1544
# Epoch 18 Loss 8.2463
# Time taken for 1 epoch 0.6021509170532227 sec
#
#  val loss : tf.Tensor(3.8013427, shape=(), dtype=float32)
#
# Epoch 19 Batch 0 Loss 1.1829
# Epoch 19 Loss 7.7642
# Time taken for 1 epoch 0.6062192916870117 sec
#
#  val loss : tf.Tensor(3.6921036, shape=(), dtype=float32)
#
# Epoch 20 Batch 0 Loss 1.1135
# Epoch 20 Loss 7.2711
# Time taken for 1 epoch 0.6208014488220215 sec
#
#  val loss : tf.Tensor(3.6471064, shape=(), dtype=float32)
#
# Epoch 21 Batch 0 Loss 0.9865
# Epoch 21 Loss 6.8292
# Time taken for 1 epoch 0.613835334777832 sec
#
#  val loss : tf.Tensor(3.5786905, shape=(), dtype=float32)
#
# Epoch 22 Batch 0 Loss 0.9243
# Epoch 22 Loss 6.3330
# Time taken for 1 epoch 0.6072595119476318 sec
#
#  val loss : tf.Tensor(3.557832, shape=(), dtype=float32)
#
# Epoch 23 Batch 0 Loss 0.8071
# Epoch 23 Loss 5.9387
# Time taken for 1 epoch 0.6048352718353271 sec
#
#  val loss : tf.Tensor(3.4958985, shape=(), dtype=float32)
#
# Epoch 24 Batch 0 Loss 0.8122
# Epoch 24 Loss 5.5849
# Time taken for 1 epoch 0.601107120513916 sec
#
#  val loss : tf.Tensor(3.4717562, shape=(), dtype=float32)
#
# Epoch 25 Batch 0 Loss 0.7260
# Epoch 25 Loss 5.1257
# Time taken for 1 epoch 0.6166877746582031 sec
#
#  val loss : tf.Tensor(3.478963, shape=(), dtype=float32)
#
# Epoch 26 Batch 0 Loss 0.6375
# Epoch 26 Loss 4.7927
# Time taken for 1 epoch 0.6149604320526123 sec
#
#  val loss : tf.Tensor(3.4505315, shape=(), dtype=float32)
#
# Epoch 27 Batch 0 Loss 0.6148
# Epoch 27 Loss 4.3561
# Time taken for 1 epoch 0.6161835193634033 sec
#
#  val loss : tf.Tensor(3.4927278, shape=(), dtype=float32)
#
# Epoch 28 Batch 0 Loss 0.5993
# Epoch 28 Loss 4.0707
# Time taken for 1 epoch 0.6025819778442383 sec
#
#  val loss : tf.Tensor(3.4655037, shape=(), dtype=float32)
#
# Epoch 29 Batch 0 Loss 0.5690
# Epoch 29 Loss 3.7023
# Time taken for 1 epoch 0.6057333946228027 sec
#
#  val loss : tf.Tensor(3.4288318, shape=(), dtype=float32)
#
# Epoch 30 Batch 0 Loss 0.5183
# Epoch 30 Loss 3.4063
# Time taken for 1 epoch 0.6206169128417969 sec
#
#  val loss : tf.Tensor(3.5121114, shape=(), dtype=float32)
#
# Epoch 31 Batch 0 Loss 0.4201
# Epoch 31 Loss 3.1327
# Time taken for 1 epoch 0.7460322380065918 sec
#
#  val loss : tf.Tensor(3.4280262, shape=(), dtype=float32)
#
# Epoch 32 Batch 0 Loss 0.4249
# Epoch 32 Loss 2.8327
# Time taken for 1 epoch 1.4156591892242432 sec
#
#  val loss : tf.Tensor(3.4322913, shape=(), dtype=float32)
#
# Epoch 33 Batch 0 Loss 0.3769
# Epoch 33 Loss 2.6311
# Time taken for 1 epoch 0.6389174461364746 sec
#
#  val loss : tf.Tensor(3.4309645, shape=(), dtype=float32)
#
# Epoch 34 Batch 0 Loss 0.3602
# Epoch 34 Loss 2.4570
# Time taken for 1 epoch 0.6162943840026855 sec
#
#  val loss : tf.Tensor(3.4243753, shape=(), dtype=float32)
#
# Epoch 35 Batch 0 Loss 0.3070
# Epoch 35 Loss 2.2335
# Time taken for 1 epoch 0.620415210723877 sec
#
#  val loss : tf.Tensor(3.3995678, shape=(), dtype=float32)
#
# Epoch 36 Batch 0 Loss 0.2680
# Epoch 36 Loss 2.0270
# Time taken for 1 epoch 0.6104662418365479 sec
#
#  val loss : tf.Tensor(3.4444466, shape=(), dtype=float32)
#
# Epoch 37 Batch 0 Loss 0.2707
# Epoch 37 Loss 1.8674
# Time taken for 1 epoch 0.6040835380554199 sec
#
#  val loss : tf.Tensor(3.4357288, shape=(), dtype=float32)
#
# Epoch 38 Batch 0 Loss 0.2541
# Epoch 38 Loss 1.7335
# Time taken for 1 epoch 0.6006910800933838 sec
#
#  val loss : tf.Tensor(3.3751566, shape=(), dtype=float32)
#
# Epoch 39 Batch 0 Loss 0.2232
# Epoch 39 Loss 1.6009
# Time taken for 1 epoch 0.609032154083252 sec
#
#  val loss : tf.Tensor(3.4547222, shape=(), dtype=float32)
#
# Epoch 40 Batch 0 Loss 0.2142
# Epoch 40 Loss 1.5065
# Time taken for 1 epoch 0.6051032543182373 sec
#
#  val loss : tf.Tensor(3.450573, shape=(), dtype=float32)
#
# Epoch 41 Batch 0 Loss 0.2022
# Epoch 41 Loss 1.3454
# Time taken for 1 epoch 0.6249091625213623 sec
#
#  val loss : tf.Tensor(3.420246, shape=(), dtype=float32)
#
# Epoch 42 Batch 0 Loss 0.1875
# Epoch 42 Loss 1.2740
# Time taken for 1 epoch 0.605388879776001 sec
#
#  val loss : tf.Tensor(3.429327, shape=(), dtype=float32)
#
# Epoch 43 Batch 0 Loss 0.1797
# Epoch 43 Loss 1.1800
# Time taken for 1 epoch 0.615206241607666 sec
#
#  val loss : tf.Tensor(3.4598267, shape=(), dtype=float32)
#
# Epoch 44 Batch 0 Loss 0.1348
# Epoch 44 Loss 1.0942
# Time taken for 1 epoch 0.6274025440216064 sec
#
#  val loss : tf.Tensor(3.4238732, shape=(), dtype=float32)
#
# Epoch 45 Batch 0 Loss 0.1324
# Epoch 45 Loss 0.9955
# Time taken for 1 epoch 0.611330509185791 sec
#
#  val loss : tf.Tensor(3.4891906, shape=(), dtype=float32)
#
# Epoch 46 Batch 0 Loss 0.1201
# Epoch 46 Loss 0.9127
# Time taken for 1 epoch 0.6851406097412109 sec
#
#  val loss : tf.Tensor(3.5049858, shape=(), dtype=float32)
#
# Epoch 47 Batch 0 Loss 0.1286
# Epoch 47 Loss 0.8559
# Time taken for 1 epoch 0.600304365158081 sec
#
#  val loss : tf.Tensor(3.4980445, shape=(), dtype=float32)
#
# Epoch 48 Batch 0 Loss 0.1157
# Epoch 48 Loss 0.8232
# Time taken for 1 epoch 0.6177890300750732 sec
#
#  val loss : tf.Tensor(3.496967, shape=(), dtype=float32)
#
# Epoch 49 Batch 0 Loss 0.1119
# Epoch 49 Loss 0.7585
# Time taken for 1 epoch 0.5947983264923096 sec
#
#  val loss : tf.Tensor(3.516794, shape=(), dtype=float32)
#
# Epoch 50 Batch 0 Loss 0.1127
# Epoch 50 Loss 0.7089
# Time taken for 1 epoch 0.6249113082885742 sec
#
#  val loss : tf.Tensor(3.4885347, shape=(), dtype=float32)
#
# Epoch 51 Batch 0 Loss 0.0941
# Epoch 51 Loss 0.6882
# Time taken for 1 epoch 0.6081206798553467 sec
#
#  val loss : tf.Tensor(3.4795704, shape=(), dtype=float32)
#
# Epoch 52 Batch 0 Loss 0.0930
# Epoch 52 Loss 0.6408
# Time taken for 1 epoch 0.6089284420013428 sec
#
#  val loss : tf.Tensor(3.5076122, shape=(), dtype=float32)
#
# Epoch 53 Batch 0 Loss 0.0768
# Epoch 53 Loss 0.5976
# Time taken for 1 epoch 0.595890998840332 sec
#
#  val loss : tf.Tensor(3.5681856, shape=(), dtype=float32)
#
# Epoch 54 Batch 0 Loss 0.0752
# Epoch 54 Loss 0.5884
# Time taken for 1 epoch 0.6031079292297363 sec
#
#  val loss : tf.Tensor(3.5596514, shape=(), dtype=float32)
#
# Epoch 55 Batch 0 Loss 0.0681
# Epoch 55 Loss 0.5524
# Time taken for 1 epoch 0.5921499729156494 sec
#
#  val loss : tf.Tensor(3.5294237, shape=(), dtype=float32)
#
# Epoch 56 Batch 0 Loss 0.0781
# Epoch 56 Loss 0.5277
# Time taken for 1 epoch 0.6092109680175781 sec
#
#  val loss : tf.Tensor(3.5387285, shape=(), dtype=float32)
#
# Epoch 57 Batch 0 Loss 0.0584
# Epoch 57 Loss 0.5701
# Time taken for 1 epoch 0.6187543869018555 sec
#
#  val loss : tf.Tensor(3.5607235, shape=(), dtype=float32)
#
# Epoch 58 Batch 0 Loss 0.0690
# Epoch 58 Loss 0.4866
# Time taken for 1 epoch 0.6202900409698486 sec
#
#  val loss : tf.Tensor(3.6044524, shape=(), dtype=float32)
#
# Epoch 59 Batch 0 Loss 0.0635
# Epoch 59 Loss 0.4955
# Time taken for 1 epoch 0.6132147312164307 sec
#
#  val loss : tf.Tensor(3.5954473, shape=(), dtype=float32)
#
# Epoch 60 Batch 0 Loss 0.0670
# Epoch 60 Loss 0.4433
# Time taken for 1 epoch 0.6047494411468506 sec
#
#  val loss : tf.Tensor(3.6225939, shape=(), dtype=float32)
#
# Epoch 61 Batch 0 Loss 0.0619
# Epoch 61 Loss 0.4336
# Time taken for 1 epoch 0.5991315841674805 sec
#
#  val loss : tf.Tensor(3.5983915, shape=(), dtype=float32)
#
# Epoch 62 Batch 0 Loss 0.0606
# Epoch 62 Loss 0.4261
# Time taken for 1 epoch 0.6266791820526123 sec
#
#  val loss : tf.Tensor(3.6146219, shape=(), dtype=float32)
#
# Epoch 63 Batch 0 Loss 0.0605
# Epoch 63 Loss 0.4228
# Time taken for 1 epoch 0.5983560085296631 sec
#
#  val loss : tf.Tensor(3.5805647, shape=(), dtype=float32)
#
# Epoch 64 Batch 0 Loss 0.0559
# Epoch 64 Loss 0.3899
# Time taken for 1 epoch 0.5963475704193115 sec
#
#  val loss : tf.Tensor(3.587165, shape=(), dtype=float32)
#
# Epoch 65 Batch 0 Loss 0.0605
# Epoch 65 Loss 0.3849
# Time taken for 1 epoch 0.6275060176849365 sec
#
#  val loss : tf.Tensor(3.6273851, shape=(), dtype=float32)
#
# Epoch 66 Batch 0 Loss 0.0385
# Epoch 66 Loss 0.3794
# Time taken for 1 epoch 0.6112015247344971 sec
#
#  val loss : tf.Tensor(3.6051435, shape=(), dtype=float32)
#
# Epoch 67 Batch 0 Loss 0.0495
# Epoch 67 Loss 0.3608
# Time taken for 1 epoch 0.602846622467041 sec
#
#  val loss : tf.Tensor(3.5978503, shape=(), dtype=float32)
#
# Epoch 68 Batch 0 Loss 0.0506
# Epoch 68 Loss 0.3623
# Time taken for 1 epoch 0.6066718101501465 sec
#
#  val loss : tf.Tensor(3.5982385, shape=(), dtype=float32)
#
# Epoch 69 Batch 0 Loss 0.0510
# Epoch 69 Loss 0.3630
# Time taken for 1 epoch 0.5977940559387207 sec
#
#  val loss : tf.Tensor(3.6470902, shape=(), dtype=float32)
#
# Epoch 70 Batch 0 Loss 0.0392
# Epoch 70 Loss 0.3353
# Time taken for 1 epoch 0.6074991226196289 sec
#
#  val loss : tf.Tensor(3.6516948, shape=(), dtype=float32)
#
# Epoch 71 Batch 0 Loss 0.0373
# Epoch 71 Loss 0.3385
# Time taken for 1 epoch 0.5986785888671875 sec
#
#  val loss : tf.Tensor(3.616978, shape=(), dtype=float32)
#
# Epoch 72 Batch 0 Loss 0.0469
# Epoch 72 Loss 0.3294
# Time taken for 1 epoch 0.592233419418335 sec
#
#  val loss : tf.Tensor(3.6486926, shape=(), dtype=float32)
#
# Epoch 73 Batch 0 Loss 0.0489
# Epoch 73 Loss 0.3295
# Time taken for 1 epoch 0.611588716506958 sec
#
#  val loss : tf.Tensor(3.6607194, shape=(), dtype=float32)
#
# Epoch 74 Batch 0 Loss 0.0453
# Epoch 74 Loss 0.3089
# Time taken for 1 epoch 0.617786169052124 sec
#
#  val loss : tf.Tensor(3.6544683, shape=(), dtype=float32)
#
# Epoch 75 Batch 0 Loss 0.0374
# Epoch 75 Loss 0.3159
# Time taken for 1 epoch 0.6071953773498535 sec
#
#  val loss : tf.Tensor(3.6871626, shape=(), dtype=float32)
#
# Epoch 76 Batch 0 Loss 0.0507
# Epoch 76 Loss 0.3092
# Time taken for 1 epoch 0.6058738231658936 sec
#
#  val loss : tf.Tensor(3.6638367, shape=(), dtype=float32)
#
# Epoch 77 Batch 0 Loss 0.0402
# Epoch 77 Loss 0.3065
# Time taken for 1 epoch 0.6084451675415039 sec
#
#  val loss : tf.Tensor(3.657009, shape=(), dtype=float32)
#
# Epoch 78 Batch 0 Loss 0.0450
# Epoch 78 Loss 0.2773
# Time taken for 1 epoch 0.6074068546295166 sec
#
#  val loss : tf.Tensor(3.6433082, shape=(), dtype=float32)
#
# Epoch 79 Batch 0 Loss 0.0289
# Epoch 79 Loss 0.2986
# Time taken for 1 epoch 0.5935192108154297 sec
#
#  val loss : tf.Tensor(3.6588411, shape=(), dtype=float32)
#
# Epoch 80 Batch 0 Loss 0.0468
# Epoch 80 Loss 0.2745
# Time taken for 1 epoch 0.6042890548706055 sec
#
#  val loss : tf.Tensor(3.6532385, shape=(), dtype=float32)
#
# Epoch 81 Batch 0 Loss 0.0480
# Epoch 81 Loss 0.3019
# Time taken for 1 epoch 0.6133921146392822 sec
#
#  val loss : tf.Tensor(3.675807, shape=(), dtype=float32)
#
# Epoch 82 Batch 0 Loss 0.0436
# Epoch 82 Loss 0.2998
# Time taken for 1 epoch 0.6071145534515381 sec
#
#  val loss : tf.Tensor(3.6868978, shape=(), dtype=float32)
#
# Epoch 83 Batch 0 Loss 0.0289
# Epoch 83 Loss 0.2941
# Time taken for 1 epoch 0.6063792705535889 sec
#
#  val loss : tf.Tensor(3.6844056, shape=(), dtype=float32)
#
# Epoch 84 Batch 0 Loss 0.0456
# Epoch 84 Loss 0.2877
# Time taken for 1 epoch 0.6929161548614502 sec
#
#  val loss : tf.Tensor(3.7111084, shape=(), dtype=float32)
#
# Epoch 85 Batch 0 Loss 0.0478
# Epoch 85 Loss 0.2805
# Time taken for 1 epoch 0.6097872257232666 sec
#
#  val loss : tf.Tensor(3.6839037, shape=(), dtype=float32)
#
# Epoch 86 Batch 0 Loss 0.0389
# Epoch 86 Loss 0.2649
# Time taken for 1 epoch 0.6014080047607422 sec
#
#  val loss : tf.Tensor(3.6755738, shape=(), dtype=float32)
#
# Epoch 87 Batch 0 Loss 0.0405
# Epoch 87 Loss 0.2631
# Time taken for 1 epoch 0.5872437953948975 sec
#
#  val loss : tf.Tensor(3.678361, shape=(), dtype=float32)
#
# Epoch 88 Batch 0 Loss 0.0302
# Epoch 88 Loss 0.2669
# Time taken for 1 epoch 0.6006412506103516 sec
#
#  val loss : tf.Tensor(3.700398, shape=(), dtype=float32)
#
# Epoch 89 Batch 0 Loss 0.0329
# Epoch 89 Loss 0.2512
# Time taken for 1 epoch 0.621286153793335 sec
#
#  val loss : tf.Tensor(3.681601, shape=(), dtype=float32)
#
# Epoch 90 Batch 0 Loss 0.0339
# Epoch 90 Loss 0.2635
# Time taken for 1 epoch 0.6097960472106934 sec
#
#  val loss : tf.Tensor(3.6864297, shape=(), dtype=float32)
#
# Epoch 91 Batch 0 Loss 0.0243
# Epoch 91 Loss 0.2484
# Time taken for 1 epoch 0.5934557914733887 sec
#
#  val loss : tf.Tensor(3.7336047, shape=(), dtype=float32)
#
# Epoch 92 Batch 0 Loss 0.0471
# Epoch 92 Loss 0.2434
# Time taken for 1 epoch 0.701972484588623 sec
#
#  val loss : tf.Tensor(3.7352364, shape=(), dtype=float32)
#
# Epoch 93 Batch 0 Loss 0.0347
# Epoch 93 Loss 0.2478
# Time taken for 1 epoch 0.6039872169494629 sec
#
#  val loss : tf.Tensor(3.7081747, shape=(), dtype=float32)
#
# Epoch 94 Batch 0 Loss 0.0291
# Epoch 94 Loss 0.2458
# Time taken for 1 epoch 0.5975377559661865 sec
#
#  val loss : tf.Tensor(3.7305408, shape=(), dtype=float32)
#
# Epoch 95 Batch 0 Loss 0.0369
# Epoch 95 Loss 0.2350
# Time taken for 1 epoch 0.5874061584472656 sec
#
#  val loss : tf.Tensor(3.7054574, shape=(), dtype=float32)
#
# Epoch 96 Batch 0 Loss 0.0300
# Epoch 96 Loss 0.2361
# Time taken for 1 epoch 0.6048600673675537 sec
#
#  val loss : tf.Tensor(3.7075903, shape=(), dtype=float32)
#
# Epoch 97 Batch 0 Loss 0.0494
# Epoch 97 Loss 0.2382
# Time taken for 1 epoch 0.6372954845428467 sec
#
#  val loss : tf.Tensor(3.76106, shape=(), dtype=float32)
#
# Epoch 98 Batch 0 Loss 0.0364
# Epoch 98 Loss 0.2356
# Time taken for 1 epoch 0.6082565784454346 sec
#
#  val loss : tf.Tensor(3.721299, shape=(), dtype=float32)
#
# Epoch 99 Batch 0 Loss 0.0307
# Epoch 99 Loss 0.2226
# Time taken for 1 epoch 0.6247541904449463 sec
#
#  val loss : tf.Tensor(3.7530413, shape=(), dtype=float32)
#
# Epoch 100 Batch 0 Loss 0.0282
# Epoch 100 Loss 0.2242
# Time taken for 1 epoch 0.6211662292480469 sec
#
#  val loss : tf.Tensor(3.7303438, shape=(), dtype=float32)

# %%
checkpoint.restore(tf.train.latest_checkpoint(checkpoint_dir))
encoder_latest=checkpoint.encoder
decoder_latest=checkpoint.decoder

# %%
enc_input = X_val
dec_input = tf.zeros(shape=(len(X_val),1))
enc_out, enc_state = encoder_latest(enc_input)
dec_state = enc_state

pred = []  

for i in range(y_val.shape[1]-1):
  dec_out, dec_state, attention_w = decoder_latest(dec_input, enc_out, dec_state)
  decoded_out = tf.expand_dims(tf.argmax(dec_out, axis=-1), axis=1)
  pred.append(decoded_out) 
  dec_input = decoded_out 

pred = tf.concat(pred, axis=-1).numpy()

pred_text = tokenizer_en.sequences_to_texts(pred)
y_val_text = tokenizer_en.sequences_to_texts(y_val[:,1:])
for i in range(10):
  print("pred:", pred_text[i])
  print("true:", y_val_text[i])
  print("\n")
# Out:
# pred: am cold i'm
# true: i'm right
#
#
# pred: take it hot
# true: take it
#
#
# pred: you up you
# true: move over
#
#
# pred: go ahead go
# true: go ahead
#
#
# pred: on it you
# true: here's 5
#
#
# pred: i give up
# true: i forgot
#
#
# pred: me go away
# true: go now
#
#
# pred: who knows she
# true: who spoke
#
#
# pred: i hope so
# true: i'm ok
#
#
# pred: a man it
# true: keep it
