# %% [markdown]
# ![crack](https://files.covidtracker.fr/covidtracker_vect.svg)
#
# # Covid Tracker 🦠
#
# Let's build our first dashboard using streamlit.
#
# For this first exercise, we got inspiration from the great [Covid Tracker app](https://covidtracker.fr/) built by [Guillaume Rozier](https://fr.wikipedia.org/wiki/Guillaume_Rozier).
#
# Your goal will be to build a dashboard that follow each covid wave throughout the year. To do so, we are going to use data from the European Centre for Disease Prevention and Control (ECDC).
#
# * [Download data here](https://www.ecdc.europa.eu/en/publications-data/data-daily-new-cases-covid-19-eueea-country)
#
#
# Here is an example of what you can create:
#
# * [Example dashboard](https://covid-tracker-fs-streamlit-app.herokuapp.com/)
#
# Ready? Here are a few step you need to follow:
#
# 1. First, you need to run this docker command:
#     * `docker run -it -v "$(pwd):/home/app" -p 4000:4000 jedha/streamlit-fs-image`
#
#     > You will be prompted to what is called a *container*. As for now, simply think of a container as a mini computer within your own computer. I know, it sounds weird but it is actually extremely handy when you start working on infrastructures. But we'll get to it later 😉
#     >
#     > You should see a beautiful unicorn appearing on your terminal:
#     > ```
#     >               ,,))))))));,
#     >             __)))))))))))))),
#     > \|/       -\(((((''''((((((((.
#     > -*-==//////((''  .     `)))))),
#     > /|\      ))| o    ;-.    '(((((                                  ,(,
#     >         ( `|    /  )    ;))))'                               ,_))^;(~
#     >            |   |   |   ,))((((_     _____------~~~-.        %,;(;(>';'~
#     >             o_);   ;    )))(((` ~---~  `::           \      %%~~)(v;(`('~
#     >                  ;    ''''````         `:       `:::|\,__,%%    );`'; ~
#     >                 |   _                )     /      `:|`----'     `-'
#     >           ______/\/~    |                 /        /
#     >         /~;;.____/;;'  /          ___--,-(   `;;;/
#     >        / //  _;______;'------~~~~~    /;;/\    /
#     >       //  | |                        / ;   \;;,\
#     >      (<_  | ;                      /',/-----'  _>
#     >       \_| ||_                     //~;~~~~~~~~~
#     >           `\_|                   (,~~  -Tua Xiong
#     >                                   \~\
#     >                                    ~~
#     >
#     >
#     >```
#
#
#
# 2. Use your streamlit's course and [documentation](https://docs.streamlit.io/) to build your dashboard
#
# 3. Once you are done, you can simply get out of this container by executing the following command:
#     * `exit`
#     * Finally run:
#         * `docker rm $(docker ps -aq); docker rmi $(docker image ls -q)`
