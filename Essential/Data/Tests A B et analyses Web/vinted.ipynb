# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'fichiers\vinted_website_optimization.csv')

# %%
sns.catplot(x="Feature_A", y="Feature_A", data=df, kind="bar")
