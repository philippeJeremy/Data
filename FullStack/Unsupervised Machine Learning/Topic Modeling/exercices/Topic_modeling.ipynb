# %%
import spacy
import pandas as pd
import en_core_web_sm
from pprint import pprint
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from spacy.lang.en.stop_words import STOP_WORDS
from sklearn.datasets import fetch_20newsgroups
news = fetch_20newsgroups()
nlp = en_core_web_sm.load()

# %%
pprint(news.DESCR)
# Out:
# ('.. _20newsgroups_dataset:\n'
#  '\n'
#  'The 20 newsgroups text dataset\n'
#  '------------------------------\n'
#  '\n'
#  'The 20 newsgroups dataset comprises around 18000 newsgroups posts on\n'
#  '20 topics split in two subsets: one for training (or development)\n'
#  'and the other one for testing (or for performance evaluation). The split\n'
#  'between the train and test set is based upon a messages posted before\n'
#  'and after a specific date.\n'
#  '\n'
#  'This module contains two loaders. The first one,\n'
#  ':func:`sklearn.datasets.fetch_20newsgroups`,\n'
#  'returns a list of the raw texts that can be fed to text feature\n'
#  'extractors such as '
#  ':class:`~sklearn.feature_extraction.text.CountVectorizer`\n'
#  'with custom parameters so as to extract feature vectors.\n'
#  'The second one, :func:`sklearn.datasets.fetch_20newsgroups_vectorized`,\n'
#  'returns ready-to-use features, i.e., it is not necessary to use a feature\n'
#  'extractor.\n'
#  '\n'
#  '**Data Set Characteristics:**\n'
#  '\n'
#  '    =================   ==========\n'
#  '    Classes                     20\n'
#  '    Samples total            18846\n'
#  '    Dimensionality               1\n'
#  '    Features                  text\n'
#  '    =================   ==========\n'
#  '\n'
#  'Usage\n'
#  '~~~~~\n'
#  '\n'
#  'The :func:`sklearn.datasets.fetch_20newsgroups` function is a data\n'
#  'fetching / caching functions that downloads the data archive from\n'
#  'the original `20 newsgroups website`_, extracts the archive contents\n'
#  'in the ``~/scikit_learn_data/20news_home`` folder and calls the\n'
#  ':func:`sklearn.datasets.load_files` on either the training or\n'
#  'testing set folder, or both of them::\n'
#  '\n'
#  '  >>> from sklearn.datasets import fetch_20newsgroups\n'
#  "  >>> newsgroups_train = fetch_20newsgroups(subset='train')\n"
#  '\n'
#  '  >>> from pprint import pprint\n'
#  '  >>> pprint(list(newsgroups_train.target_names))\n'
#  "  ['alt.atheism',\n"
#  "   'comp.graphics',\n"
#  "   'comp.os.ms-windows.misc',\n"
#  "   'comp.sys.ibm.pc.hardware',\n"
#  "   'comp.sys.mac.hardware',\n"
#  "   'comp.windows.x',\n"
#  "   'misc.forsale',\n"
#  "   'rec.autos',\n"
#  "   'rec.motorcycles',\n"
#  "   'rec.sport.baseball',\n"
#  "   'rec.sport.hockey',\n"
#  "   'sci.crypt',\n"
#  "   'sci.electronics',\n"
#  "   'sci.med',\n"
#  "   'sci.space',\n"
#  "   'soc.religion.christian',\n"
#  "   'talk.politics.guns',\n"
#  "   'talk.politics.mideast',\n"
#  "   'talk.politics.misc',\n"
#  "   'talk.religion.misc']\n"
#  '\n'
#  'The real data lies in the ``filenames`` and ``target`` attributes. The '
#  'target\n'
#  'attribute is the integer index of the category::\n'
#  '\n'
#  '  >>> newsgroups_train.filenames.shape\n'
#  '  (11314,)\n'
#  '  >>> newsgroups_train.target.shape\n'
#  '  (11314,)\n'
#  '  >>> newsgroups_train.target[:10]\n'
#  '  array([ 7,  4,  4,  1, 14, 16, 13,  3,  2,  4])\n'
#  '\n'
#  'It is possible to load only a sub-selection of the categories by passing '
#  'the\n'
#  'list of the categories to load to the\n'
#  ':func:`sklearn.datasets.fetch_20newsgroups` function::\n'
#  '\n'
#  "  >>> cats = ['alt.atheism', 'sci.space']\n"
#  "  >>> newsgroups_train = fetch_20newsgroups(subset='train', "
#  'categories=cats)\n'
#  '\n'
#  '  >>> list(newsgroups_train.target_names)\n'
#  "  ['alt.atheism', 'sci.space']\n"
#  '  >>> newsgroups_train.filenames.shape\n'
#  '  (1073,)\n'
#  '  >>> newsgroups_train.target.shape\n'
#  '  (1073,)\n'
#  '  >>> newsgroups_train.target[:10]\n'
#  '  array([0, 1, 1, 1, 0, 1, 1, 0, 0, 0])\n'
#  '\n'
#  'Converting text to vectors\n'
#  '~~~~~~~~~~~~~~~~~~~~~~~~~~\n'
#  '\n'
#  'In order to feed predictive or clustering models with the text data,\n'
#  'one first need to turn the text into vectors of numerical values suitable\n'
#  'for statistical analysis. This can be achieved with the utilities of the\n'
#  '``sklearn.feature_extraction.text`` as demonstrated in the following\n'
#  'example that extract `TF-IDF`_ vectors of unigram tokens\n'
#  'from a subset of 20news::\n'
#  '\n'
#  '  >>> from sklearn.feature_extraction.text import TfidfVectorizer\n'
#  "  >>> categories = ['alt.atheism', 'talk.religion.misc',\n"
#  "  ...               'comp.graphics', 'sci.space']\n"
#  "  >>> newsgroups_train = fetch_20newsgroups(subset='train',\n"
#  '  ...                                       categories=categories)\n'
#  '  >>> vectorizer = TfidfVectorizer()\n'
#  '  >>> vectors = vectorizer.fit_transform(newsgroups_train.data)\n'
#  '  >>> vectors.shape\n'
#  '  (2034, 34118)\n'
#  '\n'
#  'The extracted TF-IDF vectors are very sparse, with an average of 159 '
#  'non-zero\n'
#  'components by sample in a more than 30000-dimensional space\n'
#  '(less than .5% non-zero features)::\n'
#  '\n'
#  '  >>> vectors.nnz / float(vectors.shape[0])\n'
#  '  159.01327...\n'
#  '\n'
#  ':func:`sklearn.datasets.fetch_20newsgroups_vectorized` is a function which\n'
#  'returns ready-to-use token counts features instead of file names.\n'
#  '\n'
#  '.. _`20 newsgroups website`: '
#  'http://people.csail.mit.edu/jrennie/20Newsgroups/\n'
#  '.. _`TF-IDF`: https://en.wikipedia.org/wiki/Tf-idf\n'
#  '\n'
#  '\n'
#  'Filtering text for more realistic training\n'
#  '~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~\n'
#  '\n'
#  'It is easy for a classifier to overfit on particular things that appear in '
#  'the\n'
#  '20 Newsgroups data, such as newsgroup headers. Many classifiers achieve '
#  'very\n'
#  'high F-scores, but their results would not generalize to other documents '
#  'that\n'
#  "aren't from this window of time.\n"
#  '\n'
#  "For example, let's look at the results of a multinomial Naive Bayes "
#  'classifier,\n'
#  'which is fast to train and achieves a decent F-score::\n'
#  '\n'
#  '  >>> from sklearn.naive_bayes import MultinomialNB\n'
#  '  >>> from sklearn import metrics\n'
#  "  >>> newsgroups_test = fetch_20newsgroups(subset='test',\n"
#  '  ...                                      categories=categories)\n'
#  '  >>> vectors_test = vectorizer.transform(newsgroups_test.data)\n'
#  '  >>> clf = MultinomialNB(alpha=.01)\n'
#  '  >>> clf.fit(vectors, newsgroups_train.target)\n'
#  '  MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)\n'
#  '\n'
#  '  >>> pred = clf.predict(vectors_test)\n'
#  "  >>> metrics.f1_score(newsgroups_test.target, pred, average='macro')\n"
#  '  0.88213...\n'
#  '\n'
#  '(The example '
#  ':ref:`sphx_glr_auto_examples_text_plot_document_classification_20newsgroups.py` '
#  'shuffles\n'
#  'the training and test data, instead of segmenting by time, and in that case\n'
#  'multinomial Naive Bayes gets a much higher F-score of 0.88. Are you '
#  'suspicious\n'
#  "yet of what's going on inside this classifier?)\n"
#  '\n'
#  "Let's take a look at what the most informative features are:\n"
#  '\n'
#  '  >>> import numpy as np\n'
#  '  >>> def show_top10(classifier, vectorizer, categories):\n'
#  '  ...     feature_names = vectorizer.get_feature_names_out()\n'
#  '  ...     for i, category in enumerate(categories):\n'
#  '  ...         top10 = np.argsort(classifier.coef_[i])[-10:]\n'
#  '  ...         print("%s: %s" % (category, " ".join(feature_names[top10])))\n'
#  '  ...\n'
#  '  >>> show_top10(clf, vectorizer, newsgroups_train.target_names)\n'
#  '  alt.atheism: edu it and in you that is of to the\n'
#  '  comp.graphics: edu in graphics it is for and of to the\n'
#  '  sci.space: edu it that is in and space to of the\n'
#  '  talk.religion.misc: not it you in is that and to of the\n'
#  '\n'
#  '\n'
#  'You can now see many things that these features have overfit to:\n'
#  '\n'
#  '- Almost every group is distinguished by whether headers such as\n'
#  '  ``NNTP-Posting-Host:`` and ``Distribution:`` appear more or less often.\n'
#  '- Another significant feature involves whether the sender is affiliated '
#  'with\n'
#  '  a university, as indicated either by their headers or their signature.\n'
#  '- The word "article" is a significant feature, based on how often people '
#  'quote\n'
#  '  previous posts like this: "In article [article ID], [name] <[e-mail '
#  'address]>\n'
#  '  wrote:"\n'
#  '- Other features match the names and e-mail addresses of particular people '
#  'who\n'
#  '  were posting at the time.\n'
#  '\n'
#  'With such an abundance of clues that distinguish newsgroups, the '
#  'classifiers\n'
#  'barely have to identify topics from text at all, and they all perform at '
#  'the\n'
#  'same high level.\n'
#  '\n'
#  'For this reason, the functions that load 20 Newsgroups data provide a\n'
#  'parameter called **remove**, telling it what kinds of information to strip '
#  'out\n'
#  'of each file. **remove** should be a tuple containing any subset of\n'
#  "``('headers', 'footers', 'quotes')``, telling it to remove headers, "
#  'signature\n'
#  'blocks, and quotation blocks respectively.\n'
#  '\n'
#  "  >>> newsgroups_test = fetch_20newsgroups(subset='test',\n"
#  "  ...                                      remove=('headers', 'footers', "
#  "'quotes'),\n"
#  '  ...                                      categories=categories)\n'
#  '  >>> vectors_test = vectorizer.transform(newsgroups_test.data)\n'
#  '  >>> pred = clf.predict(vectors_test)\n'
#  "  >>> metrics.f1_score(pred, newsgroups_test.target, average='macro')\n"
#  '  0.77310...\n'
#  '\n'
#  'This classifier lost over a lot of its F-score, just because we removed\n'
#  'metadata that has little to do with topic classification.\n'
#  'It loses even more if we also strip this metadata from the training data:\n'
#  '\n'
#  "  >>> newsgroups_train = fetch_20newsgroups(subset='train',\n"
#  "  ...                                       remove=('headers', 'footers', "
#  "'quotes'),\n"
#  '  ...                                       categories=categories)\n'
#  '  >>> vectors = vectorizer.fit_transform(newsgroups_train.data)\n'
#  '  >>> clf = MultinomialNB(alpha=.01)\n'
#  '  >>> clf.fit(vectors, newsgroups_train.target)\n'
#  '  MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)\n'
#  '\n'
#  '  >>> vectors_test = vectorizer.transform(newsgroups_test.data)\n'
#  '  >>> pred = clf.predict(vectors_test)\n'
#  "  >>> metrics.f1_score(newsgroups_test.target, pred, average='macro')\n"
#  '  0.76995...\n'
#  '\n'
#  'Some other classifiers cope better with this harder version of the task. '
#  'Try\n'
#  'running '
#  ':ref:`sphx_glr_auto_examples_model_selection_grid_search_text_feature_extraction.py` '
#  'with and without\n'
#  'the ``--filter`` option to compare the results.\n'
#  '\n'
#  '.. topic:: Data Considerations\n'
#  '\n'
#  '  The Cleveland Indians is a major league baseball team based in Cleveland,\n'
#  '  Ohio, USA. In December 2020, it was reported that "After several months '
#  'of\n'
#  '  discussion sparked by the death of George Floyd and a national reckoning '
#  'over\n'
#  '  race and colonialism, the Cleveland Indians have decided to change their\n'
#  '  name." Team owner Paul Dolan "did make it clear that the team will not '
#  'make\n'
#  '  its informal nickname -- the Tribe -- its new team name." "It\'s not going '
#  'to\n'
#  '  be a half-step away from the Indians," Dolan said."We will not have a '
#  'Native\n'
#  '  American-themed name."\n'
#  '\n'
#  '  https://www.mlb.com/news/cleveland-indians-team-name-change\n'
#  '\n'
#  '.. topic:: Recommendation\n'
#  '\n'
#  '  - When evaluating text classifiers on the 20 Newsgroups data, you\n'
#  '    should strip newsgroup-related metadata. In scikit-learn, you can do '
#  'this\n'
#  "    by setting ``remove=('headers', 'footers', 'quotes')``. The F-score will "
#  'be\n'
#  '    lower because it is more realistic.\n'
#  '  - This text dataset contains data which may be inappropriate for certain '
#  'NLP\n'
#  '    applications. An example is listed in the "Data Considerations" section\n'
#  '    above. The challenge with using current text datasets in NLP for tasks '
#  'such\n'
#  '    as sentence completion, clustering, and other applications is that text\n'
#  '    that is culturally biased and inflammatory will propagate biases. This\n'
#  '    should be taken into consideration when using the dataset, reviewing '
#  'the\n'
#  '    output, and the bias should be documented.\n'
#  '\n'
#  '.. topic:: Examples\n'
#  '\n'
#  '   * '
#  ':ref:`sphx_glr_auto_examples_model_selection_grid_search_text_feature_extraction.py`\n'
#  '\n'
#  '   * '
#  ':ref:`sphx_glr_auto_examples_text_plot_document_classification_20newsgroups.py`\n')

# %%
df = pd.DataFrame(news.data, columns=["texte"])

# %%
df["cible"] = news.target

# %%
df_sample = df.sample(n=5000)

# %%
df_sample
# Out:
#                                                   texte  cible
# 8518  From: ifaz706@utxvms.cc.utexas.edu (Noam Tract...     17
# 7887  From: mcovingt@aisun3.ai.uga.edu (Michael Covi...     15
# 3744  From: estasic@ic.sunysb.edu (Edward Stasic)\nS...      3
# 2913  From: hasan@McRCIM.McGill.EDU \nSubject: Re: N...     17
# 458   From: jodfishe@silver.ucs.indiana.edu (joseph ...     15
# ...                                                 ...    ...
# 8736  Subject: Re: Shaft-drives and Wheelies\nFrom: ...      8
# 6173  From: mcelwre@cnsvax.uwec.edu\nSubject: THE DI...     19
# 9076  From: healta@saturn.wwc.edu (Tammy R Healy)\nS...      0
# 4114  From: Rick Miller - former spook <rick@ee.uwm....     11
# 915   From: tcmay@netcom.com (Timothy C. May)\nSubje...     11
#
# [5000 rows x 2 columns]

# %%
df_sample["text_clean"] = df_sample["texte"].str.replace(r"[^A-Za-z0-9 ]+", " ")
df_sample["text_clean"] = df_sample["text_clean"].str.split("Subject").str[1]
df_sample["text_clean"] = df_sample["text_clean"].str.lower()
# Out:
# C:\Users\jerem\AppData\Local\Temp\ipykernel_16176\674135871.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_sample["text_clean"] = df_sample["texte"].str.replace(r"[^A-Za-z0-9 ]+", " ")

# %%
def process_text(x):
    spacied = nlp(x)
    new_sentence = []
    for token in spacied:
        if token.lemma_.lower() not in STOP_WORDS:
            new_sentence.append(token.lemma_.lower())
    return  " ".join(new_sentence)        

df_sample["processed_documents"] = df_sample['text_clean'].apply(process_text)

# %%
df_sample
# Out:
#                                                   texte  cible  \
# 8518  From: ifaz706@utxvms.cc.utexas.edu (Noam Tract...     17
# 7887  From: mcovingt@aisun3.ai.uga.edu (Michael Covi...     15
# 3744  From: estasic@ic.sunysb.edu (Edward Stasic)\nS...      3
# 2913  From: hasan@McRCIM.McGill.EDU \nSubject: Re: N...     17
# 458   From: jodfishe@silver.ucs.indiana.edu (joseph ...     15
# ...                                                 ...    ...
# 8736  Subject: Re: Shaft-drives and Wheelies\nFrom: ...      8
# 6173  From: mcelwre@cnsvax.uwec.edu\nSubject: THE DI...     19
# 9076  From: healta@saturn.wwc.edu (Tammy R Healy)\nS...      0
# 4114  From: Rick Miller - former spook <rick@ee.uwm....     11
# 915   From: tcmay@netcom.com (Timothy C. May)\nSubje...     11
#
#                                              text_clean  \
# 8518    go hizbollah ii lines  28 nntp posting host ...
# 7887    re  did he really rise organization  ai prog...
# 3744    re  ide vs scsi  here we go again organizati...
# 2913    re  no land for peace   no negotiatians orig...
# 458     re  eternity of hell  was re  hell organizat...
# ...                                                 ...
# 8736    re  shaft drives and wheelies from  stafford...
# 6173    the divine masters organization  university ...
# 9076    getting to the point lines  12 organization ...
# 4114    alternate  legal  wiretaps organization  jus...
# 915     re  once tapped  your code is no good any mo...
#
#                                     processed_documents
# 8518     hizbollah ii line   28 nntp post host   pur...
# 7887       rise organization   ai programs   univers...
# 3744       ide vs scsi   organization   state univer...
# 2913       land peace    negotiatians originator   h...
# 458        eternity hell     hell organization   ind...
# ...                                                 ...
# 8736       shaft drive wheelie   stafford vax2 winon...
# 6173     divine masters organization   university wi...
# 9076     point line   12 organization   walla walla ...
# 4114     alternate   legal   wiretaps organization  ...
# 915        tap   code good organization   netcom lin...
#
# [5000 rows x 4 columns]

# %%
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(df_sample['processed_documents'])

# %%
vectorizer.vocabulary_
# Out:
# {'hizbollah': 31972,
#  'ii': 33205,
#  'line': 38412,
#  '28': 5582,
#  'nntp': 44408,
#  'post': 48303,
#  'host': 32325,
#  'purple': 49319,
#  'cc': 19019,
#  'utexas': 61036,
#  'edu': 25361,
#  'organization': 45815,
#  'university': 60491,
#  'texas': 58119,
#  'austin': 14885,
#  'israel': 34677,
#  'thursday': 58461,
#  'april': 14109,
#  '22': 4896,
#  '1993': 3659,
#  'today': 58739,
#  'ha': 30936,
#  'aretz': 14244,
#  'report': 51239,
#  'woman': 63541,
#  'injure': 33983,
#  'katyusha': 36240,
#  'rocket': 52092,
#  'fall': 27270,
#  'center': 19172,
#  'community': 20636,
#  'dozen': 24518,
#  'fire': 27897,
#  'galilee': 29199,
#  'northern': 44571,
#  'yesterday': 64943,
#  'terrorist': 58064,
#  'hizbullah': 31974,
#  'article': 14405,
#  '1993apr14': 3677,
#  '125813': 2119,
#  '21737': 4861,
#  'ncsu': 43724,
#  'hernlem': 31686,
#  'chess': 19503,
#  'brad': 17163,
#  'write': 63729,
#  'congratulation': 20955,
#  'brave': 17215,
#  'man': 39999,
#  'lebanese': 37906,
#  'resistance': 51355,
#  'israeli': 34678,
#  'son': 55239,
#  'place': 47812,
#  'grave': 30342,
#  'underline': 60277,
#  'moral': 42377,
#  'bankruptcy': 15536,
#  'occupation': 45208,
#  'draw': 24575,
#  'attention': 14774,
#  'government': 30183,
#  'policy': 48109,
#  'reckless': 50701,
#  'disregard': 24033,
#  'civilian': 19918,
#  'life': 38312,
#  'apparently': 14009,
#  'encourage': 25905,
#  'cheer': 19450,
#  'good': 30105,
#  'job': 35513,
#  'forget': 28365,
#  'tell': 57934,
#  'ask': 14495,
#  'daughter': 22674,
#  'paraphrase': 46595,
#  'bit': 16512,
#  'justify': 35874,
#  'holding': 32121,
#  'security': 53615,
#  'zone': 65642,
#  'noam': 44417,
#  'rise': 51773,
#  'ai': 12954,
#  'programs': 48877,
#  'georgia': 29555,
#  'athens': 14702,
#  '14': 2389,
#  'historic': 31941,
#  'fact': 27197,
#  'think': 58324,
#  'important': 33494,
#  'jesus': 35257,
#  'didn': 23653,
#  'dead': 22820,
#  'equally': 26226,
#  'impressive': 33516,
#  'order': 45788,
#  'create': 21692,
#  'observed': 45164,
#  'impact': 33429,
#  'display': 24012,
#  'body': 16860,
#  'jewish': 35269,
#  'roman': 52171,
#  'authority': 14908,
#  'gain': 29176,
#  'lot': 38870,
#  'discredit': 23910,
#  'christian': 19673,
#  'michael': 41374,
#  'covington': 21566,
#  'internet': 34266,
#  'mcovingt': 40704,
#  'uga': 59924,
#  'artificial': 14409,
#  'intelligence': 34174,
#  'program': 48867,
#  'phone': 47482,
#  '706': 9502,
#  '542': 8097,
#  '0358': 609,
#  'fax': 27420,
#  '0349': 606,
#  '30602': 6246,
#  '7415': 9819,
#  'amateur': 13436,
#  'radio': 50205,
#  'n4tmi': 43379,
#  'ide': 33072,
#  'vs': 62223,
#  'scsi': 53457,
#  'state': 56062,
#  'new': 44002,
#  'york': 65073,
#  'stony': 56320,
#  'brook': 17390,
#  '13': 2198,
#  'engws1': 26002,
#  'ic': 32990,
#  'sunysb': 56861,
#  '1993apr16': 3679,
#  '205724': 4672,
#  '26258': 5448,
#  'mnemosyne': 42052,
#  'cs': 21928,
#  'du': 24768,
#  'smace': 54920,
#  'nyx': 44950,
#  'scott': 53383,
#  'mace': 39671,
#  'don': 24386,
#  'belive': 16026,
#  'busmastering': 17741,
#  'vlbus': 62035,
#  'pick': 47580,
#  'issue': 34704,
#  'pc': 46875,
#  'week': 62889,
#  'whihc': 63082,
#  'test': 58082,
#  'eisa': 25526,
#  'isa': 34596,
#  'card': 18717,
#  'recall': 50665,
#  'message': 41105,
#  'relate': 51018,
#  'provoke': 49070,
#  'argument': 14264,
#  'straight': 56357,
#  'dope': 24425,
#  'probably': 48786,
#  'definitive': 23050,
#  'answer': 13822,
#  'want': 62663,
#  'ed': 25299,
#  'stasic': 56056,
#  'estasic': 26446,
#  'land': 37590,
#  'peace': 46943,
#  'negotiatians': 43822,
#  'originator': 45852,
#  'hasan': 31288,
#  'haley': 31045,
#  'mcrcim': 40713,
#  'mcgill': 40637,
#  'research': 51316,
#  'centre': 19185,
#  'intelligent': 34175,
#  'machine': 39683,
#  '45': 7395,
#  '1993apr5': 3695,
#  '175047': 3184,
#  '17368': 3150,
#  'unocal': 60558,
#  'com': 20517,
#  'stssdxb': 56486,
#  'st': 55899,
#  'dorin': 24434,
#  'baru': 15640,
#  'alan': 13132,
#  'stein': 56158,
#  'talk': 57576,
#  'rabin': 50164,
#  'clearly': 20088,
#  'indicate': 33735,
#  'interest': 34223,
#  'territorial': 58057,
#  'compromise': 20755,
#  'leave': 37903,
#  'vast': 61445,
#  'majority': 39914,
#  'arabs': 14167,
#  'judea': 35775,
#  'samaria': 52911,
#  'gaza': 29366,
#  'outside': 46083,
#  'control': 21211,
#  'interrupting': 34293,
#  'comment': 20584,
#  'early': 25144,
#  '1980': 3636,
#  'israelis': 34679,
#  'willing': 63243,
#  'adminstration': 12606,
#  'rule': 52508,
#  'occupy': 45211,
#  'terretorie': 58049,
#  'palestineans': 46471,
#  'refuse': 50901,
#  'settlement': 53881,
#  'deny': 23259,
#  'right': 51705,
#  'self': 53691,
#  'determination': 23447,
#  'period': 47145,
#  'know': 36944,
#  'point': 48072,
#  'bad': 15395,
#  'idea': 33073,
#  'voice': 62106,
#  'negotiation': 43824,
#  'negociation': 43818,
#  'opinion': 45675,
#  'ok': 45417,
#  'donot': 24408,
#  'guess': 30655,
#  'arabian': 14165,
#  'palestinean': 46470,
#  'current': 22133,
#  'process': 48811,
#  'se': 53522,
#  'found': 28442,
#  'prediction': 48539,
#  'inch': 33611,
#  'west': 62968,
#  'bank': 15531,
#  'golan': 30054,
#  'height': 31520,
#  '18': 3262,
#  'month': 42328,
#  'madrid': 39777,
#  'washington': 62716,
#  'prove': 49052,
#  'jump': 35828,
#  'blame': 16612,
#  'result': 51435,
#  'stall': 55963,
#  'loose': 38814,
#  'arab': 14163,
#  'feel': 27526,
#  'legitimize': 37979,
#  'status': 56093,
#  'quo': 49966,
#  'open': 45641,
#  'door': 24420,
#  'market': 40190,
#  'trade': 59006,
#  'orange': 45760,
#  'simply': 54518,
#  'unacceptable': 60126,
#  'revoke': 51533,
#  'eternity': 26481,
#  'hell': 31562,
#  'indiana': 33732,
#  '98': 11557,
#  'apr': 14098,
#  '00': 0,
#  '09': 939,
#  '04': 636,
#  '28448': 5611,
#  'athos': 14711,
#  'rutger': 52562,
#  'dlecoint': 24202,
#  'garnet': 29291,
#  'acns': 12427,
#  'fsu': 28748,
#  'darius': 22598,
#  'lecointe': 37916,
#  'insert': 34058,
#  'deletion': 23131,
#  'unnecessary': 60553,
#  'quote': 49971,
#  'notion': 44620,
#  'god': 30024,
#  'sort': 55293,
#  'pleasure': 47893,
#  'punish': 49273,
#  'people': 47083,
#  'purpose': 49323,
#  'destroy': 23418,
#  'devil': 23501,
#  'angel': 13711,
#  'mercy': 41060,
#  'compassion': 20667,
#  'ex': 26710,
#  '33': 6402,
#  '19': 3444,
#  'enjoy': 26017,
#  'send': 53743,
#  'seek': 53635,
#  'save': 53084,
#  'lose': 38860,
#  'luke': 39098,
#  '10': 1291,
#  'poster': 48311,
#  'try': 59370,
#  'support': 56933,
#  'eternal': 26478,
#  'theory': 58251,
#  'remember': 51110,
#  'bible': 16325,
#  'teach': 57797,
#  'reserve': 51334,
#  'day': 22719,
#  'judgement': 35781,
#  'soon': 55252,
#  'come': 20541,
#  'let': 38075,
#  'suggest': 56730,
#  'maybe': 40468,
#  'believe': 16023,
#  'provide': 49058,
#  'biblical': 16327,
#  'evidence': 26652,
#  'find': 27857,
#  'stay': 56104,
#  'away': 15074,
#  'human': 32573,
#  'account': 12338,
#  'reference': 50859,
#  'peter': 47276,
#  'ff': 27662,
#  'ungodly': 60406,
#  'matthew': 40395,
#  '25': 5321,
#  '31': 6272,
#  '46': 7435,
#  'clear': 20079,
#  'righteous': 51706,
#  'eye': 26998,
#  'thessalonian': 58287,
#  'cause': 18925,
#  'trouble': 59320,
#  'disciple': 23877,
#  'everlasting': 26635,
#  'destruction': 23422,
#  'shut': 54334,
#  'presence': 48617,
#  'lord': 38830,
#  'thessalonians': 58288,
#  '12': 1990,
#  'love': 38899,
#  'truth': 59363,
#  'condemn': 20864,
#  'revelation': 51505,
#  '21': 4736,
#  'difference': 23684,
#  'overcome': 46124,
#  'list': 38488,
#  'verse': 61703,
#  'fiery': 27769,
#  'lake': 37551,
#  'burn': 17699,
#  'sulfur': 56758,
#  'indication': 33736,
#  'follow': 28258,
#  'beast': 15878,
#  'torment': 58864,
#  'rest': 51408,
#  'night': 44220,
#  'psalm': 49110,
#  '17': 3073,
#  'wicked': 63165,
#  'return': 51486,
#  'nation': 43605,
#  'sufficient': 56719,
#  'joe': 35521,
#  'fisher': 27929,
#  'following': 28261,
#  'play': 47868,
#  'advocate': 12695,
#  'position': 48280,
#  'concern': 20828,
#  'understand': 60298,
#  'possible': 48300,
#  'passage': 46714,
#  'different': 23686,
#  'way': 62778,
#  'rev': 51498,
#  'use': 60944,
#  'term': 58025,
#  'second': 53593,
#  'death': 22845,
#  'obvious': 45181,
#  'understanding': 60301,
#  'final': 27843,
#  'extinction': 26953,
#  'problem': 48794,
#  'speak': 55445,
#  'punishment': 49277,
#  'convince': 21261,
#  'view': 61848,
#  'help': 31588,
#  'wide': 63168,
#  'variety': 61425,
#  'image': 33327,
#  'tom': 58772,
#  'albrecht': 13162,
#  'primary': 48717,
#  'detail': 23431,
#  'thing': 58322,
#  'interesting': 34226,
#  '20': 4527,
#  '35': 6570,
#  'imply': 33489,
#  'damn': 22532,
#  'resurrect': 51444,
#  'presumably': 48650,
#  'yes': 64937,
#  'aware': 15072,
#  'non': 44469,
#  'literal': 38510,
#  'hold': 32118,
#  'isn': 34654,
#  'punishement': 49275,
#  'cursed': 22139,
#  'prepare': 48596,
#  'doesn': 24331,
#  'mean': 40810,
#  'flame': 28018,
#  'forever': 28356,
#  'particularly': 46682,
#  'having': 31339,
#  'false': 27280,
#  'prophet': 48963,
#  'throw': 58422,
#  'refer': 50854,
#  'sound': 55305,
#  'like': 38348,
#  'effect': 25414,
#  'supernatural': 56900,
#  'entity': 26091,
#  'similarly': 54497,
#  'everlaste': 26634,
#  'necessarily': 43771,
#  'contrast': 21192,
#  'kind': 36683,
#  'occur': 45212,
#  'explicitly': 26894,
#  'suffer': 56711,
#  'smoke': 54969,
#  'respite': 51391,
#  'relevant': 51049,
#  'clh': 20117,
#  'ussr': 61001,
#  'reach': 50568,
#  'moon': 42351,
#  'reply': 51233,
#  'gary': 29304,
#  'ke4zv': 36335,
#  'uucp': 61082,
#  'coffman': 20379,
#  'destructive': 23423,
#  'testing': 58093,
#  'system': 57318,
#  '63': 8794,
#  '93110': 11262,
#  '031905saundrsg': 587,
#  'qucdn': 49892,
#  'queensu': 49900,
#  'graydon': 30354,
#  'saundrsg': 53074,
#  '1993apr18': 3681,
#  '091051': 949,
#  '14496': 2516,
#  'conceivable': 20811,
#  'luna': 39117,
#  'military': 41535,
#  'commercial': 20591,
#  'likely': 38350,
#  'scientific': 53330,
#  'year': 64910,
#  'lunar': 39119,
#  'basis': 15682,
#  'predicate': 48534,
#  'funding': 28850,
#  'level': 38104,
#  'little': 38525,
#  'antarctic': 13827,
#  '200': 4528,
#  'person': 47226,
#  'base': 15651,
#  '30': 6197,
#  'million': 41560,
#  'grad': 30244,
#  'student': 56501,
#  'able': 12169,
#  'run': 52520,
#  'hardly': 31214,
#  'couple': 21519,
#  'century': 19195,
#  'significant': 54445,
#  'commerical': 20594,
#  'activity': 12476,
#  'wishful': 63383,
#  'thinking': 58327,
#  'site': 54604,
#  'major': 39913,
#  'far': 27324,
#  'material': 40348,
#  'cheap': 19426,
#  'earth': 25153,
#  'asteroid': 14604,
#  'comet': 20548,
#  'aside': 14491,
#  'semi': 53718,
#  'mythic': 43274,
#  'he3': 31423,
#  'useful': 60947,
#  'low': 38910,
#  'grade': 30246,
#  'fusion': 28893,
#  'reactor': 50574,
#  'explore': 26903,
#  'satisfy': 53054,
#  'curiosity': 22122,
#  'itch': 34731,
#  'gravity': 30350,
#  'heat': 31469,
#  'sink': 54565,
#  'capacity': 18658,
#  'offer': 45320,
#  'utility': 61047,
#  'high': 31843,
#  'ground': 30497,
#  'weapon': 62854,
#  'minute': 41645,
#  'value': 61369,
#  'space': 55367,
#  'travel': 59147,
#  'tourist': 58924,
#  'attraction': 14794,
#  'mt': 42798,
#  'everest': 26630,
#  'minor': 41634,
#  'global': 29913,
#  'scope': 53363,
#  'inconvienent': 33660,
#  'field': 27758,
#  'prevent': 48678,
#  'calcium': 18463,
#  'loss': 38863,
#  'muscle': 43038,
#  'atrophy': 14748,
#  'long': 38779,
#  'genetic': 29492,
#  'drift': 24620,
#  'micro': 41395,
#  'manufacture': 40090,
#  'colony': 20480,
#  'factory': 27204,
#  'spin': 55570,
#  'convienent': 21256,
#  'look': 38798,
#  'modest': 42157,
#  'vacuum': 61330,
#  'raw': 50434,
#  'solar': 55172,
#  'exposure': 26921,
#  'orbital': 45766,
#  'continous': 21158,
#  'source': 55316,
#  'light': 38328,
#  'element': 25628,
#  'rock': 52089,
#  'serve': 53849,
#  'heatsink': 31478,
#  'shield': 54157,
#  'heavy': 31487,
#  'volatile': 62114,
#  'compound': 20743,
#  'steep': 56145,
#  'delta': 23160,
#  'require': 51293,
#  '3rd': 7076,
#  'seafloor': 53538,
#  'virtually': 61946,
#  'ignore': 33182,
#  'antarctica': 13828,
#  'continent': 21154,
#  'deal': 22826,
#  'condition': 20875,
#  'buck': 17523,
#  'expensive': 26867,
#  'visit': 61968,
#  'live': 38540,
#  'work': 63606,
#  'll': 38620,
#  'easy': 25177,
#  'push': 49340,
#  'development': 23488,
#  'main': 39881,
#  'short': 54250,
#  'farside': 27355,
#  'astronomy': 14637,
#  'observatory': 45162,
#  'noisy': 44453,
#  'laser': 37678,
#  'particle': 46680,
#  'beam': 15865,
#  'linear': 38414,
#  'accelerator': 12289,
#  'defend': 23018,
#  'bombard': 16919,
#  'case': 18832,
#  'unlikely': 60519,
#  'cost': 21456,
#  'basic': 15671,
#  'science': 53328,
#  'instrument': 34126,
#  'conventional': 21233,
#  'nuke': 44823,
#  'safe': 52830,
#  'warfare': 62676,
#  'glory': 29926,
#  'watch': 62730,
#  'bunker': 17653,
#  'fight': 27778,
#  'continental': 21155,
#  'range': 50340,
#  'ultimate': 60047,
#  'profit': 48855,
#  'gatech': 29324,
#  'wa4mei': 62537,
#  'break': 17227,
#  'uunet': 61092,
#  'rsiatl': 52412,
#  '534': 8063,
#  'shannon': 54026,
#  'guarantee': 30631,
#  'emory': 25820,
#  'kd4nc': 36320,
#  'lawrenceville': 37773,
#  'ga': 29146,
#  '30244': 6221,
#  'gun': 30703,
#  'backcountry': 15362,
#  'thank': 58180,
#  'computer': 20780,
#  'department': 23266,
#  'stanford': 55996,
#  '174436': 3168,
#  '22897': 5035,
#  'midway': 41479,
#  'uchicago': 59840,
#  'pkgeragh': 47767,
#  'gsbphd': 30557,
#  'kevin': 36452,
#  'geraghty': 29566,
#  'wrong': 63741,
#  'protection': 49022,
#  'mindset': 41596,
#  'systemic': 57324,
#  'cumulative': 22097,
#  'individual': 33763,
#  'action': 12467,
#  'insurance': 34143,
#  'house': 32363,
#  'prudent': 49084,
#  'bunch': 17639,
#  'paranoid': 46592,
#  'pack': 46392,
#  'handgun': 31129,
#  'choose': 19630,
#  'protect': 49021,
#  'manner': 40060,
#  'pretty': 48669,
#  'king': 36697,
#  'nervous': 43889,
#  'threat': 58394,
#  'affect': 12762,
#  'logical': 38738,
#  'conclusion': 20845,
#  'suppose': 56936,
#  'carry': 18797,
#  'time': 58551,
#  'collectively': 20447,
#  'insecure': 34054,
#  'note': 44604,
#  'available': 14973,
#  'psych': 49149,
#  'info': 33886,
#  'feeling': 27528,
#  'increase': 33668,
#  'victimization': 61811,
#  'stat': 56060,
#  'rational': 50403,
#  'modify': 42163,
#  'behavior': 15975,
#  'response': 51398,
#  'itchier': 34733,
#  'kill': 36645,
#  'course': 21532,
#  'routine': 52296,
#  'mugging': 42897,
#  'nope': 44530,
#  'happen': 31184,
#  'instead': 34102,
#  'switch': 57175,
#  'change': 19344,
#  'property': 48958,
#  'crime': 21739,
#  'improvement': 33528,
#  'economic': 25272,
#  'unchanged': 60195,
#  'sure': 56965,
#  'andy': 13695,
#  'male': 39948,
#  'female': 27574,
#  'mystery': 43266,
#  'dumbest': 24835,
#  'automotive': 14946,
#  'concept': 20821,
#  'california': 18488,
#  'institute': 34112,
#  'technology': 57835,
#  '16': 2826,
#  'neptune': 43880,
#  'caltech': 18519,
#  '1993apr1': 3672,
#  '191826': 3496,
#  '28921': 5665,
#  'iscnvx': 34608,
#  'lmsc': 38662,
#  'lockheed': 38712,
#  'sharen': 54041,
#  'rund': 52523,
#  'husband': 32638,
#  'hate': 31310,
#  'auto': 14916,
#  'lock': 38709,
#  'feature': 27498,
#  'family': 27300,
#  'child': 19549,
#  'car': 18695,
#  'easily': 25165,
#  'addition': 12540,
#  'check': 19437,
#  'near': 43751,
#  'park': 46625,
#  'secluded': 53592,
#  'spot': 55666,
#  'etc': 26473,
#  'key': 36459,
#  'ready': 50591,
#  'fumble': 28834,
#  'purse': 49330,
#  'biological': 16460,
#  'reason': 50631,
#  'pant': 46528,
#  'pocket': 48049,
#  'wallent': 62623,
#  'botton': 17052,
#  'close': 20184,
#  'securely': 53614,
#  'simple': 54509,
#  'ie': 33124,
#  'room': 52209,
#  'big': 16355,
#  'plus': 47958,
#  'wallet': 62624,
#  'raise': 50268,
#  'parent': 46610,
#  'swr': 57197,
#  'meter': 41150,
#  'cb': 18952,
#  'radios': 50215,
#  'digital': 23718,
#  'equipment': 26241,
#  'corporation': 21391,
#  'cimill': 19831,
#  '734953838': 9727,
#  'aa00508': 12044,
#  'insane': 34048,
#  'apana': 13943,
#  'org': 45807,
#  'au': 14806,
#  'tryndoch': 59374,
#  'allthe': 13318,
#  'reincarnateswr': 50977,
#  'td': 57779,
#  'ssave': 55863,
#  'ole': 45468,
#  'cdac': 19085,
#  'reincarnate': 50976,
#  'wa': 62527,
#  'choice': 19616,
#  'wave': 62766,
#  'read': 50575,
#  'installation': 34091,
#  'instruction': 34122,
#  'antenna': 13832,
#  'tune': 59493,
#  'channel': 19350,
#  '32': 6332,
#  'minimum': 41621,
#  'reading': 50584,
#  'question': 49908,
#  'explanation': 26890,
#  'sense': 53757,
#  'cancell': 18591,
#  'btw': 17506,
#  'beastie': 15879,
#  'common': 20616,
#  'pattern': 46802,
#  'cloverleaf': 20205,
#  'lobe': 38696,
#  'transmit': 59109,
#  'uncommon': 60212,
#  'usual': 61005,
#  'rubber': 52460,
#  'duck': 24792,
#  'coil': 20396,
#  'fool': 28287,
#  'quarter': 49876,
#  'reccomend': 50668,
#  'arrl': 14377,
#  'handbook': 31118,
#  'book': 16960,
#  'dave': 22679,
#  'pierson': 47614,
#  'accurately': 12362,
#  'manage': 40004,
#  '40': 7161,
#  'old': 45461,
#  'bolton': 16915,
#  'rd': 50544,
#  'nra': 44701,
#  'stow': 56349,
#  'mass': 40302,
#  '01775': 456,
#  'usa': 60925,
#  'msd26': 42739,
#  'enet': 25967,
#  'dec': 22878,
#  'credit': 21706,
#  'raffle': 50231,
#  'hezbollah': 31740,
#  'orion': 45859,
#  'oac': 45070,
#  'uci': 59841,
#  'irvine': 34588,
#  '133': 2267,
#  'apr15': 14101,
#  '175334': 3192,
#  '72079': 9585,
#  'yuma': 65172,
#  'colostate': 20499,
#  'bh437292': 16269,
#  'lance': 37586,
#  'camp': 18559,
#  'village': 61885,
#  'small': 54924,
#  'kid': 36620,
#  'soccer': 55096,
#  'street': 56412,
#  'lunch': 39123,
#  'young': 65084,
#  'usually': 61006,
#  'age': 12842,
#  'member': 40978,
#  'inhabitant': 33947,
#  'secretive': 53603,
#  'suspect': 57024,
#  'financially': 27853,
#  'iran': 34508,
#  'sneak': 55027,
#  'arm': 14309,
#  'ammunition': 13529,
#  'set': 53868,
#  'booby': 16958,
#  'trap': 59134,
#  'patrol': 46798,
#  'soldier': 55184,
#  'retalliate': 51455,
#  'indiscriminately': 33754,
#  'bomb': 16918,
#  'choosing': 19632,
#  'innocent': 34014,
#  'true': 59340,
#  'method': 41159,
#  'utilize': 61050,
#  'guerilla': 30649,
#  'group': 30505,
#  'conduct': 20887,
#  'operation': 45661,
#  'midst': 41475,
#  'local': 38699,
#  'populace': 48221,
#  'force': 28316,
#  'oppose': 45691,
#  'harm': 31238,
#  'search': 53557,
#  'avoid': 15017,
#  'abandon': 12118,
#  'certainly': 19215,
#  'population': 48228,
#  'cover': 21555,
#  'blaim': 16605,
#  'drag': 24556,
#  'totally': 58905,
#  'attack': 14756,
#  'hope': 32253,
#  'respect': 51380,
#  'insist': 34070,
#  'necessary': 43772,
#  'pay': 46830,
#  'price': 48696,
#  'blood': 16706,
#  'demilitarize': 23188,
#  'buffer': 17561,
#  'territory': 58061,
#  'exactly': 26721,
#  'surprize': 56992,
#  'decide': 22908,
#  'stop': 56325,
#  'interested': 34225,
#  'withdraw': 63391,
#  'neighboring': 43841,
#  'start': 56041,
#  'responsibility': 51400,
#  'duty': 24903,
#  'soil': 55159,
#  'guaratee': 30634,
#  'accept': 12294,
#  'word': 63594,
#  'past': 46738,
#  'attitude': 14784,
#  'tolerance': 58763,
#  'anti': 13845,
#  'residence': 51343,
#  'newsgroup': 44042,
#  'real': 50600,
#  'solution': 55210,
#  'comprehensive': 20746,
#  'border': 16998,
#  'troop': 59312,
#  'station': 56075,
#  'insure': 34144,
#  'shell': 54115,
#  'world': 63626,
#  'gove': 30174,
#  'un': 60119,
#  'country': 21512,
#  'allow': 13310,
#  'nasser': 43583,
#  '56': 8193,
#  '67': 8991,
#  'limitation': 38371,
#  'power': 48371,
#  'comfortable': 20552,
#  'genuine': 29522,
#  'commitment': 20607,
#  'concrete': 20853,
#  'intellectual': 34170,
#  'political': 48123,
#  'exercise': 26804,
#  'jargon': 35049,
#  'party': 46696,
#  'worthless': 63650,
#  'ruse': 52545,
#  'realistic': 50606,
#  'realize': 50610,
#  'aim': 12974,
#  'city': 19913,
#  'fail': 27232,
#  'occasional': 45196,
#  ...}

# %%
svd_model = TruncatedSVD(n_components=20, n_iter=100, random_state=0)
lsa = svd_model.fit_transform(X)
sujet = [f"sujet_{i}" for i in range(1,21)]
topic_encoded_df = pd.DataFrame(lsa, columns = sujet, index=df_sample.index)

# %%
topic_encoded_df["class_pred"] = topic_encoded_df.idxmax(axis=1).str.split("_").str[1]

# %%
topic_encoded_df
# Out:
#        sujet_1   sujet_2   sujet_3   sujet_4   sujet_5   sujet_6   sujet_7  \
# 8518  0.128766  0.073880  0.009735  0.043079  0.030638 -0.169242  0.044743
# 7887  0.098157  0.047029 -0.014820 -0.044539 -0.058988  0.045472 -0.037858
# 3744  0.131643 -0.044241 -0.057205  0.003757  0.038206 -0.015205 -0.101250
# 2913  0.115906  0.062678  0.005949  0.024895  0.033937 -0.125965  0.044883
# 458   0.193075  0.173279 -0.000964 -0.109375 -0.004836  0.090771  0.002260
# ...        ...       ...       ...       ...       ...       ...       ...
# 8736  0.105896 -0.022567 -0.056799  0.015259  0.044098 -0.033906 -0.093723
# 6173  0.161869  0.145887  0.015744 -0.122638 -0.014707  0.084662  0.013394
# 9076  0.129130  0.028402 -0.037553 -0.003896 -0.017405  0.042212 -0.005292
# 4114  0.134408 -0.001061  0.119474  0.037885 -0.002225  0.009657 -0.010681
# 915   0.134050 -0.000938  0.099688  0.058203  0.005428  0.011297 -0.030008
#
#        sujet_8   sujet_9  sujet_10  ...  sujet_12  sujet_13  sujet_14  \
# 8518  0.248812  0.013740 -0.043961  ... -0.075524 -0.052757 -0.080970
# 7887  0.038334  0.003096 -0.022491  ...  0.015809  0.043630  0.034996
# 3744  0.058934 -0.060840  0.049803  ...  0.027117 -0.009984  0.011796
# 2913  0.167045  0.018293 -0.024345  ... -0.073781 -0.041579 -0.073949
# 458   0.016263  0.003226 -0.024986  ...  0.026876  0.039940  0.019305
# ...        ...       ...       ...  ...       ...       ...       ...
# 8736  0.019633 -0.029902 -0.012292  ... -0.020426 -0.039083  0.069004
# 6173  0.005724  0.034910 -0.006917  ...  0.011182  0.037740 -0.013778
# 9076  0.001278  0.012745 -0.009851  ...  0.004982  0.022745 -0.003815
# 4114 -0.002563 -0.023169 -0.003040  ...  0.014136  0.011444  0.020500
# 915  -0.012006  0.011158  0.007399  ...  0.000198 -0.010831 -0.034905
#
#       sujet_15  sujet_16  sujet_17  sujet_18  sujet_19  sujet_20  class_pred
# 8518 -0.087474 -0.053667 -0.020125 -0.063334 -0.020742  0.025689           8
# 7887  0.029846 -0.040566 -0.004224 -0.036927  0.008289  0.008985           1
# 3744  0.017112  0.001728  0.036828 -0.033799  0.081724  0.033413           1
# 2913 -0.089031 -0.042504 -0.016928 -0.031258 -0.012558  0.002463           8
# 458   0.000969 -0.023906  0.022916 -0.009993  0.000710 -0.000052           1
# ...        ...       ...       ...       ...       ...       ...         ...
# 8736  0.011209 -0.028063 -0.010355 -0.012871 -0.036933 -0.033061           1
# 6173  0.020581 -0.034053 -0.012331  0.006941  0.009386 -0.007938           1
# 9076  0.002972 -0.038096 -0.034750  0.010185  0.017045 -0.013644           1
# 4114  0.000202  0.001523 -0.000856  0.004937  0.009409 -0.003660           1
# 915   0.000307 -0.036640 -0.003123  0.021201 -0.017480  0.023221           1
#
# [5000 rows x 21 columns]

# %%
topic_encoded_df["class_pred"].value_counts()
# Out:
# 1     3926
# 3      145
# 9      100
# 2       99
# 4       90
# 8       85
# 5       83
# 6       79
# 15      58
# 16      53
# 13      52
# 18      43
# 7       42
# 20      37
# 12      28
# 11      26
# 17      25
# 10      13
# 19      10
# 14       6
# Name: class_pred, dtype: int64

# %%
topic_encoded_df["cible"] = df_sample["cible"]

# %%
topic_encoded_df
# Out:
#        sujet_1   sujet_2   sujet_3   sujet_4   sujet_5   sujet_6   sujet_7  \
# 8518  0.128766  0.073880  0.009735  0.043079  0.030638 -0.169242  0.044743
# 7887  0.098157  0.047029 -0.014820 -0.044539 -0.058988  0.045472 -0.037858
# 3744  0.131643 -0.044241 -0.057205  0.003757  0.038206 -0.015205 -0.101250
# 2913  0.115906  0.062678  0.005949  0.024895  0.033937 -0.125965  0.044883
# 458   0.193075  0.173279 -0.000964 -0.109375 -0.004836  0.090771  0.002260
# ...        ...       ...       ...       ...       ...       ...       ...
# 8736  0.105896 -0.022567 -0.056799  0.015259  0.044098 -0.033906 -0.093723
# 6173  0.161869  0.145887  0.015744 -0.122638 -0.014707  0.084662  0.013394
# 9076  0.129130  0.028402 -0.037553 -0.003896 -0.017405  0.042212 -0.005292
# 4114  0.134408 -0.001061  0.119474  0.037885 -0.002225  0.009657 -0.010681
# 915   0.134050 -0.000938  0.099688  0.058203  0.005428  0.011297 -0.030008
#
#        sujet_8   sujet_9  sujet_10  ...  sujet_13  sujet_14  sujet_15  \
# 8518  0.248812  0.013740 -0.043961  ... -0.052757 -0.080970 -0.087474
# 7887  0.038334  0.003096 -0.022491  ...  0.043630  0.034996  0.029846
# 3744  0.058934 -0.060840  0.049803  ... -0.009984  0.011796  0.017112
# 2913  0.167045  0.018293 -0.024345  ... -0.041579 -0.073949 -0.089031
# 458   0.016263  0.003226 -0.024986  ...  0.039940  0.019305  0.000969
# ...        ...       ...       ...  ...       ...       ...       ...
# 8736  0.019633 -0.029902 -0.012292  ... -0.039083  0.069004  0.011209
# 6173  0.005724  0.034910 -0.006917  ...  0.037740 -0.013778  0.020581
# 9076  0.001278  0.012745 -0.009851  ...  0.022745 -0.003815  0.002972
# 4114 -0.002563 -0.023169 -0.003040  ...  0.011444  0.020500  0.000202
# 915  -0.012006  0.011158  0.007399  ... -0.010831 -0.034905  0.000307
#
#       sujet_16  sujet_17  sujet_18  sujet_19  sujet_20  class_pred  cible
# 8518 -0.053667 -0.020125 -0.063334 -0.020742  0.025689           8     17
# 7887 -0.040566 -0.004224 -0.036927  0.008289  0.008985           1     15
# 3744  0.001728  0.036828 -0.033799  0.081724  0.033413           1      3
# 2913 -0.042504 -0.016928 -0.031258 -0.012558  0.002463           8     17
# 458  -0.023906  0.022916 -0.009993  0.000710 -0.000052           1     15
# ...        ...       ...       ...       ...       ...         ...    ...
# 8736 -0.028063 -0.010355 -0.012871 -0.036933 -0.033061           1      8
# 6173 -0.034053 -0.012331  0.006941  0.009386 -0.007938           1     19
# 9076 -0.038096 -0.034750  0.010185  0.017045 -0.013644           1      0
# 4114  0.001523 -0.000856  0.004937  0.009409 -0.003660           1     11
# 915  -0.036640 -0.003123  0.021201 -0.017480  0.023221           1     11
#
# [5000 rows x 22 columns]

# %%
topic_encoded_df["cible"].value_counts()
# Out:
# 14    274
# 11    272
# 7     271
# 8     268
# 9     266
# 2     266
# 10    265
# 17    262
# 13    262
# 3     260
# 4     259
# 6     259
# 15    254
# 5     252
# 12    251
# 16    243
# 1     242
# 0     220
# 18    201
# 19    153
# Name: cible, dtype: int64
