# %%
import pandas as pd
import numpy as np 
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LinearRegression
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Users\jerem\jedha essential\projet\btc-usdt.csv')

# %%
df
# Out:
#                            Open Time      Open      High       Low     Close  \
# 0      2019-07-30 00:00:00.000000000   9509.07   9535.00   9503.07   9517.75
# 1      2019-07-30 00:30:00.000000000   9517.03   9539.00   9507.00   9532.58
# 2      2019-07-30 01:00:00.000000000   9533.59   9534.00   9500.00   9500.25
# 3      2019-07-30 01:30:00.000000000   9500.25   9514.46   9460.71   9465.25
# 4      2019-07-30 02:00:00.000000000   9465.25   9488.94   9430.01   9460.42
# ...                              ...       ...       ...       ...       ...
# 55377  2022-09-27 16:30:00.000000000  19492.21  19499.25  18918.77  19110.79
# 55378  2022-09-27 17:00:00.000000000  19110.79  19115.89  18863.70  18951.06
# 55379  2022-09-27 17:30:00.000000000  18951.06  19036.61  18863.01  18957.20
# 55380  2022-09-27 18:00:00.000000000  18957.95  18997.46  18816.32  18951.87
# 55381  2022-09-27 18:30:00.000000000  18950.71  19159.83  18924.64  19103.23
#
# ...

# %%
df.describe(include="all")
# Out:
#                             Open Time          Open         High  \
# count                           55382  55382.000000  55382.00000
# unique                          55382           NaN          NaN
# top     2019-07-30 00:00:00.000000000           NaN          NaN
# freq                                1           NaN          NaN
# mean                              NaN  27078.813587  27185.77378
# std                               NaN  17839.585463  17913.22781
# min                               NaN   4131.230000   4258.53000
# 25%                               NaN   9718.515000   9742.96250
# 50%                               NaN  21747.490000  21846.32500
# 75%                               NaN  42236.362500  42389.46500
# max                               NaN  68635.120000  69000.00000
#
#                  Low         Close        Volume  \
# count   55382.000000  55382.000000  55382.000000
# unique           NaN           NaN           NaN
# ...

# %%
df.isnull().any()
# Out:
# Open Time             False
# Open                  False
# High                  False
# Low                   False
# Close                 False
# Volume                False
# Close Time            False
# Quote Asset Volume    False
# Number of Trades      False
# TB Base Volume        False
# TB Quote Volume       False
# Ignore                False
# dtype: bool

# %%
df["Open Time"] = df["Open Time"].apply(lambda x: x.replace(".000000000", ""))

# %%
df = df.drop(["Close Time", 'Ignore'], axis=1,)

# %%
x = df.iloc[1:,1].reset_index()["Open"]
y = df.iloc[:-1,1].reset_index()["Open"]

# %%
df["forward"] = (y -x) / x * 10000

# %%
df["Performance"] = (x -y) / y * 10000

# %%
df
# Out:
#                  Open Time      Open      High       Low     Close  \
# 0      2019-07-30 00:00:00   9509.07   9535.00   9503.07   9517.75
# 1      2019-07-30 00:30:00   9517.03   9539.00   9507.00   9532.58
# 2      2019-07-30 01:00:00   9533.59   9534.00   9500.00   9500.25
# 3      2019-07-30 01:30:00   9500.25   9514.46   9460.71   9465.25
# 4      2019-07-30 02:00:00   9465.25   9488.94   9430.01   9460.42
# ...                    ...       ...       ...       ...       ...
# 55377  2022-09-27 16:30:00  19492.21  19499.25  18918.77  19110.79
# 55378  2022-09-27 17:00:00  19110.79  19115.89  18863.70  18951.06
# 55379  2022-09-27 17:30:00  18951.06  19036.61  18863.01  18957.20
# 55380  2022-09-27 18:00:00  18957.95  18997.46  18816.32  18951.87
# 55381  2022-09-27 18:30:00  18950.71  19159.83  18924.64  19103.23
#
#              Volume  Quote Asset Volume  Number of Trades  TB Base Volume  \
# 0        381.293856        3.631211e+06              3492      216.528742
# ...
