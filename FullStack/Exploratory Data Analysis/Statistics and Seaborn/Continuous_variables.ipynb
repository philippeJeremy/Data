# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from datetime import datetime as dt
from time import strftime

# %%
df = pd.read_csv('sales_predictions.csv')

# %%
df
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 0        02.01.2013               0       59    22154      999.00
# 1        03.01.2013               0       25     2552      899.00
# 2        05.01.2013               0       25     2552      899.00
# 3        06.01.2013               0       25     2554     1709.05
# 4        15.01.2013               0       25     2555     1099.00
# ...             ...             ...      ...      ...         ...
# 2935844  10.10.2015              33       25     7409      299.00
# 2935845  09.10.2015              33       25     7460      299.00
# 2935846  14.10.2015              33       25     7459      349.00
# 2935847  22.10.2015              33       25     7440      299.00
# 2935848  03.10.2015              33       25     7460      299.00
#
#          item_cnt_day
# 0                 1.0
# 1                 1.0
# 2                -1.0
# 3                 1.0
# 4                 1.0
# ...               ...
# 2935844           1.0
# 2935845           1.0
# 2935846           1.0
# 2935847           1.0
# 2935848           1.0
#
# [2935849 rows x 6 columns]

# %%
n = df.sample(n=25)

# %%
sns.relplot(x='date', y='item_price', data=n, kind="line")

# %%
n['date'] = pd.to_datetime(n['date'])
# Out:
# C:\Users\jerem\AppData\Local\Temp\ipykernel_24592\1749465151.py:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   n['date'] = pd.to_datetime(n['date'])

# %%
n.dtypes
# Out:
# date              datetime64[ns]
# date_block_num             int64
# shop_id                    int64
# item_id                    int64
# item_price               float64
# item_cnt_day             float64
# dtype: object

# %%
n['date'] = n['date'].dt.strftime("%Y %m")

# %%
n
# Out:
#             date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 2215616  2014 10              23       57    18831      199.00           1.0
# 2299836  2014 12              23       56    13168      349.00           1.0
# 2300595  2014 07              23       56     5820     2499.00           1.0
# 2332122  2015 01              24       16    21404      169.00           2.0
# 2019181  2014 09              20       54     5822     1049.00           1.0
# 235096   2013 03               2       45     2584      299.00           1.0
# 1048736  2013 11              10       38     2808      999.00           1.0
# 1013818  2013 08               9       10     8863      175.00           1.0
# 1860274  2014 07              18       18    19092      399.00           1.0
# 2440587  2015 02              25       49    16361      999.00           1.0
# 734809   2013 08               7       57    11691      149.00           1.0
# 2169638  2014 11              22       24     2766      199.00           5.0
# 180128   2013 03               1        1     2848       73.00           1.0
# 2141554  2014 11              22       15     7531      499.00           1.0
# 1192697  2013 12              11       17    22045      399.00           1.0
# 1689958  2014 07              16       41     6090      999.00           1.0
# 2678945  2015 12              29       41    11217      199.34           1.0
# 196626   2013 02               1       45    16323     2389.00           1.0
# 348697   2013 04               3       25    15702      149.00           1.0
# 1770439  2014 07              17       41    21488      699.00           1.0
# 409936   2013 04               3       57     5572     1490.00           1.0
# 635716   2013 07               6       28    15347      539.00           1.0
# 2274403  2014 06              23       54     8226     1149.00           1.0
# 1057813  2013 11              10       31    10915      199.00           1.0
# 1497839  2014 05              14       19     4638     1199.00           1.0

# %%
g =sns.relplot(x='date', y='item_price', data=n, kind="line", )
g.fig.set_figwidth(20)
g.fig.set_figheight(10)
