# %%
import pandas as pd
import numpy as np

# %%
fichier = pd.read_excel(r"fichiers\Hours Spent on Facebook.xlsx").iloc[:,1:]

# %%
t_value=1.96
sigma = fichier.std()
n = len(fichier)
E = t_value * sigma / np.sqrt(n)

fichier.mean().plot(yerr=E, kind="bar")
# Out:
# <AxesSubplot: >
