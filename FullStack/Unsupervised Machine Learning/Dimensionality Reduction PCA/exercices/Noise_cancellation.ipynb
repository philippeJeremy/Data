# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("noisy_digits.csv")
df_2 = pd.read_csv('noisy_digits_labels.csv')

# %%
df = df.drop("Unnamed: 0", axis=1)

# %%
df_2 = df_2.drop("Unnamed: 0", axis=1)

# %%
df
# Out:
#            pixel0      pixel1      pixel2      pixel3      pixel4      pixel5  \
# 0     -176.321245  -52.743850  143.604939  -53.567749   80.289381   20.686379
# 1     -158.421239   16.371695   62.810879  263.533916 -193.920320  -25.366668
# 2     -290.343750   81.586500   12.615232  146.567851  111.233602 -188.989259
# 3     -208.840590  136.190431   38.552191  -67.825346   24.316303  176.103673
# 4     -328.876288  -42.862900  174.651874 -228.833439   71.909654  -97.206392
# ...           ...         ...         ...         ...         ...         ...
# 41995 -193.715418 -121.055317  -47.201498   41.050010  275.268593   81.153157
# 41996   16.644166 -149.397247 -154.872496 -222.054111  -48.943347  -19.228871
# 41997 -137.293206 -280.697152 -177.704894  224.618264   -5.735675  -59.081084
# 41998  120.670250  -60.609717  -56.538574  -73.734513   39.947645  -45.941658
# 41999  -38.434243   -5.786893 -209.555177  112.697133  110.515887 -113.391496
#
# ...

# %%
df = df.to_numpy
