# %%
import pandas as pd
import numpy as np 
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.metrics import plot_confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df_bitcoin = pd.read_csv(r'C:\Users\jerem\jedha essential\projet\bitcoin.csv')
df_1inch = pd.read_csv(r'C:\Users\jerem\jedha essential\projet\1inch.csv')
df_kava = pd.read_csv(r'C:\Users\jerem\jedha essential\projet\kava.csv')
df_ripple = pd.read_csv(r'C:\Users\jerem\jedha essential\projet\ripple.csv')
df_etherium = pd.read_csv(r'C:\Users\jerem\jedha essential\projet\etherium.csv')
df_perf = pd.read_csv(r'C:\Users\jerem\jedha essential\projet\perf.csv')

# %%
# x_bitcoin = df_bitcoin.iloc[1:,1].reset_index()["open"]
# y_bitcion = df_bitcoin.iloc[:-1,1].reset_index()["open"]
# x_1inch = df_1inch.iloc[1:,1].reset_index()["open"]
# y_1inch = df_1inch.iloc[:-1,1].reset_index()["open"]
# x_kava = df_kava.iloc[1:,1].reset_index()["open"]
# y_kava = df_kava.iloc[:-1,1].reset_index()["open"]
# x_ripple = df_ripple.iloc[1:,1].reset_index()["open"]
# y_ripple = df_ripple.iloc[:-1,1].reset_index()["open"]
# x_etherium = df_etherium.iloc[1:,1].reset_index()["open"]
# y_etherium = df_etherium.iloc[:-1,1].reset_index()["open"]

# %%
# df_bitcoin["forward"] = (y_bitcion - x_bitcoin) / x_bitcoin * 10000
# df_1inch["forward"] = (y_1inch - x_1inch) / x_1inch * 10000
# df_kava["forward"] = (y_kava - x_kava) / x_kava * 10000
# df_ripple["forward"] = (y_ripple - x_ripple) / x_ripple * 10000
# df_etherium["forward"] = (y_etherium - x_etherium) / x_etherium * 10000

# %%
# df_bitcoin = df_bitcoin[::-1]
# df_1inch = df_1inch[::-1]
# df_kava = df_kava[::-1]
# df_ripple = df_ripple[::-1]
# df_etherium = df_etherium[::-1]

# %%
# df_bitcoin = df_bitcoin.reset_index()
# df_1inch = df_1inch.reset_index()
# df_kava = df_kava.reset_index()
# df_ripple = df_ripple.reset_index()
# df_etherium = df_etherium.reset_index()

# %%
# x_bitcoin = df_bitcoin.iloc[1:,2].reset_index()["open"]
# y_bitcion = df_bitcoin.iloc[:-1,2].reset_index()["open"]
# x_1inch = df_1inch.iloc[1:,2].reset_index()["open"]
# y_1inch = df_1inch.iloc[:-1,2].reset_index()["open"]
# x_kava = df_kava.iloc[1:,2].reset_index()["open"]
# y_kava = df_kava.iloc[:-1,2].reset_index()["open"]
# x_ripple = df_ripple.iloc[1:,2].reset_index()["open"]
# y_ripple = df_ripple.iloc[:-1,2].reset_index()["open"]
# x_etherium = df_etherium.iloc[1:,2].reset_index()["open"]
# y_etherium = df_etherium.iloc[:-1,2].reset_index()["open"]

# %%
# df_bitcoin["performance"] = (y_bitcion - x_bitcoin) / x_bitcoin * 10000
# df_1inch["performance"] = (y_1inch - x_1inch) / x_1inch * 10000
# df_kava["performance"] = (y_kava - x_kava) / x_kava * 10000
# df_ripple["performance"] = (y_ripple - x_ripple) / x_ripple * 10000
# df_etherium["performance"] = (y_etherium - x_etherium) / x_etherium * 10000

# %%
# df_bitcoin = df_bitcoin[::-1]
# df_1inch = df_1inch[::-1]
# df_kava = df_kava[::-1]
# df_ripple = df_ripple[::-1]
# df_etherium = df_etherium[::-1]

# %%
# df_bitcoin = df_bitcoin.reset_index()
# df_1inch = df_1inch.reset_index()
# df_kava = df_kava.reset_index()
# df_ripple = df_ripple.reset_index()
# df_etherium = df_etherium.reset_index()

# %%
# df_bitcoin = df_bitcoin.drop(["level_0", "index"], axis=1)
# df_1inch = df_1inch.drop(["level_0", "index"], axis=1)
# df_kava = df_kava.drop(["level_0", "index"], axis=1)
# df_ripple = df_ripple.drop(["level_0", "index"], axis=1)
# df_etherium = df_etherium.drop(["level_0", "index"], axis=1)

# %%
# df_perf["time"] = df_bitcoin["open_time"]
# df_perf["perf_back_bitcoin"] = df_bitcoin["performance"]
# df_perf["perf_back_etherium"] = df_etherium["performance"]
# df_perf["perf_back_kava"] = df_kava["performance"]
# df_perf["perf_back_ripple"] = df_ripple["performance"]
# df_perf["perf_for_bitcoin"] = df_bitcoin["forward"]
# df_perf["perf_for_etherium"] = df_etherium["forward"]
# df_perf["perf_for_kava"] = df_kava["forward"]
# df_perf["perf_for_ripple"] = df_ripple["forward"]

# %%
df_bitcoin
# Out:
#             open_time      open      high       low     close       volume  \
# 0       1577836800000   7195.24   7196.25   7178.64   7179.78    95.509133
# 1       1577837100000   7179.76   7191.77   7178.20   7191.07    59.365225
# 2       1577837400000   7193.15   7193.53   7180.24   7180.97    48.068510
# 3       1577837700000   7180.97   7186.40   7177.35   7178.29    32.192929
# 4       1577838000000   7177.71   7182.46   7175.47   7176.96    49.027397
# ...               ...       ...       ...       ...       ...          ...
# 288028  1664380200000  19443.79  19478.07  19439.56  19467.97  1885.375480
# 288029  1664380500000  19466.75  19500.00  19455.68  19487.79  2718.508770
# 288030  1664380800000  19487.79  19666.66  19487.41  19612.85  4890.075890
# 288031  1664381100000  19613.69  19626.37  19529.30  19532.32  2548.206890
# 288032  1664381400000  19534.01  19608.37  19514.97  19602.00  1420.871200
#
#            close_time  quote_asset_volume  number_of_trades  \
# ...

# %%
df_perf = df_perf.drop(["Unnamed: 0.2","Unnamed: 0.1","Unnamed: 0"], axis=1)

# %%
df_perf
# Out:
#                        time  perf_back_bitcoin  perf_back_etherium  \
# 0       2020-01-01 00:05:00         -21.514223          -24.775472
# 1       2020-01-01 00:10:00          18.649648            6.985408
# 2       2020-01-01 00:15:00         -16.932776           -1.551229
# 3       2020-01-01 00:20:00          -4.539777           -4.654410
# 4       2020-01-01 00:25:00          -0.167184          -10.089251
# ...                     ...                ...                 ...
# 288024  2022-09-28 15:35:00         -25.090026          -22.934223
# 288025  2022-09-28 15:40:00           9.507916           19.962344
# 288026  2022-09-28 15:45:00           2.356672           -4.678786
# 288027  2022-09-28 15:50:00          24.473715           36.768314
# 288028  2022-09-28 15:55:00          11.808397           11.659571
#
#         perf_back_kava  perf_back_ripple  perf_for_bitcoin  perf_for_etherium  \
# 0            -6.258382         -9.333679        -18.614932          -6.980532
# ...

# %%
df_perf["for_etherium_bitcoin"] = df_perf["perf_for_etherium"] - df_perf["perf_for_bitcoin"]
df_perf["for_kava_bitcoin"] = df_perf["perf_for_kava"] - df_perf["perf_for_bitcoin"]
df_perf["for_ripple_bitcoin"] = df_perf["perf_for_ripple"] - df_perf["perf_for_bitcoin"]
df_perf["back_etherium_bitcoin"] = df_perf["perf_back_etherium"] - df_perf["perf_back_bitcoin"]
df_perf["back_kava_bitcoin"] = df_perf["perf_back_kava"] - df_perf["perf_back_bitcoin"]
df_perf["back_ripple_bitcoin"] = df_perf["perf_back_ripple"] - df_perf["perf_back_bitcoin"]

# %%
df_perf
# Out:
#                        time  perf_back_bitcoin  perf_back_etherium  \
# 0       2020-01-01 00:05:00         -21.514223          -24.775472
# 1       2020-01-01 00:10:00          18.649648            6.985408
# 2       2020-01-01 00:15:00         -16.932776           -1.551229
# 3       2020-01-01 00:20:00          -4.539777           -4.654410
# 4       2020-01-01 00:25:00          -0.167184          -10.089251
# ...                     ...                ...                 ...
# 288024  2022-09-28 15:35:00         -25.090026          -22.934223
# 288025  2022-09-28 15:40:00           9.507916           19.962344
# 288026  2022-09-28 15:45:00           2.356672           -4.678786
# 288027  2022-09-28 15:50:00          24.473715           36.768314
# 288028  2022-09-28 15:55:00          11.808397           11.659571
#
#         perf_back_kava  perf_back_ripple  perf_for_bitcoin  perf_for_etherium  \
# 0            -6.258382         -9.333679        -18.614932          -6.980532
# ...

# %%
df_perf = df_perf.drop(0, axis=0)

# %%
# Compute the correlation matrix
corr = df_perf.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool,), )

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=1, center=0, 
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True, )
# Out:
# C:\Users\jerem\AppData\Local\Temp\ipykernel_1804\3865083028.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df_perf.corr()
# <AxesSubplot: >

# %%
features_list = [ index for i, index in enumerate(df_perf.columns) if "back" in index]


x = df_perf[features_list]
y = df_perf["for_etherium_bitcoin"]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, 
                                                    test_size=0.2, 
                                                    random_state=0)

# %%
x_train
# Out:
#         perf_back_bitcoin  perf_back_etherium  perf_back_kava  \
# 105129           0.513632          -12.047214        8.723236
# 187754           2.042323            4.045939       25.965034
# 147203          51.265306           21.261618       15.533119
# 218492          39.046023           78.346011       42.918455
# 96496           34.766520           45.958688       53.911658
# ...                   ...                 ...             ...
# 211544         -36.928192          -36.744557      -46.805523
# 86294            0.795547            5.095801        4.691532
# 122580          15.418003           28.914648       31.233224
# 152316         -32.597702          -21.506418      -28.211348
# 117953          18.260048           11.103028      -19.067882
#
#         perf_back_ripple  back_etherium_bitcoin  back_kava_bitcoin  \
# 105129         49.957625             -12.560846           8.209604
# 187754          8.946144               2.003616          23.922711
# ...

# %%
numeric_features = [i  for i,item in enumerate(x_train.columns)]

numeric_features = [i for i in range(len(x_train.columns))]
numeric_transformer = StandardScaler()


# categorical_features = [0, 1, 2, 3] 
# categorical_transformer = OneHotEncoder()


feature_encoder = ColumnTransformer(
    transformers=[
        # ('cat', categorical_transformer, categorical_features),    
        ('num', numeric_transformer, numeric_features)
        ]
    )

# %%
x_train = feature_encoder.fit_transform(x_train)

# %%
regressor = RandomForestRegressor(n_estimators=30, random_state=0,max_depth=10)
regressor.fit(x_train, y_train)
# Out:
# RandomForestRegressor(max_depth=10, n_estimators=30, random_state=0)

# %%
y_train_pred = regressor.predict(x_train)

# %%
x_test = feature_encoder.transform(x_test)

# %%
y_test_pred = regressor.predict(x_test)

# %%
print("R2 score on training set : ", regressor.score(x_train, y_train))
print("R2 score on test set : ", regressor.score(x_test, y_test))
# Out:
# R2 score on training set :  0.04658210670390328
# R2 score on test set :  0.004699553402353951

# %%
def mae(y_train_pred, y_test_pred):
    y_train_pred, y_test_pred = np.array(y_train_pred), np.array(y_test_pred)
    return np.mean(np.abs(y_train_pred - y_test_pred))
print(mae(y_train_pred, y_test_pred))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [31], line 4
#       2     y_train_pred, y_test_pred = np.array(y_train_pred), np.array(y_test_pred)
#       3     return np.mean(np.abs(y_train_pred - y_test_pred))
# ----> 4 print(mae(y_train_pred, y_test_pred))
#
# Cell In [31], line 3, in mae(y_train_pred, y_test_pred)
#       1 def mae(y_train_pred, y_test_pred):
#       2     y_train_pred, y_test_pred = np.array(y_train_pred), np.array(y_test_pred)
# ----> 3     return np.mean(np.abs(y_train_pred - y_test_pred))
#
# ValueError: operands could not be broadcast together with shapes (230422,) (57606,)
