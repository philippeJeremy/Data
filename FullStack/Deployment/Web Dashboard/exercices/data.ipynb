# %%
import pandas as pd
import plotly.express as px 
import plotly.graph_objects as go
import numpy as np

# %%
# df = px.data.gapminder().query("year == 2007")

# %%
df
# Out:
#                  country continent  year  lifeExp       pop     gdpPercap  \
# 11           Afghanistan      Asia  2007   43.828  31889923    974.580338
# 23               Albania    Europe  2007   76.423   3600523   5937.029526
# 35               Algeria    Africa  2007   72.301  33333216   6223.367465
# 47                Angola    Africa  2007   42.731  12420476   4797.231267
# 59             Argentina  Americas  2007   75.320  40301927  12779.379640
# ...                  ...       ...   ...      ...       ...           ...
# 1655             Vietnam      Asia  2007   74.249  85262356   2441.576404
# 1667  West Bank and Gaza      Asia  2007   73.422   4018332   3025.349798
# 1679         Yemen, Rep.      Asia  2007   62.698  22211743   2280.769906
# 1691              Zambia    Africa  2007   42.384  11746035   1271.211593
# 1703            Zimbabwe    Africa  2007   43.487  12311143    469.709298
#
#      iso_alpha  iso_num
# 11         AFG        4
# 23         ALB        8
# ...

# %%
data = pd.read_csv('https://opendata.ecdc.europa.eu/covid19/nationalcasedeath_eueea_daily_ei/csv')

# %%
data
# Out:
#           dateRep  day  month  year    cases  deaths countriesAndTerritories  \
# 0      23/10/2022   23     10  2022   3557.0     0.0                 Austria
# 1      22/10/2022   22     10  2022   5494.0     4.0                 Austria
# 2      21/10/2022   21     10  2022   7776.0     4.0                 Austria
# 3      20/10/2022   20     10  2022   8221.0     6.0                 Austria
# 4      19/10/2022   19     10  2022  10007.0     8.0                 Austria
# ...           ...  ...    ...   ...      ...     ...                     ...
# 28724  08/02/2020    8      2  2020      0.0     0.0                  Sweden
# 28725  07/02/2020    7      2  2020      0.0     0.0                  Sweden
# 28726  06/02/2020    6      2  2020      0.0     0.0                  Sweden
# 28727  05/02/2020    5      2  2020      0.0     0.0                  Sweden
# 28728  04/02/2020    4      2  2020      1.0     0.0                  Sweden
#
# ...

# %%
fig_2 = px.scatter_geo(data, locations="countryterritoryCode", color="countriesAndTerritories",
                     hover_name="countriesAndTerritories", animation_frame="year", scope="europe" ,size=10)
                     
fig_2.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [48], line 1
# ----> 1 fig_2 = px.scatter_geo(data, locations="countryterritoryCode", color="countriesAndTerritories",
#       2                      hover_name="countriesAndTerritories", animation_frame="year", scope="europe" ,size="deaths")
#       4 fig_2.show()
#
# ...

# %%
data['dateRep'] =  pd.to_datetime(data['dateRep'])
# df['dateRep'] =  pd.to_datetime(df['dateRep'], format="%Y-%m-%d")
# Out:
# C:\Users\jerem\AppData\Local\Temp\ipykernel_364\3726775672.py:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   data['dateRep'] =  pd.to_datetime(data['dateRep'])
