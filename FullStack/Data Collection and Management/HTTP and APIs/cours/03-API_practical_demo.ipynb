# %% [markdown]
# # API DEMO
#
# Now that you have some general knowledge of APIs and how to call them with the `requests` library, let's walk you through a concrete example of how to navigate an API's documentation in order to start querying it and get the information that you are looking for!

# %% [markdown]
# ## What you are going to learn in this course 🧐🧐
#
# This course will give you a step by step demo of how you should generally approach the discovery and usage of a new API. Here's the outline:
#
# * Explore an API's documentation
# * Start querying the RATP API

# %% [markdown]
# ## Explore an API's documentation
#
# Creating an API is one thing, you are making an interface available to your users so they can get information through programs. However, apart from those who created the API, no one would know how to use it. This is why every API comes with a documentation to help users find what they are looking for!
#
# Let's take a look at the documentation for RATP's API (the unofficial french public transport network's API) available at the following [link](https://api-ratp.pierre-grimaud.fr/v4/).
#
# The homepage looks like this:
#
# ![ratp_api_homepage](https://full-stack-assets.s3.eu-west-3.amazonaws.com/images/0-M04-data-collection/ratp_api_homepage.PNG)
#
# The homepage actually contains the api's documentation! In this case, and it's actually pretty common, all the url we will request for this api will start by `https://api-ratp.pierre-grimaud.fr/v4/` which is the homepage url, then we can add suffixes to this url to get various information.
#
# The various urls you can access to get data from an API are called **endpoints**! This a word that will appear in almost all the API documentations you will run into, so remember it means that it is the url you may request to get a response from the API.

# %% [markdown]
# ### API call with generic url/endpoint
#
# As you can see in the documentation, some of the urls you can request are generic, and others must include specific information like `type` or `code`.
#
# Let's focus first on the this url `https://api-ratp.pierre-grimaud.fr/v4/lines`, click this section of the documentation to get additional information about this endpoint!
#
# ![ratp_lines](https://full-stack-assets.s3.eu-west-3.amazonaws.com/images/0-M04-data-collection/ratp_lines.PNG)
#
# There are several we learn from reading this documentation:
#
# * **Purpose**: we now know that this endpoint should give us informations about all the lines from the ratp network
# * **Parameters**: there are none
# * **Responses**: the only response type documented is 200 and the response data type is json!
#
# With this in mind let's try it!

# %%
import requests

r =  requests.get("https://api-ratp.pierre-grimaud.fr/v4/lines")
print("Response code:",r,"\n \n")
print("Response data:\n")
r.json()
# Out:
# Response code: <Response [200]>
#
#
# Response data:
# {'result': {'metros': [{'code': '1',
#     'name': 'Métro 1',
#     'directions': 'La Defense / Chateau de Vincennes',
#     'id': '62'},
#    {'code': '2',
#     'name': 'Métro 2',
#     'directions': 'Porte Dauphine / Nation',
#     'id': '67'},
#    {'code': '3',
#     'name': 'Métro 3',
#     'directions': 'Pont de Levallois - Becon / Gallieni',
#     'id': '68'},
#    {'code': '3b',
#     'name': 'Métro 3b',
#     'directions': 'Gambetta / Porte des Lilas',
#     'id': '69'},
#    {'code': '4',
#     'name': 'Métro 4',
#     'directions': 'Bagneux - Lucie Aubrac / Porte de Clignancourt',
#     'id': '70'},
#    {'code': '5',
#     'name': 'Métro 5',
#     'directions': "Place d'Italie / Bobigny - Pablo Picasso",
#     'id': '71'},
#    {'code': '6',
#     'name': 'Métro 6',
#     'directions': 'Charles de Gaulle - Etoile / Nation',
#     'id': '72'},
#    {'code': '7',
#     'name': 'Métro 7',
#     'directions': "Villejuif-L. Aragon / Mairie d'Ivry / la Courneuve - 8 Mai 1945",
#     'id': '73'},
#    {'code': '7b',
#     'name': 'Métro 7b',
#     'directions': 'Louis Blanc / Pre-Saint-Gervais',
#     'id': '74'},
#    {'code': '8',
#     'name': 'Métro 8',
#     'directions': 'Creteil-Pointe du Lac / Balard',
#     'id': '172562'},
#    {'code': '9',
#     'name': 'Métro 9',
#     'directions': 'Mairie de Montreuil / Pont de Sevres',
#     'id': '76'},
#    {'code': '10',
#     'name': 'Métro 10',
#     'directions': "Gare d'Austerlitz / Boulogne - Pont de Saint Cloud",
#     'id': '63'},
#    {'code': '11',
#     'name': 'Métro 11',
#     'directions': 'Chatelet / Mairie des Lilas',
#     'id': '64'},
#    {'code': '12',
#     'name': 'Métro 12',
#     'directions': "Front Populaire / Mairie d'Issy",
#     'id': '65'},
#    {'code': '13',
#     'name': 'Métro 13',
#     'directions': 'St-Denis-Universite/Les Courtilles / Chatillon - Montrouge',
#     'id': '66'},
#    {'code': '14',
#     'name': 'Métro 14',
#     'directions': 'Olympiades / Mairie de Saint-Ouen',
#     'id': '55098'},
#    {'code': 'Fun',
#     'name': 'Métro Fun',
#     'directions': 'Gare Haute / Gare basse',
#     'id': '79'},
#    {'code': 'Orv',
#     'name': 'Métro Orv',
#     'directions': 'Orly 4 / Antony-RER',
#     'id': '455'}],
#   'rers': [{'code': 'A',
#     'name': 'RER A',
#     'directions': 'Marne la Vallee-Boissy Saint Leger / Cergy-Poissy-Saint Germain en Laye',
#     'id': '77'},
#    {'code': 'B',
#     'name': 'RER B',
#     'directions': 'Robinson-Saint Remy les Chevreuse / Aeroport Ch.De Gaulle 2-Mitry Claye',
#     'id': '78'},
#    {'code': 'C',
#     'name': 'RER C',
#     'directions': 'Dourdan-Massy Palaiseau / Pontoise',
#     'id': '1030'},
#    {'code': 'D',
#     'name': 'RER D',
#     'directions': 'Melun / Orry la Ville-Coye',
#     'id': '25065'},
#    {'code': 'E',
#     'name': 'RER E',
#     'directions': 'Chelles Gournay-Tournan / Haussmann Saint Lazare',
#     'id': '264000'},
#    {'code': 'C',
#     'name': 'RER C',
#     'directions': "Saint Martin d'Etampes / Saint Quentin en Yvelines",
#     'id': '1028'},
#    {'code': 'C',
#     'name': 'RER C',
#     'directions': 'Dourdan / Saint Quentin en Yvelines',
#     'id': '1029'},
#    {'code': 'C',
#     'name': 'RER C',
#     'directions': 'Massy Palaiseau / Champ de Mars Tour Eiffel',
#     'id': '1031'},
#    {'code': 'C',
#     'name': 'RER C',
#     'directions': 'Bretigny Sur Orge / Versailles Chateau-Rive Gauche',
#     'id': '1032'},
#    {'code': 'C',
#     'name': 'RER C',
#     'directions': 'Versailles Chantiers / Versailles Chateau-Rive Gauche',
#     'id': '1033'},
#    {'code': 'C',
#     'name': 'RER C',
#     'directions': 'Montigny Beauchamp / Dourdan la Foret',
#     'id': '70960'},
#    {'code': 'C',
#     'name': 'RER C',
#     'directions': "Saint Martin d'Etampes / Montigny Beauchamp",
#     'id': '80928'},
#    {'code': 'C',
#     'name': 'RER C',
#     'directions': 'Versailles-Chantiers / Versailles-Chantiers.',
#     'id': '468706'},
#    {'code': 'D',
#     'name': 'RER D',
#     'directions': 'Melun / Orry la Ville-Creil',
#     'id': '1273'},
#    {'code': 'D',
#     'name': 'RER D',
#     'directions': 'Malesherbes / Orry la Ville-Creil',
#     'id': '1275'},
#    {'code': 'D',
#     'name': 'RER D',
#     'directions': 'Gare de Corbeil Essonnes / Gare de Lyon',
#     'id': '80841'}],
#   'tramways': [{'code': '11',
#     'name': 'Tramway T11',
#     'directions': 'Le Bourget / Epinay Sur Seine',
#     'id': '365923'},
#    {'code': '1',
#     'name': 'Tramway T1',
#     'directions': 'Asnieres - Quatre Routes / Gare de Noisy-Le-Sec',
#     'id': '516753'},
#    {'code': '2',
#     'name': 'Tramway T2',
#     'directions': 'Porte de Versailles (Parc Expo) / Pont de Bezons',
#     'id': '208996'},
#    {'code': '3a',
#     'name': 'Tramway T3a',
#     'directions': 'Porte de Vincennes / Pont Garigliano - Hop G.Pompidou',
#     'id': '198721'},
#    {'code': '3b',
#     'name': 'Tramway T3b',
#     'directions': "Porte d'Asnieres - Marguerite Long / Porte de Vincennes",
#     'id': '420347'},
#    {'code': '4',
#     'name': 'Tramway T4',
#     'directions': 'Gare de Bondy / Hopital de Montfermeil',
#     'id': '476764'},
#    {'code': '5',
#     'name': 'Tramway T5',
#     'directions': 'Marche de Saint-Denis / Garges-Sarcelles RER',
#     'id': '216459'},
#    {'code': '6',
#     'name': 'Tramway T6',
#     'directions': 'Viroflay - Rive Droite / Chatillon - Montrouge',
#     'id': '322861'},
#    {'code': '7',
#     'name': 'Tramway T7',
#     'directions': "Villejuif - Louis Aragon / Porte de l'Essonne",
#     'id': '224161'},
#    {'code': '8',
#     'name': 'Tramway T8',
#     'directions': 'Epinay - Orgemont / Saint-Denis - Porte de Paris',
#     'id': '252615'},
#    {'code': '9',
#     'name': 'Tramway T9',
#     'directions': 'Orly - Gaston Viens / Porte de Choisy',
#     'id': '532639'},
#    {'code': '1',
#     'name': 'Tramway T1',
#     'directions': 'Asnieres - Quatre Routes / (Asnieres - Quatre Routes)',
#     'id': '506188'},
#    {'code': '2',
#     'name': 'Tramway T2',
#     'directions': 'Porte de Versailles (Parc Expo) / Pont de Bezons',
#     'id': '539496'},
#    {'code': '3a',
#     'name': 'Tramway T3a',
#     'directions': 'Porte de Vincennes / Pont Garigliano - Hop G.Pompidou',
#     'id': '540534'},
#    {'code': '3b',
#     'name': 'Tramway T3b',
#     'directions': "Porte d'Asnieres - Marguerite Long / Porte de Vincennes",
#     'id': '527178'},
#    {'code': '4',
#     'name': 'Tramway T4',
#     'directions': "Gare de Bondy / Gare d'Aulnay Sous Bois",
#     'id': '39837'},
#    {'code': '5',
#     'name': 'Tramway T5',
#     'directions': '(Garges-Sarcelles RER) / Garges-Sarcelles RER',
#     'id': '545738'},
#    {'code': '5',
#     'name': 'Tramway T5',
#     'directions': '(Garges-Sarcelles RER) / Garges-Sarcelles RER',
#     'id': '545739'},
#    {'code': '5',
#     'name': 'Tramway T5',
#     'directions': 'Marche de Saint-Denis / Garges-Sarcelles RER',
#     'id': '545740'},
#    {'code': '6',
#     'name': 'Tramway T6',
#     'directions': 'Viroflay - Rive Droite / Chatillon - Montrouge',
#     'id': '545746'},
#    {'code': '7',
#     'name': 'Tramway T7',
#     'directions': 'Villejuif - Louis Aragon / (Villejuif - Louis Aragon)',
#     'id': '572212'},
#    {'code': '7',
#     'name': 'Tramway T7',
#     'directions': "(Porte de l'Essonne) / Porte de l'Essonne",
#     'id': '572213'},
#    {'code': '8',
#     'name': 'Tramway T8',
#     'directions': 'Villetaneuse-Universite / Saint-Denis - Porte de Paris',
#     'id': '252614'},
#    {'code': '8',
#     'name': 'Tramway T8',
#     'directions': 'Epinay - Orgemont / Saint-Denis - Porte de Paris',
#     'id': '572221'},
#    {'code': '8',
#     'name': 'Tramway T8',
#     'directions': 'Saint-Denis - Porte de Paris / (Saint-Denis - Porte de Paris)',
#     'id': '572222'},
#    {'code': '8',
#     'name': 'Tramway T8',
#     'directions': 'Villetaneuse-Universite / Saint-Denis - Porte de Paris',
#     'id': '572224'}],
#   'buses': [{'code': '20',
#     'name': 'Bus RATP 20',
#     'directions': 'Porte des Lilas / Louison Bobet',
#     'id': '529148'},
#    {'code': '21',
#     'name': 'Bus RATP 21',
#     'directions': 'Stade Charlety - Porte de Gentilly / Porte de Saint-Ouen-Hopital Bichat',
#     'id': '557531'},
#    {'code': '22',
#     'name': 'Bus RATP 22',
#     'directions': 'Porte de Saint-Cloud / Gare Saint-Lazare',
#     'id': '465779'},
#    {'code': '24',
#     'name': 'Bus RATP 24',
#     'directions': '(Ecole Veterinaire) / Pantheon',
#     'id': '438035'},
#    {'code': '25',
#     'name': 'Bus RATP 25',
#     'directions': 'Duras / Bibliotheque Francois Mitterrand',
#     'id': '436158'},
#    {'code': '26',
#     'name': 'Bus RATP 26',
#     'directions': 'Nation - Trone / Gare Saint-Lazare',
#     'id': '436163'},
#    {'code': '27',
#     'name': 'Bus RATP 27',
#     'directions': "Porte d'Ivry / Gare Saint-Lazare",
#     'id': '563330'},
#    {'code': '28',
#     'name': 'Bus RATP 28',
#     'directions': 'Porte de Clichy / Gare Montparnasse',
#     'id': '511235'},
#    {'code': '29',
#     'name': 'Bus RATP 29',
#     'directions': 'Porte de Montempoivre / Gare Saint-Lazare',
#     'id': '436207'},
#    {'code': '30',
#     'name': 'Bus RATP 30',
#     'directions': 'Hopital Europeen Georges Pompid / Pigalle',
#     'id': '540282'},
#    {'code': '31',
#     'name': 'Bus RATP 31',
#     'directions': "Charles de Gaulle - Etoile / Gare de l'Est",
#     'id': '264611'},
#    {'code': '32',
#     'name': 'Bus RATP 32',
#     'directions': "Porte d'Auteuil / Gare de l'Est",
#     'id': '442745'},
#    {'code': '35',
#     'name': 'Bus RATP 35',
#     'directions': "Gare du Nord / Mairie d'Aubervilliers",
#     'id': '560310'},
#    {'code': '38',
#     'name': 'Bus RATP 38',
#     'directions': "Porte d'Orleans / Porte de la Chapelle",
#     'id': '560327'},
#    {'code': '39',
#     'name': 'Bus RATP 39',
#     'directions': 'Freres Voisin / Gare du Nord',
#     'id': '437446'},
#    {'code': '40',
#     'name': 'Bus RATP 40',
#     'directions': 'Le Peletier / Mairie du 18e - Jules Joffrin',
#     'id': '438046'},
#    {'code': '42',
#     'name': 'Bus RATP 42',
#     'directions': "Cours de l'Ile Seguin / Gare Saint-Lazare",
#     'id': '574267'},
#    {'code': '43',
#     'name': 'Bus RATP 43',
#     'directions': 'Hippodrome de Longchamp / Gare du Nord',
#     'id': '463398'},
#    {'code': '45',
#     'name': 'Bus RATP 45',
#     'directions': 'Concorde / France-Asie',
#     'id': '441771'},
#    {'code': '46',
#     'name': 'Bus RATP 46',
#     'directions': "Chateau de Vincennes / Gare de l'Est",
#     'id': '501824'},
#    {'code': '47',
#     'name': 'Bus RATP 47',
#     'directions': 'Chatelet / Fort du Kremlin-Bicetre',
#     'id': '438927'},
#    {'code': '48',
#     'name': 'Bus RATP 48',
#     'directions': 'Gare du Nord / Porte des Lilas',
#     'id': '436171'},
#    {'code': '52',
#     'name': 'Bus RATP 52',
#     'directions': 'Parc de Saint-Cloud / Opera - Rue Halevy',
#     'id': '464656'},
#    {'code': '54',
#     'name': 'Bus RATP 54',
#     'directions': "Gabriel Peri-Metro / Porte d'Aubervilliers",
#     'id': '438925'},
#    {'code': '56',
#     'name': 'Bus RATP 56',
#     'directions': 'Chateau de Vincennes / Porte de Clignancourt',
#     'id': '436169'},
#    {'code': '57',
#     'name': 'Bus RATP 57',
#     'directions': 'Laplace RER / (Laplace RER)',
#     'id': '540281'},
#    {'code': '58',
#     'name': 'Bus RATP 58',
#     'directions': 'Vanves-Lycee Michelet / Chatelet',
#     'id': '437502'},
#    {'code': '59',
#     'name': 'Bus RATP 59',
#     'directions': "Gare de Clamart / Place d'Italie",
#     'id': '438932'},
#    {'code': '60',
#     'name': 'Bus RATP 60',
#     'directions': 'Porte de Montmartre / Gambetta - Japon',
#     'id': '562193'},
#    {'code': '61',
#     'name': 'Bus RATP 61',
#     'directions': "Eglise de Pantin-Metro / Place d'Italie",
#     'id': '437447'},
#    {'code': '62',
#     'name': 'Bus RATP 62',
#     'directions': 'Porte de Saint-Cloud (Travaux) / Porte de France',
#     'id': '381518'},
#    {'code': '63',
#     'name': 'Bus RATP 63',
#     'directions': 'Porte de la Muette / Gare de Lyon - Maison de la Ratp',
#     'id': '461302'},
#    {'code': '64',
#     'name': 'Bus RATP 64',
#     'directions': 'Denfert-Rochereau / Porte des Lilas',
#     'id': '438049'},
#    {'code': '66',
#     'name': 'Bus RATP 66',
#     'directions': 'Saint-Ouen - les Docks / Opera',
#     'id': '511236'},
#    {'code': '67',
#     'name': 'Bus RATP 67',
#     'directions': 'Stade Charlety - Porte de Gentilly / Palais Royal - Musee du Louvre',
#     'id': '437451'},
#    {'code': '68',
#     'name': 'Bus RATP 68',
#     'directions': 'Chatillon-Montrouge-Metro / Place de Clichy',
#     'id': '271118'},
#    {'code': '69',
#     'name': 'Bus RATP 69',
#     'directions': 'Champ de Mars / Gambetta - Mairie du 20e',
#     'id': '441410'},
#    {'code': '70',
#     'name': 'Bus RATP 70',
#     'directions': 'Suresnes - de Gaulle / Hotel de Ville',
#     'id': '560305'},
#    {'code': '71',
#     'name': 'Bus RATP 71',
#     'directions': 'Bibliotheque Francois Mitterrand / Porte de la Villette',
#     'id': '436157'},
#    {'code': '72',
#     'name': 'Bus RATP 72',
#     'directions': 'Gare de Lyon - Maison de la Ratp / Parc de Saint-Cloud',
#     'id': '436175'},
#    {'code': '73',
#     'name': 'Bus RATP 73',
#     'directions': "Garenne-Colombes - Charlebourg / Musee d'Orsay",
#     'id': '540542'},
#    {'code': '74',
#     'name': 'Bus RATP 74',
#     'directions': 'Clichy - Berges de Seine / Chatelet',
#     'id': '436181'},
#    {'code': '75',
#     'name': 'Bus RATP 75',
#     'directions': 'Porte de Pantin / Pantheon',
#     'id': '438051'},
#    {'code': '76',
#     'name': 'Bus RATP 76',
#     'directions': 'Louise Michel / Chatelet',
#     'id': '437450'},
#    {'code': '77',
#     'name': 'Bus RATP 77',
#     'directions': 'Joinville-Le-Pont RER / Gare de Lyon',
#     'id': '436156'},
#    {'code': '80',
#     'name': 'Bus RATP 80',
#     'directions': 'Mairie du 18e - Jules Joffrin / Porte de Versailles',
#     'id': '529160'},
#    {'code': '82',
#     'name': 'Bus RATP 82',
#     'directions': 'Hopital Americain / Luxembourg',
#     'id': '574263'},
#    {'code': '83',
#     'name': 'Bus RATP 83',
#     'directions': "Porte d'Ivry / Invalides",
#     'id': '438045'},
#    {'code': '84',
#     'name': 'Bus RATP 84',
#     'directions': 'Alsace / Pantheon',
#     'id': '521841'},
#    {'code': '85',
#     'name': 'Bus RATP 85',
#     'directions': 'Saint-Ouen - les Docks / Chatelet',
#     'id': '511237'},
#    {'code': '86',
#     'name': 'Bus RATP 86',
#     'directions': 'Demi Lune - Parc Zoologique / Champ de Mars',
#     'id': '438044'},
#    {'code': '87',
#     'name': 'Bus RATP 87',
#     'directions': 'Porte de Reuilly / Invalides',
#     'id': '559355'},
#    {'code': '88',
#     'name': 'Bus RATP 88',
#     'directions': "Porte d'Auteuil / Montsouris - Tombe Issoire",
#     'id': '437455'},
#    {'code': '89',
#     'name': 'Bus RATP 89',
#     'directions': 'Gare de Vanves-Malakoff / Porte de France',
#     'id': '202693'},
#    {'code': '91',
#     'name': 'Bus RATP 91',
#     'directions': 'Gare du Nord / Montparnasse 2 - Gare Tgv',
#     'id': '560302'},
#    {'code': '92',
#     'name': 'Bus RATP 92',
#     'directions': "Porte de Champerret / Porte d'Orleans",
#     'id': '521842'},
#    {'code': '93',
#     'name': 'Bus RATP 93',
#     'directions': 'Suresnes-De Gaulle / Invalides',
#     'id': '545728'},
#    {'code': '94',
#     'name': 'Bus RATP 94',
#     'directions': 'Pont de Levallois / Gare Montparnasse',
#     'id': '438052'},
#    {'code': '95',
#     'name': 'Bus RATP 95',
#     'directions': 'Porte de Montmartre / Porte de Vanves - Place Simard',
#     'id': '438931'},
#    {'code': '96',
#     'name': 'Bus RATP 96',
#     'directions': 'Porte des Lilas-Metro / Gare Montparnasse',
#     'id': '436173'},
#    {'code': '101',
#     'name': 'Bus RATP 101',
#     'directions': 'Champigny Sur Marne-Camping / Joinville le Pont-RER',
#     'id': '188524'},
#    {'code': '102',
#     'name': 'Bus RATP 102',
#     'directions': 'Bois-Perrier-RER-Rosny 2 / Gambetta (Travaux)',
#     'id': '335755'},
#    {'code': '103',
#     'name': 'Bus RATP 103',
#     'directions': 'Georges Halgoult / Ecole Veterinaire de Maisons-Alfort',
#     'id': '191931'},
#    {'code': '104',
#     'name': 'Bus RATP 104',
#     'directions': 'Sucy-Bonneuil RER / Ecole Veterinaire de Maisons-Alfort',
#     'id': '191935'},
#    {'code': '105',
#     'name': 'Bus RATP 105',
#     'directions': '(Porte des Lilas-Metro) / Porte des Lilas-Metro',
#     'id': '526633'},
#    {'code': '106',
#     'name': 'Bus RATP 106',
#     'directions': 'Villiers/Marne - le Plessis Trevis / (Villiers/Marne - le Plessis Trevi)',
#     'id': '521859'},
#    {'code': '107',
#     'name': 'Bus RATP 107',
#     'directions': 'La Pie / (Ecole Veterinaire Ma)',
#     'id': '190883'},
#    {'code': '108',
#     'name': 'Bus RATP 108',
#     'directions': 'Champigny Sur Marne-Jeanne Vacher / Joinville le Pont-RER',
#     'id': '188525'},
#    {'code': '109',
#     'name': 'Bus RATP 109',
#     'directions': 'Liberte-Chanzy / Terroirs de France',
#     'id': '281240'},
#    {'code': '110',
#     'name': 'Bus RATP 110',
#     'directions': 'Gare de Villiers Sur Marne / Joinville le Pont-RER',
#     'id': '188526'},
#    {'code': '111',
#     'name': 'Bus RATP 111',
#     'directions': 'Champigny-Saint-Maur RER / Terroirs de France',
#     'id': '248575'},
#    {'code': '112',
#     'name': 'Bus RATP 112',
#     'directions': 'La Varenne - Chennevieres RER / Chateau de Vincennes',
#     'id': '290317'},
#    {'code': '113',
#     'name': 'Bus RATP 113',
#     'directions': 'Terre Ciel / Nogent-Sur-Marne RER',
#     'id': '191790'},
#    {'code': '114',
#     'name': 'Bus RATP 114',
#     'directions': 'Les Coquetiers / Chateau de Vincennes',
#     'id': '214213'},
#    {'code': '115',
#     'name': 'Bus RATP 115',
#     'directions': 'Chateau de Vincennes / Porte des Lilas-Metro',
#     'id': '191966'},
#    {'code': '116',
#     'name': 'Bus RATP 116',
#     'directions': 'Champigny - Saint-Maur RER / Bois-Perrier RER- Rosny 2',
#     'id': '505548'},
#    {'code': '117',
#     'name': 'Bus RATP 117',
#     'directions': 'Prefecture du Val de Marne / Champigny-Saint Maur-RER',
#     'id': '188533'},
#    {'code': '118',
#     'name': 'Bus RATP 118',
#     'directions': 'Van Derheyden / Chateau de Vincennes',
#     'id': '191918'},
#    {'code': '119',
#     'name': 'Bus RATP 119',
#     'directions': 'Abbaye Cimetiere / les Baconnets-RER',
#     'id': '551051'},
#    {'code': '120',
#     'name': 'Bus RATP 120',
#     'directions': "Noisy-Le-Grand - Mont d'Est RER / Nogent Sur Marne-RER",
#     'id': '242379'},
#    {'code': '121',
#     'name': 'Bus RATP 121',
#     'directions': 'Lycee Georges Clemenceau / Mairie de Montreuil',
#     'id': '228492'},
#    {'code': '122',
#     'name': 'Bus RATP 122',
#     'directions': 'Val-De-Fontenay RER / Gallieni-Metro',
#     'id': '219397'},
#    {'code': '123',
#     'name': 'Bus RATP 123',
#     'directions': "Porte d'Auteuil-Metro / Mairie d'Issy-Metro",
#     'id': '191759'},
#    {'code': '124',
#     'name': 'Bus RATP 124',
#     'directions': 'Val de Fontenay-RER / Chateau de Vincennes',
#     'id': '191921'},
#    {'code': '125',
#     'name': 'Bus RATP 125',
#     'directions': "Ecole Veterinaire de Maison-Alfort / Porte d'Orleans-Metro",
#     'id': '197110'},
#    {'code': '126',
#     'name': 'Bus RATP 126',
#     'directions': "Parc de Saint Cloud / Porte d'Orleans-Metro",
#     'id': '178476'},
#    {'code': '127',
#     'name': 'Bus RATP 127',
#     'directions': 'Place de la Resistance / Croix de Chavaux-Metro',
#     'id': '496473'},
#    {'code': '128',
#     'name': 'Bus RATP 128',
#     'directions': "Robinson RER / Porte d'Orleans",
#     'id': '521852'},
#    {'code': '129',
#     'name': 'Bus RATP 129',
#     'directions': 'Mairie de Montreuil / Porte des Lilas',
#     'id': '358769'},
#    {'code': '131',
#     'name': 'Bus RATP 131',
#     'directions': "Rungis - la Fraternelle RER / Porte d'Italie-Metro",
#     'id': '438934'},
#    {'code': '132',
#     'name': 'Bus RATP 132',
#     'directions': 'Moulin Vert / Bibliotheque Francois Mitterrand',
#     'id': '255132'},
#    {'code': '133',
#     'name': 'Bus RATP 133',
#     'directions': "Le Bourget RER / Bois d'Ecouen",
#     'id': '221621'},
#    {'code': '137',
#     'name': 'Bus RATP 137',
#     'directions': 'Zone Industrielle Nord / Porte de Clignancourt - Croisset',
#     'id': '521840'},
#    {'code': '138',
#     'name': 'Bus RATP 138',
#     'directions': "Gare d'Ermont-Eaubonne RER / Saint-Ouen RER",
#     'id': '515613'},
#    {'code': '139',
#     'name': 'Bus RATP 139',
#     'directions': 'Quai de Seine / Porte de la Villette',
#     'id': '563332'},
#    {'code': '140',
#     'name': 'Bus RATP 140',
#     'directions': "Gare d'Argenteuil / Clichy - Berges de Seine",
#     'id': '511244'},
#    {'code': '141',
#     'name': 'Bus RATP 141',
#     'directions': 'Madeleine Danielou / Boulevard de la Seine',
#     'id': '209741'},
#    {'code': '143',
#     'name': 'Bus RATP 143',
#     'directions': 'Rosny-Sous-Bois RER / la Courneuve - Aubervilliers RER',
#     'id': '319758'},
#    {'code': '144',
#     'name': 'Bus RATP 144',
#     'directions': 'Rueil-Malmaison RER / la Defense-Metro-RER-Tramway',
#     'id': '209744'},
#    {'code': '145',
#     'name': 'Bus RATP 145',
#     'directions': 'Cimetiere de Villemomble / Eglise de Pantin-Metro',
#     'id': '178666'},
#    {'code': '146',
#     'name': 'Bus RATP 146',
#     'directions': '(Montfermeil-Les Bosquets) / le Bourget-RER',
#     'id': '498287'},
#    {'code': '147',
#     'name': 'Bus RATP 147',
#     'directions': 'Avenue Ronsard / (Ronsard)',
#     'id': '506185'},
#    {'code': '148',
#     'name': 'Bus RATP 148',
#     'directions': "Musee de l'Air et de l'Espace / Bobigny - Pablo Picasso",
#     'id': '214654'},
#    {'code': '150',
#     'name': 'Bus RATP 150',
#     'directions': 'Gare de Pierrefitte - Stains RER / Porte de la Villette',
#     'id': '207208'},
#    {'code': '151',
#     'name': 'Bus RATP 151',
#     'directions': 'Jouhaux - Blum / Porte de Pantin',
#     'id': '194290'},
#    {'code': '152',
#     'name': 'Bus RATP 152',
#     'directions': 'Zac des Tulipes Nord / Porte de la Villette',
#     'id': '244743'},
#    {'code': '153',
#     'name': 'Bus RATP 153',
#     'directions': 'Moulin Neuf / Porte de la Chapelle',
#     'id': '208670'},
#    {'code': '157',
#     'name': 'Bus RATP 157',
#     'directions': 'Boulevard de la Seine / Pont de Neuilly-Metro',
#     'id': '209746'},
#    {'code': '158',
#     'name': 'Bus RATP 158',
#     'directions': 'Rueil-Malmaison RER / Pont de Neuilly-Metro',
#     'id': '554467'},
#    {'code': '159',
#     'name': 'Bus RATP 159',
#     'directions': 'Cite du Vieux Pont / la Defense-Metro-RER-Tramway',
#     'id': '209747'},
#    {'code': '160',
#     'name': 'Bus RATP 160',
#     'directions': 'Nanterre-Prefecture RER / Pont de Saint-Cloud - Albert Kahn',
#     'id': '384988'},
#    {'code': '162',
#     'name': 'Bus RATP 162',
#     'directions': 'Val Fleury RER / Villejuif - Louis Aragon',
#     'id': '545732'},
#    {'code': '163',
#     'name': 'Bus RATP 163',
#     'directions': 'Centre Madeleine Danielou / Nanterre - Prefecture RER',
#     'id': '424599'},
#    {'code': '164',
#     'name': 'Bus RATP 164',
#     'directions': 'College Claude Monet / Porte de Champerret',
#     'id': '209721'},
#    {'code': '165',
#     'name': 'Bus RATP 165',
#     'directions': 'Asnieres - 18 Juin 194 Porte de Champerret',
#     'id': '554469'},
#    {'code': '166',
#     'name': 'Bus RATP 166',
#     'directions': 'Zac des Louvresses / Porte de Clignancourt',
#     'id': '421223'},
#    {'code': '167',
#     'name': 'Bus RATP 167',
#     'directions': 'Pont de Levallois - Becon / Piscine - Patinoire',
#     'id': '541279'},
#    {'code': '168',
#     'name': 'Bus RATP 168',
#     'directions': 'Chantepie / Saint-Denis - Universite',
#     'id': '505547'},
#    {'code': '169',
#     'name': 'Bus RATP 169',
#     'directions': 'Pont de Sevres / Hopital Europeen Georges Pompidou',
#     'id': '468700'},
#    {'code': '170',
#     'name': 'Bus RATP 170',
#     'directions': 'Gare de Saint-Denis RER / Porte des Lilas',
#     'id': '560324'},
#    {'code': '171',
#     'name': 'Bus RATP 171',
#     'directions': 'Chateau de Versailles / Pont de Sevres-Metro',
#     'id': '208981'},
#    {'code': '172',
#     'name': 'Bus RATP 172',
#     'directions': 'Hopital Henri Mondor / Bourg-La-Reine RER',
#     'id': '302261'},
#    {'code': '173',
#     'name': 'Bus RATP 173',
#     'directions': 'La Courneuve - 8 Mai 1945 / Porte de Clichy',
#     'id': '529136'},
#    {'code': '174',
#     'name': 'Bus RATP 174',
#     'directions': 'Saint-Ouen RER / la Defense-Metro-RER-Tramway',
#     'id': '511245'},
#    {'code': '175',
#     'name': 'Bus RATP 175',
#     'directions': 'Gabriel Peri-Metro / Porte de Saint-Cloud',
#     'id': '209422'},
#    {'code': '176',
#     'name': 'Bus RATP 176',
#     'directions': 'Petit Gennevilliers / Pont de Neuilly-Metro',
#     'id': '209723'},
#    {'code': '177',
#     'name': 'Bus RATP 177',
#     'directions': 'Zone Industrielle Nord / Gabriel Peri-Metro',
#     'id': '209443'},
#    {'code': '178',
#     'name': 'Bus RATP 178',
#     'directions': 'Vieux Chemin de St Denis - C Com / la Defense-Metro-RER-Tramway',
#     'id': '307175'},
#    {'code': '179',
#     'name': 'Bus RATP 179',
#     'directions': 'Robinson RER / Pont de Sevres',
#     'id': '551059'},
#    {'code': '180',
#     'name': 'Bus RATP 180',
#     'directions': 'Villejuif - Louis Aragon / Charenton-Ecoles',
#     'id': '560323'},
#    {'code': '181',
#     'name': 'Bus RATP 181',
#     'directions': 'Creteil-Gaite Rn 19 / Ecole Veterinaire-Metro',
#     'id': '188534'},
#    {'code': '182',
#     'name': 'Bus RATP 182',
#     'directions': "Villeneuve-Triage RER / Mairie d'Ivry-Metro",
#     'id': '197280'},
#    {'code': '183',
#     'name': 'Bus RATP 183',
#     'directions': "Aeroport d'Orly 4 / Marche International de Rungis",
#     'id': '530086'},
#    {'code': '184',
#     'name': 'Bus RATP 184',
#     'directions': "Fresnes-Pasteur / Porte d'Italie - Helene Boucher",
#     'id': '346943'},
#    {'code': '185',
#     'name': 'Bus RATP 185',
#     'directions': "Choisy Sud / (Porte d'Italie - Choisy Sud)",
#     'id': '229301'},
#    {'code': '186',
#     'name': 'Bus RATP 186',
#     'directions': "Rond-Point Roosevelt / Porte d'Italie-Metro",
#     'id': '197283'},
#    {'code': '187',
#     'name': 'Bus RATP 187',
#     'directions': "Charcot - Zola / Porte d'Orleans - Metro",
#     'id': '194222'},
#    {'code': '188',
#     'name': 'Bus RATP 188',
#     'directions': "Rosenberg / Porte d'Orleans",
#     'id': '521858'},
#    {'code': '189',
#     'name': 'Bus RATP 189',
#     'directions': 'Porte de Saint-Cloud-Metro / Georges Pompidou',
#     'id': '246344'},
#    {'code': '190',
#     'name': 'Bus RATP 190',
#     'directions': "(Eglise de Meudon) / Mairie d'Issy",
#     'id': '361330'},
#    {'code': '191',
#     'name': 'Bus RATP 191',
#     'directions': 'Clamart-Place du Garde / Porte de Vanves-Metro',
#     'id': '188520'},
#    {'code': '192',
#     'name': 'Bus RATP 192',
#     'directions': 'Marche International de Rungis (La) / Robinson RER',
#     'id': '254621'},
#    {'code': '193',
#     'name': 'Bus RATP 193',
#     'directions': "Mairie de l'Hay-Les-Roses / Arcueil - Lenine",
#     'id': '455607'},
#    {'code': '194',
#     'name': 'Bus RATP 194',
#     'directions': "Lycee Polyvalent / Porte d'Orleans",
#     'id': '545757'},
#    {'code': '195',
#     'name': 'Bus RATP 195',
#     'directions': 'Robinson RER / Pierre Semard - Chatillon-Montrouge',
#     'id': '547387'},
#    {'code': '196',
#     'name': 'Bus RATP 196',
#     'directions': 'Antony RER / Massy-Palaiseau RER',
#     'id': '196122'},
#    {'code': '197',
#     'name': 'Bus RATP 197',
#     'directions': "Avenue Saint Marc / Porte d'Orleans",
#     'id': '532644'},
#    {'code': '199',
#     'name': 'Bus RATP 199',
#     'directions': 'La Rocade-Lycee / Massy-Palaiseau-RER',
#     'id': '195729'},
#    {'code': '201',
#     'name': 'Bus RATP 201',
#     'directions': 'Diderot - la Plage / Porte Doree',
#     'id': '438923'},
#    {'code': '203',
#     'name': 'Bus RATP 203',
#     'directions': 'Bougainville / Neuilly-Plaisance RER',
#     'id': '520539'},
#    {'code': '206',
#     'name': 'Bus RATP 206',
#     'directions': "Le Plessis-Trevise-Place de Verdun / Noisy le Grand Mont d'Est-RER",
#     'id': '541656'},
#    {'code': '207',
#     'name': 'Bus RATP 207',
#     'directions': "Hopital de la Queue-En-Brie / Noisy-Le-Grand - Mont d'Est RER",
#     'id': '496387'},
#    {'code': '208b',
#     'name': 'Bus RATP 208b',
#     'directions': 'Place de Verdun / Champigny - Saint-Maur RER',
#     'id': '523767'},
#    {'code': '209',
#     'name': 'Bus RATP 209',
#     'directions': 'Place de Beilstein / V-Sur-Marne -Le Plessis-Trevise RER',
#     'id': '540278'},
#    {'code': '210',
#     'name': 'Bus RATP 210',
#     'directions': 'Villiers-Sur-Marne - le Plessis RER / Chateau de Vincennes',
#     'id': '480113'},
#    {'code': '211',
#     'name': 'Bus RATP 211',
#     'directions': 'Terre Ciel / Torcy RER',
#     'id': '569917'},
#    {'code': '212',
#     'name': 'Bus RATP 212',
#     'directions': 'Emerainville-Pontault-Combault / Noisy-Champs RER - Descartes',
#     'id': '513341'},
#    {'code': '213',
#     'name': 'Bus RATP 213',
#     'directions': 'Le Village / Chelles - Gournay RER',
#     'id': '365087'},
#    {'code': '214',
#     'name': 'Bus RATP 214',
#     'directions': 'Gagny-Roger Salengro / Neuilly-Plaisance RER',
#     'id': '191792'},
#    {'code': '215',
#     'name': 'Bus RATP 215',
#     'directions': "Vincennes RER - Republique / Gare d'Austerlitz",
#     'id': '437445'},
#    {'code': '216',
#     'name': 'Bus RATP 216',
#     'directions': 'Denfert-Rochereau-Metro-RER / Marche International de Rungis',
#     'id': '523773'},
#    {'code': '217',
#     'name': 'Bus RATP 217',
#     'directions': 'Hotel de Ville de Creteil / RER de Vitry-Sur-Seine',
#     'id': '521867'},
#    {'code': '220',
#     'name': 'Bus RATP 220',
#     'directions': 'Torcy-RER / Bry-Sur-Marne RER',
#     'id': '220011'},
#    {'code': '221',
#     'name': 'Bus RATP 221',
#     'directions': 'Gagny-Pointe de Gournay / Gallieni-Metro',
#     'id': '188353'},
#    {'code': '234',
#     'name': 'Bus RATP 234',
#     'directions': "Mairie de Livry-Gargan / Fort d'Aubervilliers-Metro",
#     'id': '498290'},
#    {'code': '235',
#     'name': 'Bus RATP 235',
#     'directions': 'Europe / Gabriel Peri-Metro',
#     'id': '209424'},
#    {'code': '237',
#     'name': 'Bus RATP 237',
#     'directions': 'Epinay-Sur-Seine - Gare / Porte de St Ouen - Hopital Bichat',
#     'id': '513343'},
#    {'code': '238',
#     'name': 'Bus RATP 238',
#     'directions': 'Saint-Gratien - RER / Pont de Levallois - Becon',
#     'id': '270277'},
#    {'code': '239',
#     'name': 'Bus RATP 239',
#     'directions': 'Mediatheque / Rosa Parks - Curial',
#     'id': '306409'},
#    {'code': '241',
#     'name': 'Bus RATP 241',
#     'directions': "Rueil-Malmaison RER / Porte d'Auteuil-Metro",
#     'id': '209751'},
#    {'code': '244',
#     'name': 'Bus RATP 244',
#     'directions': 'Rueil-Malmaison RER / Porte Maillot - Metro - RER',
#     'id': '277304'},
#    {'code': '247',
#     'name': 'Bus RATP 247',
#     'directions': 'Stade Charles Sage / Garonor',
#     'id': '223506'},
#    {'code': '248',
#     'name': 'Bus RATP 248',
#     'directions': "Drancy RER / Fort d'Aubervilliers",
#     'id': '529153'},
#    {'code': '249',
#     'name': 'Bus RATP 249',
#     'directions': 'Dugny-Place Valerie Andre / Porte des Lilas',
#     'id': '441365'},
#    {'code': '250',
#     'name': 'Bus RATP 250',
#     'directions': "Fontaine Cypierre Zi / Fort d'Aubervilliers",
#     'id': '360724'},
#    {'code': '251',
#     'name': 'Bus RATP 251',
#     'directions': 'Aulnay-Sous-Bois RER / Bobigny - Pablo Picasso',
#     'id': '506200'},
#    {'code': '252',
#     'name': 'Bus RATP 252',
#     'directions': 'Garges les Gonesse-RER / Porte de la Chapelle-Metro',
#     'id': '194761'},
#    {'code': '253',
#     'name': 'Bus RATP 253',
#     'directions': 'Moulin Neuf / la Courneuve - Aubervilliers RER',
#     'id': '396633'},
#    {'code': '254',
#     'name': 'Bus RATP 254',
#     'directions': "Gare d'Enghien-Les-Bains / Gare de Saint-Denis RER",
#     'id': '271717'},
#    {'code': '255',
#     'name': 'Bus RATP 255',
#     'directions': 'Rond-Point de la Lutece / Porte de Clignancourt',
#     'id': '424603'},
#    {'code': '256',
#     'name': 'Bus RATP 256',
#     'directions': "Gare d'Enghien les Bains / Saint-Denis - Universite",
#     'id': '365090'},
#    {'code': '258',
#     'name': 'Bus RATP 258',
#     'directions': 'La Jonchere / la Defense-Metro-RER-Tramway',
#     'id': '331759'},
#    {'code': '259',
#     'name': 'Bus RATP 259',
#     'directions': 'Saint-Germain-En-Laye RER / Nanterre - Anatole France',
#     'id': '331308'},
#    {'code': '260',
#     'name': 'Bus RATP 260',
#     'directions': 'Gambetta / Suzanne Lenglen',
#     'id': '384990'},
#    {'code': '261',
#     'name': 'Bus RATP 261',
#     'directions': 'Bongarde / Gare de Franconville',
#     'id': '271719'},
#    {'code': '262',
#     'name': 'Bus RATP 262',
#     'directions': 'Gare de Maisons-Laffitte-RER / Pont de Bezons',
#     'id': '209727'},
#    {'code': '263',
#     'name': 'Bus RATP 263',
#     'directions': 'Place de la Boule - Gambetta / Suresnes de Gaulle (Circulaire)',
#     'id': '540554'},
#    {'code': '268',
#     'name': 'Bus RATP 268',
#     'directions': 'Villiers le Bel - RER / Saint-Denis - Universite',
#     'id': '365088'},
#    {'code': '269',
#     'name': 'Bus RATP 269',
#     'directions': "Hotel de Ville d'Attainville / Garges-Sarcelles RER",
#     'id': '454920'},
#    {'code': '270',
#     'name': 'Bus RATP 270',
#     'directions': 'Villiers le Bel - Arnouville RER / la Cerisaie',
#     'id': '365100'},
#    {'code': '272',
#     'name': 'Bus RATP 272',
#     'directions': "Gare de Sartrouville-RER / Gare d'Argenteuil",
#     'id': '209735'},
#    {'code': '274',
#     'name': 'Bus RATP 274',
#     'directions': 'Porte Maillot - Pershing / Saint-Denis RER',
#     'id': '513344'},
#    {'code': '275',
#     'name': 'Bus RATP 275',
#     'directions': 'Pont de Levallois-Becon-Metro / la Defense-Metro-RER-Tramway',
#     'id': '209758'},
#    {'code': '276',
#     'name': 'Bus RATP 276',
#     'directions': 'La Defense / Asn-Gennevilliers-Les Courtilles',
#     'id': '347599'},
#    {'code': '278',
#     'name': 'Bus RATP 278',
#     'directions': 'Les Bruyeres / la Defense-Metro-RER-Tramway',
#     'id': '209760'},
#    {'code': '281',
#     'name': 'Bus RATP 281',
#     'directions': 'Creteil-Europarc / Joinville-Le-Pont RER',
#     'id': '188536'},
#    {'code': '285',
#     'name': 'Bus RATP 285',
#     'directions': "Juvisy-RER / Porte de l'Essonne",
#     'id': '468701'},
#    {'code': '286',
#     'name': 'Bus RATP 286',
#     'directions': 'Antony RER (Celle La) / Villejuif - Louis Aragon',
#     'id': '194228'},
#    {'code': '289',
#     'name': 'Bus RATP 289',
#     'directions': 'Georges Pompidou / Porte de Saint-Cloud-Metro',
#     'id': '270280'},
#    {'code': '290',
#     'name': 'Bus RATP 290',
#     'directions': 'La Boursidiere / Issy - Val de Seine',
#     'id': '268768'},
#    {'code': '291',
#     'name': 'Bus RATP 291',
#     'directions': 'La Cheminee / Pont de Sevres',
#     'id': '523775'},
#    {'code': '292',
#     'name': 'Bus RATP 292',
#     'directions': "Zac les Gatines - Cap Jean d'Hers / Athis-Mons - Porte de l'Essonne",
#     'id': '229287'},
#    {'code': '294',
#     'name': 'Bus RATP 294',
#     'directions': 'Igny RER / Pierre Semard - Chatillon-Montrouge',
#     'id': '416929'},
#    {'code': '297',
#     'name': 'Bus RATP 297',
#     'directions': 'Place Charles Steber / Antony RER',
#     'id': '459608'},
#    {'code': '299',
#     'name': 'Bus RATP 299',
#     'directions': "Place Lucien Boilleau / Porte d'Orleans - Ernest Reyer",
#     'id': '322564'},
#    {'code': '301',
#     'name': 'Bus RATP 301',
#     'directions': 'Pablo Picasso-Metro / Val de Fontenay-RER',
#     'id': '192004'},
#    {'code': '302',
#     'name': 'Bus RATP 302',
#     'directions': '6 Routes-Tramway / Gare du Nord',
#     'id': '194764'},
#    {'code': '303',
#     'name': 'Bus RATP 303',
#     'directions': "Bobigny-Pablo Picasso / Noisy le Grand Mont d'Est-RER",
#     'id': '242387'},
#    {'code': '304',
#     'name': 'Bus RATP 304',
#     'directions': 'Place de la Boule / les Courtilles',
#     'id': '541268'},
#    {'code': '306',
#     'name': 'Bus RATP 306',
#     'directions': "Noisy le Grand-Mont d'Est-RER / Saint Maur-Creteil-RER",
#     'id': '242384'},
#    {'code': '308',
#     'name': 'Bus RATP 308',
#     'directions': 'Villiers Sur Marne-Le Plessis-Trevi / Prefecture Val de Marne',
#     'id': '188523'},
#    {'code': '310',
#     'name': 'Bus RATP 310',
#     'directions': 'Noisy - Champs RER / les Yvris - Noisy-Le-Grand RER',
#     'id': '242385'},
#    {'code': '312',
#     'name': 'Bus RATP 312',
#     'directions': 'Noisy-Champs RER - Descartes / Noisy-Champs RER - Descartes',
#     'id': '365086'},
#    {'code': '317',
#     'name': 'Bus RATP 317',
#     'directions': 'Nogent-Le-Perreux RER / Hotel de Ville de Creteil',
#     'id': '191948'},
#    {'code': '318',
#     'name': 'Bus RATP 318',
#     'directions': 'Raymond Queneau - Route de Noisy / Chateau de Vincennes',
#     'id': '315511'},
#    {'code': '319',
#     'name': 'Bus RATP 319',
#     'directions': 'Marche International de Rungis / Massy-Palaiseau RER',
#     'id': '545731'},
#    {'code': '320',
#     'name': 'Bus RATP 320',
#     'directions': "Noisy le Grand Mont d'Est / Noisy le Grand Mont d'Est",
#     'id': '242386'},
#    {'code': '321',
#     'name': 'Bus RATP 321',
#     'directions': 'Torcy RER / Lognes RER',
#     'id': '399720'},
#    {'code': '322',
#     'name': 'Bus RATP 322',
#     'directions': 'Bobigny-Pablo Picasso / Mairie de Montreuil',
#     'id': '192062'},
#    {'code': '323',
#     'name': 'Bus RATP 323',
#     'directions': 'Gambetta / Chatillon - Montrouge-Metro',
#     'id': '399722'},
#    {'code': '325',
#     'name': 'Bus RATP 325',
#     'directions': 'Chateau de Vincennes / Quai de la Gare',
#     'id': '529146'},
#    {'code': '330',
#     'name': 'Bus RATP 330',
#     'directions': "Raymond Queneau - Anatole France / Fort d'Aubervilliers",
#     'id': '529159'},
#    {'code': '337',
#     'name': 'Bus RATP 337',
#     'directions': 'Gare de Pierrefitte - Stains RER / Zone Artisanale du Moutier',
#     'id': '365095'},
#    {'code': '340',
#     'name': 'Bus RATP 340',
#     'directions': "Gare d'Argenteuil / Gabriel Peri-Metro",
#     'id': '514954'},
#    {'code': '341',
#     'name': 'Bus RATP 341',
#     'directions': 'Charles de Gaulle - Etoile / Porte de Clignancourt - Croisset',
#     'id': '529162'},
#    {'code': '346',
#     'name': 'Bus RATP 346',
#     'directions': '(Place de la Liberation) / Bois-Perrier RER-Rosny 2',
#     'id': '506203'},
#    {'code': '349',
#     'name': 'Bus RATP 349',
#     'directions': "Route de l'Arpenteur-Adp / Parc des Expositions RER",
#     'id': '529166'},
#    {'code': '350',
#     'name': 'Bus RATP 350',
#     'directions': 'Roissypole - Gare - RER / Porte de la Chapelle',
#     'id': '572216'},
#    {'code': '351',
#     'name': 'Bus RATP 351',
#     'directions': 'Roissypole / Nation',
#     'id': '516779'},
#    {'code': '353',
#     'name': 'Bus RATP 353',
#     'directions': 'Saint-Denis - Universite / Zac Landy Nord',
#     'id': '365522'},
#    {'code': '355',
#     'name': 'Bus RATP 355',
#     'directions': 'Lycee Jean-Jacques Rousseau / (Circulaire)',
#     'id': '246734'},
#    {'code': '356',
#     'name': 'Bus RATP 356',
#     'directions': 'Marche des Mortefontaines / Cite Floreal',
#     'id': '365083'},
#    {'code': '360',
#     'name': 'Bus RATP 360',
#     'directions': 'Hopital de Garches / la Defense-Metro-RER-Tramway',
#     'id': '209761'},
#    {'code': '361',
#     'name': 'Bus RATP 361',
#     'directions': "Gare d'Argenteuil / Gare de Pierrefitte - Stains RER",
#     'id': '367542'},
#    {'code': '366',
#     'name': 'Bus RATP 366',
#     'directions': 'Eglise de Colombes / Asnieres - Bords de Seine',
#     'id': '264828'},
#    {'code': '367',
#     'name': 'Bus RATP 367',
#     'directions': 'Rueil-Malmaison RER / Pont de Bezons',
#     'id': '209762'},
#    {'code': '368',
#     'name': 'Bus RATP 368',
#     'directions': 'Garges - Sarcelles RER / Place du Souvenir Francais',
#     'id': '221225'},
#    {'code': '370',
#     'name': 'Bus RATP 370',
#     'directions': 'Villiers le Bel - Arnouville RER / Marche de Saint-Brice',
#     'id': '365099'},
#    {'code': '372',
#     'name': 'Bus RATP 372',
#     'directions': 'M-Alfort-Louis Fiche (Scolaire) / M-Alfort-Alforville RER',
#     'id': '188539'},
#    {'code': '378',
#     'name': 'Bus RATP 378',
#     'directions': 'Les Courtilles / Nanterre-Ville RER',
#     'id': '448186'},
#    {'code': '379',
#     'name': 'Bus RATP 379',
#     'directions': 'La Croix de Berny RER / Velizy 2',
#     'id': '270268'},
#    {'code': '380',
#     'name': 'Bus RATP 380',
#     'directions': 'Villejuif - Louis Aragon / Vache Noire - Centre Commercial',
#     'id': '529147'},
#    {'code': '382',
#     'name': 'Bus RATP 382',
#     'directions': 'Watteau-Rondenay / Pont de Rungis RER',
#     'id': '575572'},
#    {'code': '385',
#     'name': 'Bus RATP 385',
#     'directions': "Juvisy-RER / Gare d'Epinay-Sur-Orge RER",
#     'id': '464657'},
#    {'code': '388',
#     'name': 'Bus RATP 388',
#     'directions': "Bourg-La-Reine / Porte d'Orleans",
#     'id': '574261'},
#    {'code': '389',
#     'name': 'Bus RATP 389',
#     'directions': 'Georges Pompidou / H de Ville de Boulogne-Billancourt',
#     'id': '431762'},
#    {'code': '390',
#     'name': 'Bus RATP 390',
#     'directions': 'Bourg-La-Reine RER / Europe Sud',
#     'id': '267330'},
#    {'code': '391',
#     'name': 'Bus RATP 391',
#     'directions': 'Pont Royal RER / Gare de Vanves-Malakoff',
#     'id': '270284'},
#    {'code': '393',
#     'name': 'Bus RATP 393',
#     'directions': 'Sucy-Bonneuil RER / Carrefour de la Resistance',
#     'id': '188568'},
#    {'code': '394',
#     'name': 'Bus RATP 394',
#     'directions': 'Bourg-La-Reine RER / Issy - Val de Seine RER',
#     'id': '267347'},
#    {'code': '395',
#     'name': 'Bus RATP 395',
#     'directions': 'Antony RER / Pave Blanc',
#     'id': '556084'},
#    {'code': '396',
#     'name': 'Bus RATP 396',
#     'directions': 'Marche International de Rungis / la Croix de Berny RER',
#     'id': '229289'},
#    {'code': '399',
#     'name': 'Bus RATP 399',
#     'directions': 'Juvisy RER / Massy-Palaiseau RER',
#     'id': '478204'},
#    {'code': '421',
#     'name': 'Bus RATP 421',
#     'directions': "Gare de Vaires - Torcy / Gare d'Emerainville-Pontault",
#     'id': '513340'},
#    {'code': '426',
#     'name': 'Bus RATP 426',
#     'directions': 'La Celle St-Cloud - Gare Sncf / Pont de Sevres',
#     'id': '254620'},
#    {'code': '459',
#     'name': 'Bus RATP 459',
#     'directions': 'Henri Regnault / Gare de Saint-Cloud',
#     'id': '237732'},
#    {'code': '467',
#     'name': 'Bus RATP 467',
#     'directions': 'Rueil-Malmaison RER / Pont de Sevres-Metro',
#     'id': '209765'},
#    {'code': '471',
#     'name': 'Bus RATP 471',
#     'directions': 'Gare de Versailles - Rive Droite / les Coteaux-T2',
#     'id': '453565'},
#    {'code': '485',
#     'name': 'Bus RATP 485',
#     'directions': 'Delalande Pasteur / Noyer - Renard',
#     'id': '574265'},
#    {'code': '486',
#     'name': 'Bus RATP 486',
#     'directions': "Juvisy RER / Porte de l'Essonne",
#     'id': '464659'},
#    {'code': '487',
#     'name': 'Bus RATP 487',
#     'directions': "Juvisy RER / Athis-Mons - Porte de l'Essonne",
#     'id': '464661'},
#    {'code': '488',
#     'name': 'Bus RATP 488',
#     'directions': 'Juvisy RER / Place Henri Deudon',
#     'id': '464663'},
#    {'code': '492',
#     'name': 'Bus RATP 492',
#     'directions': 'Pres Saint-Martin / Place de la Liberation',
#     'id': '229057'},
#    {'code': '512',
#     'name': 'Bus RATP 512',
#     'directions': "Front Populaire-Gardinoux / Mairie d'Aubervilliers",
#     'id': '203636'},
#    {'code': '520',
#     'name': 'Bus RATP 520',
#     'directions': 'Les Hauts de Bry / les Boullereaux',
#     'id': '480115'},
#    {'code': '545',
#     'name': 'Bus RATP 545',
#     'directions': 'Noisy-Le-Sec RER / Louise Michel',
#     'id': '358770'},
#    {'code': '564',
#     'name': 'Bus RATP 564',
#     'directions': 'College la Malmaison / les Pince-Vins',
#     'id': '541283'},
#    {'code': '565',
#     'name': 'Bus RATP 565',
#     'directions': 'Eglise de Buzenval / Mairie de Rueil',
#     'id': '209779'},
#    {'code': '566',
#     'name': 'Bus RATP 566',
#     'directions': "Rue de l'Industrie / Eglise de Colombes",
#     'id': '412080'},
#    {'code': '595',
#     'name': 'Bus RATP 595',
#     'directions': 'Robinson RER / la Boursidiere',
#     'id': '545753'},
#    {'code': 'As-Sure',
#     'name': 'Bus RATP As-Sure',
#     'directions': 'General de Gaulle / Circuit Circulaire',
#     'id': '541273'},
#    {'code': 'Audonie',
#     'name': 'Bus RATP Audonie',
#     'directions': 'Payret / Debain',
#     'id': '515612'},
#    {'code': 'Batigno',
#     'name': 'Bus RATP Batigno',
#     'directions': 'Porte de Saint-Ouen-Hopital Bichat / (Porte de Saint-Ouen-Hop. Bichat)',
#     'id': '531138'},
#    {'code': 'Bievres',
#     'name': 'Bus RATP Bievres',
#     'directions': "La Traverse Bievre-Montsouris / Place de l'Abbe Georges Henocque",
#     'id': '560307'},
#    {'code': 'Charonn',
#     'name': 'Bus RATP Charonn',
#     'directions': 'Gambetta / la Traverse de Charonne',
#     'id': '192068'},
#    {'code': 'Choisyb',
#     'name': 'Bus RATP Choisyb',
#     'directions': 'Circulaire / Serv Urbain de Choisy le Roi',
#     'id': '301324'},
#    {'code': 'Clamibu',
#     'name': 'Bus RATP Clamibu',
#     'directions': 'Maison de Quartier - Andre Charre / Gare de Clamart',
#     'id': '203643'},
#    {'code': 'Eolien',
#     'name': 'Bus RATP Eolien',
#     'directions': 'Cimetiere Nouveau / Conservatoire-Pressense',
#     'id': '554471'},
#    {'code': 'Hironde',
#     'name': 'Bus RATP Hironde',
#     'directions': 'Hotel de Ville / (Hotel de Ville.)',
#     'id': '547390'},
#    {'code': 'Lbleue',
#     'name': 'Bus RATP Lbleue',
#     'directions': "Cimetiere du Mont Valerien / Chemin de l'Ile",
#     'id': '209772'},
#    {'code': 'avette',
#     'name': 'Bus RATP Navette',
#     'directions': 'Les Alouettes / les Parapluies-Val de Fontenay',
#     'id': '192084'},
#    {'code': 'ey-Fla',
#     'name': 'Bus RATP Ney-Fla',
#     'directions': "Porte d'Aubervilliers - Oberle / (Porte d'Aubervilliers - Oberle)",
#     'id': '530083'},
#    {'code': 'Orlybus',
#     'name': 'Bus RATP Orlybus',
#     'directions': "Aeroport d'Orly 1-2-3 / Denfert-Rochereau-Metro-RER",
#     'id': '560304'},
#    {'code': 'Pc',
#     'name': 'Bus RATP Pc',
#     'directions': "Porte d'Asnieres - Marguerite Long / Pont du Garigliano - Hopital Egp",
#     'id': '560326'},
#    {'code': 'Petit-F',
#     'name': 'Bus RATP Petit-F',
#     'directions': 'Su Circulaire Fontenay / Division Leclerc.',
#     'id': '203642'},
#    {'code': 'Port',
#     'name': 'Bus RATP Port',
#     'directions': '( les Courtilles) / Asnieres - Gennevilliers',
#     'id': '488294'},
#    {'code': 'Ptitbus',
#     'name': 'Bus RATP Ptitbus',
#     'directions': 'Marche - Mairie / Marche - Mairie',
#     'id': '415398'},
#    {'code': 'River',
#     'name': 'Bus RATP River',
#     'directions': 'Gennevilliers RER / Gabriel Peri-Metro',
#     'id': '526635'},
#    {'code': 'Roissyb',
#     'name': 'Bus RATP Roissyb',
#     'directions': 'Aeroport Cdg T3 - Roissypole / Opera',
#     'id': '526634'},
#    {'code': 'Subb',
#     'name': 'Bus RATP Subb',
#     'directions': 'Hotel de Ville - les Passages / Hotel de Ville de Boulogne',
#     'id': '388847'},
#    {'code': 'hiais',
#     'name': 'Bus RATP Thiais',
#     'directions': 'La Galaise / Ferme de Grignon',
#     'id': '258856'},
#    {'code': 'illbus',
#     'name': 'Bus RATP Tillbus',
#     'directions': "Place du Vel'D'Hiv / Place du Vel'D'Hiv",
#     'id': '370403'},
#    {'code': 'im',
#     'name': 'Bus RATP Tim',
#     'directions': 'Gare de Bellevue / (Gare de Bellevue.)',
#     'id': '554474'},
#    {'code': 'ub',
#     'name': 'Bus RATP Tub',
#     'directions': 'Blanqui Carnot / la Mare a la Veuve',
#     'id': '506198'},
#    {'code': 'uc',
#     'name': 'Bus RATP Tuc',
#     'directions': 'Rue Martre - Mairie de Clichy / Rue Martre - Mairie de Clichy',
#     'id': '209429'},
#    {'code': 'uvim',
#     'name': 'Bus RATP Tuvim',
#     'directions': "Mairie d'Issy-Metro / Circuits Grand Issy et Centre",
#     'id': '208991'},
#    {'code': 'vm',
#     'name': 'Bus RATP Tvm',
#     'directions': 'Saint-Maur - Creteil RER / la Croix de Berny RER',
#     'id': '194216'},
#    {'code': 'V2',
#     'name': 'Bus RATP V2',
#     'directions': 'Domaine Cherioux / Pasteur',
#     'id': '229293'},
#    {'code': 'V3',
#     'name': 'Bus RATP V3',
#     'directions': 'Centre Ville / Su Cachan',
#     'id': '197291'},
#    {'code': 'V4',
#     'name': 'Bus RATP V4',
#     'directions': 'Hotel de Ville - Centre / Circulaire',
#     'id': '560308'},
#    {'code': 'V5',
#     'name': 'Bus RATP V5',
#     'directions': 'Gabriel Peri - Soleil Levant / Service Urbain de Gentilly',
#     'id': '560314'},
#    {'code': 'V6',
#     'name': 'Bus RATP V6',
#     'directions': 'Leo Lagrange / Service Urbain du Kremlin Bicetre',
#     'id': '560321'},
#    {'code': 'V7',
#     'name': 'Bus RATP V7',
#     'directions': 'Les Dahlias / Villejuif - Louis Aragon',
#     'id': '229294'},
#    {'code': '24',
#     'name': 'Bus RATP 24',
# ...
#     'id': '523466'},
#    {'code': '318',
#     'name': 'Bus RATP 318',
#     'directions': 'Raymond Queneau - Route de Noisy / Chateau de Vincennes',
#     'id': '315512'},
#    {'code': '319',
#     'name': 'Bus RATP 319',
#     'directions': 'Avenue Saint Marc / (Avenue Saint Marc)',
#     'id': '534655'},
#    {'code': '319',
#     'name': 'Bus RATP 319',
#     'directions': '(Massy-Palaiseau RER) / Massy-Palaiseau RER',
#     'id': '534813'},
#    {'code': '321',
#     'name': 'Bus RATP 321',
#     'directions': 'Aerodrome de Lognes / Lognes RER',
#     'id': '497756'},
#    {'code': '321',
#     'name': 'Bus RATP 321',
#     'directions': 'Aerodrome de Lognes / (Aerodrome de Lognes)',
#     'id': '497757'},
#    {'code': '321',
#     'name': 'Bus RATP 321',
#     'directions': '(Croissy-Beaubourg) / Croissy-Beaubourg - Z.I. Pariest',
#     'id': '497758'},
#    {'code': '323',
#     'name': 'Bus RATP 323',
#     'directions': 'Chatillon - Montrouge / Issy-Val de Seine RER',
#     'id': '399723'},
#    {'code': '323',
#     'name': 'Bus RATP 323',
#     'directions': 'Gambetta / (Gambetta)',
#     'id': '546067'},
#    {'code': '337',
#     'name': 'Bus RATP 337',
#     'directions': '(Mairie de Montmagny) / Mairie de Montmagny',
#     'id': '554475'},
#    {'code': '346',
#     'name': 'Bus RATP 346',
#     'directions': 'Place de la Liberation / (Bois-Perrier RER)',
#     'id': '506202'},
#    {'code': '350',
#     'name': 'Bus RATP 350',
#     'directions': 'Roissypole - Gare - RER / (Roissypole - Gare - RER)',
#     'id': '529164'},
#    {'code': '350',
#     'name': 'Bus RATP 350',
#     'directions': 'Roissypole - Gare - RER / Porte de la Chapelle',
#     'id': '531133'},
#    {'code': '350',
#     'name': 'Bus RATP 350',
#     'directions': 'Roissypole - Gare - RER / Porte de la Chapelle',
#     'id': '531134'},
#    {'code': '350',
#     'name': 'Bus RATP 350',
#     'directions': 'Roissypole - Gare - RER / (Roissypole - Gare - RER)',
#     'id': '543495'},
#    {'code': '350',
#     'name': 'Bus RATP 350',
#     'directions': 'Roissypole - Gare - RER / (Roissypole - Gare - RER)',
#     'id': '543496'},
#    {'code': '350',
#     'name': 'Bus RATP 350',
#     'directions': 'Roissypole - Gare - RER / Porte de la Chapelle',
#     'id': '572215'},
#    {'code': '351',
#     'name': 'Bus RATP 351',
#     'directions': 'Roissypole / Nation',
#     'id': '191301'},
#    {'code': '351',
#     'name': 'Bus RATP 351',
#     'directions': 'Roissypole / Nation',
#     'id': '191302'},
#    {'code': '351',
#     'name': 'Bus RATP 351',
#     'directions': 'Gallieni / Rd Point Pierre Semard',
#     'id': '516775'},
#    {'code': '351',
#     'name': 'Bus RATP 351',
#     'directions': 'Roissypole / Nation',
#     'id': '516776'},
#    {'code': '351',
#     'name': 'Bus RATP 351',
#     'directions': 'Roissypole / Nation',
#     'id': '516778'},
#    {'code': '351',
#     'name': 'Bus RATP 351',
#     'directions': 'Nation / Roissypole',
#     'id': '516780'},
#    {'code': '355',
#     'name': 'Bus RATP 355',
#     'directions': 'Lycee Jean-Jacques Rousseau / (Lycee Jj Rousseau Circulaire)',
#     'id': '246735'},
#    {'code': '355',
#     'name': 'Bus RATP 355',
#     'directions': 'Lycee Jean-Jacques Rousseau / (Jj Rousseau Circulaire)',
#     'id': '246736'},
#    {'code': '367',
#     'name': 'Bus RATP 367',
#     'directions': 'Rueil-Malmaison RER / Nanterre-Ville RER',
#     'id': '209764'},
#    {'code': '370',
#     'name': 'Bus RATP 370',
#     'directions': 'Villiers le Bel - Arnouville RER / Marche de Saint-Brice',
#     'id': '365098'},
#    {'code': '372',
#     'name': 'Bus RATP 372',
#     'directions': 'Maisons Alfort-Louis Fliche / Maisons Alfort-Alfortville-RER',
#     'id': '188538'},
#    {'code': '385',
#     'name': 'Bus RATP 385',
#     'directions': '(Juvisy-RER) / Toulouse-Lautrec',
#     'id': '464658'},
#    {'code': '385',
#     'name': 'Bus RATP 385',
#     'directions': 'Pyramide de Juvisy / (Pyramide de Juvisy)',
#     'id': '572236'},
#    {'code': '385',
#     'name': 'Bus RATP 385',
#     'directions': 'Juvisy RER / Toulouse-Lautrec',
#     'id': '572237'},
#    {'code': '385',
#     'name': 'Bus RATP 385',
#     'directions': '(Pyramide de Juvisy) / Pyramide de Juvisy',
#     'id': '572238'},
#    {'code': '388',
#     'name': 'Bus RATP 388',
#     'directions': "Bourg-La-Reine RER / Porte d'Orleans",
#     'id': '419056'},
#    {'code': '388',
#     'name': 'Bus RATP 388',
#     'directions': "Bourg-La-Reine RER / Porte d'Orleans",
#     'id': '419057'},
#    {'code': '389',
#     'name': 'Bus RATP 389',
#     'directions': 'Georges Pompidou / H de Ville de Boulogne-Billancourt',
#     'id': '545749'},
#    {'code': '421',
#     'name': 'Bus RATP 421',
#     'directions': 'Chelles - Gournay RER / (Chelles)',
#     'id': '494708'},
#    {'code': '421',
#     'name': 'Bus RATP 421',
#     'directions': '(Torcy) / Torcy RER',
#     'id': '494709'},
#    {'code': '467',
#     'name': 'Bus RATP 467',
#     'directions': 'Rueil-Malmaison RER / Henri Regnault.',
#     'id': '209766'},
#    {'code': '485',
#     'name': 'Bus RATP 485',
#     'directions': 'Delalande Pasteur / Noyer Renard',
#     'id': '309361'},
#    {'code': '485',
#     'name': 'Bus RATP 485',
#     'directions': 'Delalande Pasteur / (Athis-Mons Noyer Renard)',
#     'id': '309362'},
#    {'code': '485',
#     'name': 'Bus RATP 485',
#     'directions': '(Athis-Mons Noyer Renard) / les Oiseaux',
#     'id': '309363'},
#    {'code': '485',
#     'name': 'Bus RATP 485',
#     'directions': 'Delalande Pasteur / (Delalande Pasteur)',
#     'id': '574264'},
#    {'code': '487',
#     'name': 'Bus RATP 487',
#     'directions': "Juvisy RER / Porte de l'Essonne",
#     'id': '464660'},
#    {'code': '520',
#     'name': 'Bus RATP 520',
#     'directions': '(Les Boullereaux-Champigny RER) / Bry-Sur-Marne RER',
#     'id': '480114'},
#    {'code': '520',
#     'name': 'Bus RATP 520',
#     'directions': '(Les Hauts de Bry) / Bry-Sur-Marne RER',
#     'id': '498150'},
#    {'code': '559a',
#     'name': 'Bus RATP 559a',
#     'directions': 'Gabriel Peri / Garches',
#     'id': '355066'},
#    {'code': '559b',
#     'name': 'Bus RATP 559b',
#     'directions': 'Gabriel Peri / Suresnes',
#     'id': '209774'},
#    {'code': '559b',
#     'name': 'Bus RATP 559b',
#     'directions': 'Verdun / Gabriel Peri',
#     'id': '355065'},
#    {'code': '559c',
#     'name': 'Bus RATP 559c',
#     'directions': 'Gabriel Peri / Soufflot',
#     'id': '355067'},
#    {'code': '559d',
#     'name': 'Bus RATP 559d',
#     'directions': "Place Foch / Chemin de l'Ile",
#     'id': '355068'},
#    {'code': '564',
#     'name': 'Bus RATP 564',
#     'directions': 'College la Malmaison / College la Malmaison',
#     'id': '541282'},
#    {'code': '595',
#     'name': 'Bus RATP 595',
#     'directions': 'Robinson RER / la Boursidiere',
#     'id': '203681'},
#    {'code': '595',
#     'name': 'Bus RATP 595',
#     'directions': 'Robinson RER / (Robinson RER)',
#     'id': '545754'},
#    {'code': 'As-Sure',
#     'name': 'Bus RATP As-Sure',
#     'directions': 'Place de Stalingrad / Circuit Marche',
#     'id': '541272'},
#    {'code': 'Bievres',
#     'name': 'Bus RATP Bievres',
#     'directions': 'Alesia - General Leclerc / la Traverse Bievre-Montsouris',
#     'id': '560306'},
#    {'code': 'Eolien',
#     'name': 'Bus RATP Eolien',
#     'directions': 'Cimetiere Nouveau / Conservatoire-Pressense',
#     'id': '541274'},
#    {'code': 'Eolien',
#     'name': 'Bus RATP Eolien',
#     'directions': 'Cimetiere Nouveau / Ecole des Sports - Ile de Puteaux',
#     'id': '541276'},
#    {'code': 'Eolien',
#     'name': 'Bus RATP Eolien',
#     'directions': 'Cimetiere Nouveau / Conservatoire-Pressense',
#     'id': '554470'},
#    {'code': 'Hironde',
#     'name': 'Bus RATP Hironde',
#     'directions': 'Hotel de Ville / Cimetiere Intercommunal',
#     'id': '191764'},
#    {'code': 'Hironde',
#     'name': 'Bus RATP Hironde',
#     'directions': 'Pierre Brossolette-Gabriel Peri / Cimetiere Intercommunal',
#     'id': '191767'},
#    {'code': 'Hironde',
#     'name': 'Bus RATP Hironde',
#     'directions': 'Hotel de Ville / (Hotel de Ville.)',
#     'id': '547389'},
#    {'code': 'avette',
#     'name': 'Bus RATP Navette',
#     'directions': 'Les Alouettes / les Parapluies-Val de Fontenay',
#     'id': '192085'},
#    {'code': 'avette',
#     'name': 'Bus RATP Navette',
#     'directions': 'Val de Fontenay-RER / les Parapluies-Val de Fontenay',
#     'id': '192086'},
#    {'code': 'avette',
#     'name': 'Bus RATP Navette',
#     'directions': 'Val de Fontenay-RER / les Parapluies-Val de Fontenay',
#     'id': '192087'},
#    {'code': 'ey-Fla',
#     'name': 'Bus RATP Ney-Fla',
#     'directions': "(Porte d'Aubervilliers - Oberle) / Porte d'Aubervilliers - Oberle",
#     'id': '530082'},
#    {'code': 'ey-Fla',
#     'name': 'Bus RATP Ney-Fla',
#     'directions': 'La Chapelle / (La Chapelle)',
#     'id': '530084'},
#    {'code': 'ey-Fla',
#     'name': 'Bus RATP Ney-Fla',
#     'directions': 'Place Hebert / (Place Hebert)',
#     'id': '530085'},
#    {'code': 'Orlybus',
#     'name': 'Bus RATP Orlybus',
#     'directions': "Denfert-Rochereau-Metro-RER / Aeroport d'Orly 1-2-3",
#     'id': '560303'},
#    {'code': 'Petit-F',
#     'name': 'Bus RATP Petit-F',
#     'directions': 'Su Circulaire / Division Leclerc.',
#     'id': '203644'},
#    {'code': 'Port',
#     'name': 'Bus RATP Port',
#     'directions': '(Gennevilliers) / Asnieres - les Courtilles',
#     'id': '488295'},
#    {'code': 'Port',
#     'name': 'Bus RATP Port',
#     'directions': 'Gare du Stade / (Le Bus du Port)',
#     'id': '488296'},
#    {'code': 'im',
#     'name': 'Bus RATP Tim',
#     'directions': 'Gare de Bellevue / (Gare de Bellevue.)',
#     'id': '554472'},
#    {'code': 'im',
#     'name': 'Bus RATP Tim',
#     'directions': 'Gare de Bellevue / (Gare de Bellevue.)',
#     'id': '554473'},
#    {'code': 'ub',
#     'name': 'Bus RATP Tub',
#     'directions': 'La Mare a la Veuve / Bondy',
#     'id': '191776'},
#    {'code': 'uc',
#     'name': 'Bus RATP Tuc',
#     'directions': 'Cailloux / Van Gogh',
#     'id': '309694'},
#    {'code': 'uvim',
#     'name': 'Bus RATP Tuvim',
#     'directions': "Mairie d'Issy-Metro / Circuit Grand Issy et Centre",
#     'id': '208993'},
#    {'code': 'uvim',
#     'name': 'Bus RATP Tuvim',
#     'directions': "Mairie d'Issy-Metro / (Circuits Grand Issy et Centre V)",
#     'id': '344603'},
#    {'code': 'uvim',
#     'name': 'Bus RATP Tuvim',
#     'directions': "Mairie d'Issy-Metro / (Circuits Grand Issy)",
#     'id': '344604'},
#    {'code': 'V2',
#     'name': 'Bus RATP V2',
#     'directions': 'Pasteur / Domaine Cherioux',
#     'id': '223508'},
#    {'code': 'V3',
#     'name': 'Bus RATP V3',
#     'directions': 'Centre Ville / Su Cachan',
#     'id': '197293'},
#    {'code': 'V5',
#     'name': 'Bus RATP V5',
#     'directions': 'Gabriel Peri - Soleil Levant / Service Urbain de Gentilly',
#     'id': '560311'},
#    {'code': 'V5',
#     'name': 'Bus RATP V5',
#     'directions': 'Gabriel Peri - Soleil Levant / Service Urbain de Gentilly',
#     'id': '560312'},
#    {'code': 'V5',
#     'name': 'Bus RATP V5',
#     'directions': 'Gabriel Peri - Soleil Levant / Service Urbain de Gentilly',
#     'id': '560313'},
#    {'code': 'V6',
#     'name': 'Bus RATP V6',
#     'directions': 'Leclerc - Thomas / Service Urbain du Kremlin Bicetre',
#     'id': '560320'}],
#   'noctiliens': [{'code': '01',
#     'name': 'Noctilien N01',
#     'directions': "Gare de l'Est / Gare de l'Est",
#     'id': '210642'},
#    {'code': '02',
#     'name': 'Noctilien N02',
#     'directions': 'Gare Montparnasse / Gare Montparnasse',
#     'id': '210221'},
#    {'code': '11',
#     'name': 'Noctilien N11',
#     'directions': 'Pont de Neuilly-Metro / Chateau de Vincennes',
#     'id': '210220'},
#    {'code': '12',
#     'name': 'Noctilien N12',
#     'directions': 'Pont de Sevres (Travaux) / Romiainville - Carnot',
#     'id': '355744'},
#    {'code': '13',
#     'name': 'Noctilien N13',
#     'directions': "Mairie d'Issy-Metro / Bobigny - Pablo Picasso",
#     'id': '210218'},
#    {'code': '14',
#     'name': 'Noctilien N14',
#     'directions': 'La Croix de Berny RER / Mairie de Saint-Ouen - Republique',
#     'id': '397426'},
#    {'code': '15',
#     'name': 'Noctilien N15',
#     'directions': 'Villejuif-Louis Aragon / Gabriel Peri-Metro',
#     'id': '210216'},
#    {'code': '16',
#     'name': 'Noctilien N16',
#     'directions': 'Pont de Levallois-Metro / Mairie de Montreuil Rouget',
#     'id': '210214'},
#    {'code': '21',
#     'name': 'Noctilien N21',
#     'directions': 'Chatelet / Hopital de Longjumeau',
#     'id': '397428'},
#    {'code': '22',
#     'name': 'Noctilien N22',
#     'directions': 'Juvisy-RER / Chatelet',
#     'id': '468703'},
#    {'code': '23',
#     'name': 'Noctilien N23',
#     'directions': 'Chelles - Gournay RER (Travaux) / Chatelet',
#     'id': '355745'},
#    {'code': '24',
#     'name': 'Noctilien N24',
#     'directions': 'Chatelet / Gare de Sartrouville-RER',
#     'id': '397427'},
#    {'code': '31',
#     'name': 'Noctilien N31',
#     'directions': '(Gdl-Orly 4) / Gare de Lyon',
#     'id': '234308'},
#    {'code': '32',
#     'name': 'Noctilien N32',
#     'directions': 'Gare de Lyon / (Boissy-Saint-Leger RER)',
#     'id': '301484'},
#    {'code': '33',
#     'name': 'Noctilien N33',
#     'directions': 'Gare de Lyon / Villiers - le Plessis-Trevise RER',
#     'id': '210206'},
#    {'code': '34',
#     'name': 'Noctilien N34',
#     'directions': 'Torcy-RER / Gare de Lyon',
#     'id': '275995'},
#    {'code': '35',
#     'name': 'Noctilien N35',
#     'directions': 'Gare de Lyon - Diderot / Villiers-Sur-Marne - le Plessis-RER',
#     'id': '455609'},
#    {'code': '41',
#     'name': 'Noctilien N41',
#     'directions': "Gare de l'Est / Villeparisis - Mitry-Le-Neuf RER",
#     'id': '305729'},
#    {'code': '42',
#     'name': 'Noctilien N42',
#     'directions': "Gare de l'Est / Garonor",
#     'id': '210201'},
#    {'code': '43',
#     'name': 'Noctilien N43',
#     'directions': "Gare de l'Est / Gare de Sarcelles-Saint-Brice",
#     'id': '210200'},
#    {'code': '44',
#     'name': 'Noctilien N44',
#     'directions': "Gare de l'Est / Garges-Sarcelles RER",
#     'id': '220190'},
#    {'code': '45',
#     'name': 'Noctilien N45',
#     'directions': "Gare de l'Est / Hopital de Montfermeil",
#     'id': '210198'},
#    {'code': '51',
#     'name': 'Noctilien N51',
#     'directions': "Gare Saint-Lazare / Gare d'Enghien-Les-Bains",
#     'id': '272065'},
#    {'code': '52',
#     'name': 'Noctilien N52',
#     'directions': 'Gare Saint Lazare / Gare de Cormeilles-En-Parisis',
#     'id': '397429'},
#    {'code': '53',
#     'name': 'Noctilien N53',
#     'directions': 'Gare Saint-Lazare / Nanterre - Anatole France',
#     'id': '333018'},
#    {'code': '61',
#     'name': 'Noctilien N61',
#     'directions': 'Gare Montparnasse / Georges Pompidou',
#     'id': '270275'},
#    {'code': '62',
#     'name': 'Noctilien N62',
#     'directions': 'Gare Montparnasse / Marche International de Rungis',
#     'id': '397430'},
#    {'code': '63',
#     'name': 'Noctilien N63',
#     'directions': 'Gare Montparnasse / Polytechnique Vauve',
#     'id': '514955'},
#    {'code': '66',
#     'name': 'Noctilien N66',
#     'directions': 'Gare de Chaville-Rive-Droite / Gare Montparnasse',
#     'id': '455608'},
#    {'code': '71',
#     'name': 'Noctilien N71',
#     'directions': 'Val de Fontenay RER / Marche International de Rungis',
#     'id': '397431'},
#    {'code': '122',
#     'name': 'Noctilien N122',
#     'directions': 'Chatelet / Saint-Remy-Les-Chevreuse RER',
#     'id': '360725'},
#    {'code': '153',
#     'name': 'Noctilien N153',
#     'directions': 'Gare Saint-Lazare / Saint-Germain-En-Laye RER',
#     'id': '210191'},
#    {'code': '16',
#     'name': 'Noctilien N16',
#     'directions': '(M de Mont - Pont de Levallois) / Mairie de Montreuil',
#     'id': '233673'},
#    {'code': '23',
#     'name': 'Noctilien N23',
#     'directions': 'Chatelet (Travaux) / Chelles - Gournay RER',
#     'id': '355747'},
#    {'code': '31',
#     'name': 'Noctilien N31',
#     'directions': 'Orly 4 / (Gdl-Orly 4)',
#     'id': '234307'},
#    {'code': '32',
#     'name': 'Noctilien N32',
#     'directions': '(Gare de Lyon) / Boissy-Saint-Leger RER',
#     'id': '301485'},
#    {'code': '33',
#     'name': 'Noctilien N33',
#     'directions': 'Gare de Lyon - Diderot / Villiers - le Plessis-Trevise RER',
#     'id': '210207'},
#    {'code': '34',
#     'name': 'Noctilien N34',
#     'directions': 'Gare de Lyon / Torcy-RER',
#     'id': '275996'}]},
#  '_metadata': {'call': 'GET /lines',
#   'date': '2022-01-12T14:38:05+01:00',
#   'version': 4}}

# %% [markdown]
# The request was successful!
#
# The data lists all the different transport lines managed by ratp. It lists various pieces of information about the line:
#
# * **code**: a number associated with the line
# * **name**: the commonly used name of the line
# * **directions**: the final destinations of the line
# * **id**: an identification number for the line

# %% [markdown]
# ### API call with specific endpoint/url
#
# Now that we have covered the easy topic of calling generic API endpoints let's explore endpoints that contain options.
#
# For example, the `https://api-ratp.pierre-grimaud.fr/v4/lines/{type}/{code}` accepts two options, `type`, and `code`. Let's take a look at what the documentation says:
#
# ![ratp_lines_option](https://full-stack-assets.s3.eu-west-3.amazonaws.com/images/0-M04-data-collection/ratp_lines_options.PNG)
#
# The documentation tells you this endpoint will give you information about a specific ratp line. It also decribes what is expected for the two options:
#
# * `type`: is one of the following options `metros`, `rers`, `tramways`, `buses`, `noctiliens`, and determines the subsection of lines you are trying to get information on
# * `code`: indicates the code of the line, it is the data associated with `code` key in the previous json file obtained from the API
#
# Two response codes may be recieved from this endpoint, either 200 for success or 400 in case the `type` or `code` option you asked for does not exist.
#
# Let's give it a try!

# %%
r = requests.get("https://api-ratp.pierre-grimaud.fr/v4/lines/metros/1")

print("Response code:", r, "\n \n")
print("Response data:\n")
r.json()
# Out:
# Response code: <Response [200]>
#
#
# Response data:
# {'result': {'code': '1',
#   'name': 'Métro 1',
#   'directions': 'La Defense / Chateau de Vincennes',
#   'id': '62'},
#  '_metadata': {'call': 'GET /lines/metros/1',
#   'date': '2022-01-12T14:38:05+01:00',
#   'version': 4}}

# %% [markdown]
# We were able to get information about line 1 of the Parisian metro!

# %% [markdown]
# ### API call with payload
#
# The ratp API we just gave you a tour of is rather simple, either you know exactly which endpoint to call and you'd get the information, or you don't. Now there are some API that let you run `GET` queries in a way that is a little more flexible.
#
# Let's take the example of the [teleport API](https://developers.teleport.org/api/getting_started/#search_name), an API that contains data on cities around the worlds regarding quality of likfe. This API comes with a feature that lets you search cities by name.
#
# There are two ways of calling the API to search for cities, one uses an url and the other leverages the ability of the `requests` library to handle payload.
#
# If we look at the API documentation, we notice that the example given is `https://api.teleport.org/api/cities/?search=San%20Francisco` to search for San Francisco. However this is not necessarily the best way to proceed for a number of reasons:
#
# * If the number of options becomes higher then the url will get more complicated with very little legibility
# * Typing a url directly is not really intuitive and is prone to error
# * Special characters aren't allowed in urls, which makes some queries espacially difficult to write
#
# Which is why it is often useful to use the `params` argument of the `requests.get` method. Let's give a shot demonstration.

# %%
response1 = requests.get("https://api.teleport.org/api/cities/?search=San%20Francisco")
response1.json()
# Out:
# {'_embedded': {'city:search-results': [{'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:5391959/'}},
#     'matching_alternate_names': [{'name': 'San Francisco'}],
#     'matching_full_name': 'San Francisco, California, United States'},
#    {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3652462/'}},
#     'matching_alternate_names': [{'name': 'San Francisco de Quito'}],
#     'matching_full_name': 'Quito, Pichincha, Ecuador (San Francisco de Quito)'},
#    {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3493146/'}},
#     'matching_alternate_names': [{'name': 'San Francisco de Macorís'},
#      {'name': 'San Francisco de Macoris'}],
#     'matching_full_name': 'San Francisco de Macorís, Duarte, Dominican Republic'},
#    {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:5454711/'}},
#     'matching_alternate_names': [{'name': 'San Francisco de Albuquerque'},
#      {'name': 'San Francisco Xavier'}],
#     'matching_full_name': 'Albuquerque, New Mexico, United States (San Francisco de Albuquerque)'},
#    {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3515807/'}},
#     'matching_alternate_names': [{'name': 'San Francisco Tepoiaco'}],
#     'matching_full_name': 'Cuautitlán Izcalli, México, Mexico (San Francisco Tepoiaco)'},
#    {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3986984/'}},
#     'matching_alternate_names': [{'name': 'San Francisco del Rincón'},
#      {'name': 'San Francisco del Rincon'}],
#     'matching_full_name': 'San Francisco del Rincón, Guanajuato, Mexico'},
#    {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3837675/'}},
#     'matching_alternate_names': [{'name': 'San Francisco'}],
#     'matching_full_name': 'San Francisco, Cordoba, Argentina'},
#    {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3621911/'}},
#     'matching_alternate_names': [{'name': 'San Francisco'}],
#     'matching_full_name': 'San Francisco, Heredia, Costa Rica'},
#    {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3590219/'}},
#     'matching_alternate_names': [{'name': 'San Francisco'},
#      {'name': 'San Francisco El Alto'}],
#     'matching_full_name': 'San Francisco El Alto, Totonicapán, Guatemala'},
#    {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3531732/'}},
#     'matching_alternate_names': [{'name': 'San Francisco de Campeche'}],
#     'matching_full_name': 'Campeche, Campeche, Mexico (San Francisco de Campeche)'},
#    {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3654215/'}},
#     'matching_alternate_names': [{'name': 'San Francisco de Milagro'}],
#     'matching_full_name': 'Milagro, Guayas, Ecuador (San Francisco de Milagro)'},
#    {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3519290/'}},
#     'matching_alternate_names': [{'name': 'San Francisco Acuautla'}],
#     'matching_full_name': 'San Francisco Acuautla, México, Mexico'},
#    {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1689973/'}},
#     'matching_alternate_names': [{'name': 'San Francisco'}],
#     'matching_full_name': 'San Francisco, Central Luzon, Philippines'},
#    {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1690019/'}},
#     'matching_alternate_names': [{'name': 'San Francisco'}],
#     'matching_full_name': 'San Francisco, Caraga, Philippines'},
#    {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3583747/'}},
#     'matching_alternate_names': [{'name': 'San Francisco'},
#      {'name': 'San Francisco Gotera'}],
#     'matching_full_name': 'San Francisco, Morazán, El Salvador'},
#    {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3590197/'}},
#     'matching_alternate_names': [{'name': 'San Francisco Zapotitlan'},
#      {'name': 'San Francisco Zapotitlán'}],
#     'matching_full_name': 'San Francisco Zapotitlán, Suchitepeque, Guatemala'},
#    {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:8858142/'}},
#     'matching_alternate_names': [{'name': 'San Francisco Tecoxpa'}],
#     'matching_full_name': 'San Francisco Tecoxpa, Mexico City, Mexico'},
#    {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3519249/'}},
#     'matching_alternate_names': [{'name': 'San Francisco Tlalcilalcalpa'},
#      {'name': 'San Francisco Tlalcilalcalpan'}],
#     'matching_full_name': 'San Francisco Tlalcilalcalpan, México, Mexico'},
#    {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3522454/'}},
#     'matching_alternate_names': [{'name': 'San Francisco Ocotlan'},
#      {'name': 'San Francisco Ocotlán'}],
#     'matching_full_name': 'San Francisco Ocotlán, Puebla, Mexico'},
#    {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3519255/'}},
#     'matching_alternate_names': [{'name': 'San Francisco Telixtlahuaca'},
#      {'name': 'San Francisco'}],
#     'matching_full_name': 'San Francisco Telixtlahuaca, Oaxaca, Mexico'},
#    {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1690011/'}},
#     'matching_alternate_names': [{'name': 'San Francisco'}],
#     'matching_full_name': 'San Francisco, Central Visayas, Philippines'},
#    {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3449112/'}},
#     'matching_alternate_names': [{'name': 'San Francisco del Sur'}],
#     'matching_full_name': 'São Francisco do Sul, Santa Catarina, Brazil (San Francisco del Sur)'},
#    {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3519243/'}},
#     'matching_alternate_names': [{'name': 'San Francisco Zacacalco'},
#      {'name': 'San Francisco'}],
#     'matching_full_name': 'San Francisco Zacacalco, Morelos, Mexico'},
#    {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3530852/'}},
#     'matching_alternate_names': [{'name': 'San Francisco Chimalpa'}],
#     'matching_full_name': 'San Francisco Chimalpa, Morelos, Mexico'},
#    {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3981791/'}},
#     'matching_alternate_names': [{'name': 'San Francisco Tesistan'},
#      {'name': 'San Francisco Tesistán'}],
#     'matching_full_name': 'Tesistán, Jalisco, Mexico (San Francisco Tesistan)'}]},
#  '_links': {'curies': [{'href': 'https://developers.teleport.org/api/resources/Location/#!/relations/{rel}/',
#     'name': 'location',
#     'templated': True},
#    {'href': 'https://developers.teleport.org/api/resources/City/#!/relations/{rel}/',
#     'name': 'city',
#     'templated': True},
#    {'href': 'https://developers.teleport.org/api/resources/UrbanArea/#!/relations/{rel}/',
#     'name': 'ua',
#     'templated': True},
#    {'href': 'https://developers.teleport.org/api/resources/Country/#!/relations/{rel}/',
#     'name': 'country',
#     'templated': True},
#    {'href': 'https://developers.teleport.org/api/resources/Admin1Division/#!/relations/{rel}/',
#     'name': 'a1',
#     'templated': True},
#    {'href': 'https://developers.teleport.org/api/resources/Timezone/#!/relations/{rel}/',
#     'name': 'tz',
#     'templated': True}],
#   'self': {'href': 'https://api.teleport.org/api/cities/?search=San%20Francisco&geohash='}},
#  'count': 25}

# %%
response2 = requests.get(" https://api.teleport.org/api/cities",params={"search":"San Francisco"})
response2.json()
# Out:
# {'_embedded': {'city:search-results': [{'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:5391959/'}},
#     'matching_alternate_names': [{'name': 'San Francisco'}],
#     'matching_full_name': 'San Francisco, California, United States'},
#    {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3652462/'}},
#     'matching_alternate_names': [{'name': 'San Francisco de Quito'}],
#     'matching_full_name': 'Quito, Pichincha, Ecuador (San Francisco de Quito)'},
#    {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3493146/'}},
#     'matching_alternate_names': [{'name': 'San Francisco de Macorís'},
#      {'name': 'San Francisco de Macoris'}],
#     'matching_full_name': 'San Francisco de Macorís, Duarte, Dominican Republic'},
#    {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:5454711/'}},
#     'matching_alternate_names': [{'name': 'San Francisco de Albuquerque'},
#      {'name': 'San Francisco Xavier'}],
#     'matching_full_name': 'Albuquerque, New Mexico, United States (San Francisco de Albuquerque)'},
#    {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3515807/'}},
#     'matching_alternate_names': [{'name': 'San Francisco Tepoiaco'}],
#     'matching_full_name': 'Cuautitlán Izcalli, México, Mexico (San Francisco Tepoiaco)'},
#    {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3986984/'}},
#     'matching_alternate_names': [{'name': 'San Francisco del Rincón'},
#      {'name': 'San Francisco del Rincon'}],
#     'matching_full_name': 'San Francisco del Rincón, Guanajuato, Mexico'},
#    {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3837675/'}},
#     'matching_alternate_names': [{'name': 'San Francisco'}],
#     'matching_full_name': 'San Francisco, Cordoba, Argentina'},
#    {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3621911/'}},
#     'matching_alternate_names': [{'name': 'San Francisco'}],
#     'matching_full_name': 'San Francisco, Heredia, Costa Rica'},
#    {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3590219/'}},
#     'matching_alternate_names': [{'name': 'San Francisco'},
#      {'name': 'San Francisco El Alto'}],
#     'matching_full_name': 'San Francisco El Alto, Totonicapán, Guatemala'},
#    {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3531732/'}},
#     'matching_alternate_names': [{'name': 'San Francisco de Campeche'}],
#     'matching_full_name': 'Campeche, Campeche, Mexico (San Francisco de Campeche)'},
#    {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3654215/'}},
#     'matching_alternate_names': [{'name': 'San Francisco de Milagro'}],
#     'matching_full_name': 'Milagro, Guayas, Ecuador (San Francisco de Milagro)'},
#    {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3519290/'}},
#     'matching_alternate_names': [{'name': 'San Francisco Acuautla'}],
#     'matching_full_name': 'San Francisco Acuautla, México, Mexico'},
#    {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1689973/'}},
#     'matching_alternate_names': [{'name': 'San Francisco'}],
#     'matching_full_name': 'San Francisco, Central Luzon, Philippines'},
#    {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1690019/'}},
#     'matching_alternate_names': [{'name': 'San Francisco'}],
#     'matching_full_name': 'San Francisco, Caraga, Philippines'},
#    {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3583747/'}},
#     'matching_alternate_names': [{'name': 'San Francisco'},
#      {'name': 'San Francisco Gotera'}],
#     'matching_full_name': 'San Francisco, Morazán, El Salvador'},
#    {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3590197/'}},
#     'matching_alternate_names': [{'name': 'San Francisco Zapotitlan'},
#      {'name': 'San Francisco Zapotitlán'}],
#     'matching_full_name': 'San Francisco Zapotitlán, Suchitepeque, Guatemala'},
#    {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:8858142/'}},
#     'matching_alternate_names': [{'name': 'San Francisco Tecoxpa'}],
#     'matching_full_name': 'San Francisco Tecoxpa, Mexico City, Mexico'},
#    {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3519249/'}},
#     'matching_alternate_names': [{'name': 'San Francisco Tlalcilalcalpa'},
#      {'name': 'San Francisco Tlalcilalcalpan'}],
#     'matching_full_name': 'San Francisco Tlalcilalcalpan, México, Mexico'},
#    {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3522454/'}},
#     'matching_alternate_names': [{'name': 'San Francisco Ocotlan'},
#      {'name': 'San Francisco Ocotlán'}],
#     'matching_full_name': 'San Francisco Ocotlán, Puebla, Mexico'},
#    {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3519255/'}},
#     'matching_alternate_names': [{'name': 'San Francisco Telixtlahuaca'},
#      {'name': 'San Francisco'}],
#     'matching_full_name': 'San Francisco Telixtlahuaca, Oaxaca, Mexico'},
#    {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:1690011/'}},
#     'matching_alternate_names': [{'name': 'San Francisco'}],
#     'matching_full_name': 'San Francisco, Central Visayas, Philippines'},
#    {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3449112/'}},
#     'matching_alternate_names': [{'name': 'San Francisco del Sur'}],
#     'matching_full_name': 'São Francisco do Sul, Santa Catarina, Brazil (San Francisco del Sur)'},
#    {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3519243/'}},
#     'matching_alternate_names': [{'name': 'San Francisco Zacacalco'},
#      {'name': 'San Francisco'}],
#     'matching_full_name': 'San Francisco Zacacalco, Morelos, Mexico'},
#    {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3530852/'}},
#     'matching_alternate_names': [{'name': 'San Francisco Chimalpa'}],
#     'matching_full_name': 'San Francisco Chimalpa, Morelos, Mexico'},
#    {'_links': {'city:item': {'href': 'https://api.teleport.org/api/cities/geonameid:3981791/'}},
#     'matching_alternate_names': [{'name': 'San Francisco Tesistan'},
#      {'name': 'San Francisco Tesistán'}],
#     'matching_full_name': 'Tesistán, Jalisco, Mexico (San Francisco Tesistan)'}]},
#  '_links': {'curies': [{'href': 'https://developers.teleport.org/api/resources/Location/#!/relations/{rel}/',
#     'name': 'location',
#     'templated': True},
#    {'href': 'https://developers.teleport.org/api/resources/City/#!/relations/{rel}/',
#     'name': 'city',
#     'templated': True},
#    {'href': 'https://developers.teleport.org/api/resources/UrbanArea/#!/relations/{rel}/',
#     'name': 'ua',
#     'templated': True},
#    {'href': 'https://developers.teleport.org/api/resources/Country/#!/relations/{rel}/',
#     'name': 'country',
#     'templated': True},
#    {'href': 'https://developers.teleport.org/api/resources/Admin1Division/#!/relations/{rel}/',
#     'name': 'a1',
#     'templated': True},
#    {'href': 'https://developers.teleport.org/api/resources/Timezone/#!/relations/{rel}/',
#     'name': 'tz',
#     'templated': True}],
#   'self': {'href': 'https://api.teleport.org/api/cities/?search=San%20Francisco&geohash='}},
#  'count': 25}

# %%
response1.json()==response2.json()
# Out:
# True

# %% [markdown]
# Responses for both queries are identical! So remember to use payloads every time you need to add extra parameters to your API call, it is very useful and helps prevent errors!

# %% [markdown]
# ### API call with POST method
#
# In the case of search, or anything else using payloads to add parameters to your query, you are only trying to access data which is already here, it all pre-exists your request. In other cases, for example if you are trying to get a predictive model's prediction, then the response you will get will be built on the spot depending on the data you sent.
#
# This is actually where the post method comes in handy, because it lets you send data to the API that will be transformed in some way to create the response.
#
# A really good example of such a usecase is a machine translation API, like [Google Translate](https://rapidapi.com/googlecloud/api/google-translate1/). APIs registered on **rapideapi** are really easy to use because the platform registers API and gives standardised documentation, which means you won't have to re-learn how to use the API every single time. It even lets you indicate with what language and what library you're using to access the API. So if we choose `pyhthon` `requests` we see this:
#
# ```python
# import requests
#
# url = "https://google-translate1.p.rapidapi.com/language/translate/v2"
#
# payload = "q=Hello%2C%20world!&target=es&source=en"
# headers = {
#     'content-type': "application/x-www-form-urlencoded",
#     'accept-encoding': "application/gzip",
#     'x-rapidapi-host': "google-translate1.p.rapidapi.com",
#     'x-rapidapi-key': "d448db74f1msh71600bf0b7eb394p1467b7jsn2923992aa0d0"
#     }
#
# response = requests.request("POST", url, data=payload, headers=headers)
#
# print(response.text)
# ```
#
# Let's try and use it in an even simpler way

# %%
url = "https://google-translate1.p.rapidapi.com/language/translate/v2"
data = {"q":"Hello, World!", "target":"es", "source":"en"}
headers = {
    'x-rapidapi-key': "d448db74f1msh71600bf0b7eb394p1467b7jsn2923992aa0d0"
    }

translation = requests.post(url, data=data, headers=headers)
translation.json()
# Out:
# {'data': {'translations': [{'translatedText': '¡Hola Mundo!'}]}}

# %% [markdown]
# The first element of the query had to be the endpoint we are trying to access. Then we had to include the data with the sentence we wish to translate, the target language and source language. Then the `headers` is used to feed our authentication key to the API so it knows we are authorized and have'nt exceeded our query quota.

# %% [markdown]
# ## API limitations and quotas
#
# Most APIs put in place protections such as authentication procedures, limits and quotas. There are several reasons for this:
#
# * If too many queries hit your API at the same time, the machine on which the API is running might not be able to handle them all and crash, meaning the API will be down until it gets rebooted.
# * Having your API running on a machine or a group of machines to match incoming demand is costly, therefore you want to prevent people from over using your API to prevent costs blowing through the roof.
# * Let's take the example of Twitter, a huge part of its data is actually public, since it's comprised of what public  profiles post, therefore if there were no limitations on Twitter's API, people could get all of twitter's publicly available data and use it for commercial purposes. However this is already what twitter is trying to do to sell advertising for example, to leverage there data to do ad targeting, if everyone could do the same twitter would lose a huge competitive advantage.
# * Some APIs are not meant to be public, companies and institutions use APIs to make specific data available to their teams but do not whish the general public to have access.
#
# It is not generally dangerous to exceed quotas or to try and call an API with the wrong access key because most of the time you will simply get an error stating the reason for your query not succeeding. Just read carefully trough the API's documentation to understand its security standards and limitations in order to avoid unpleasant surprises such as having to wait 24 hours for your quota to be filled up again!

# %% [markdown]
# ## Concluding remarks
# By now you should have a much better understanding of how API work and how to get started with brand new APIs. Let's sum up what we have learned and list some best practices:
#
# * ALWAYS read the documentation carefully before writing API calls
# * Start with test queries that resolve quickly before attempting to get massive amounts of data
# * Pay attention to athentication instructions and quotas in order to gauge the amount of calls you'd be able to make to avoid getting stuck
# * Try and use the full potential of the methods `.get()`, and `.post()` from the `requests` library instead of trying to write the full query using the url.
